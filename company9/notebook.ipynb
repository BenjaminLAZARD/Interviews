# %% [markdown]
# # Mojo
#
# Using GPT-3 for summarization and prompt answering
#
# ## How to run
#
# This jupyter notebook requires the following libraries (can be installed via pip)
# ```pip
# json
# configparser
# langchain
# openai
# tiktoken
# ```
#
# - Install "demo-segments.json" in the same repository
# - Create a file config.cfg with the following pattern
# ```cfg
# [OPENAI]
# OPENAI_API_KEY = <token>
# ```
#
#
# ## Summarization
#
# We posess a json documents that corresponds to the transcript (time-dated) of a conversation. We want to obtain
# 1. a 60 word max summary.
# 2. A free-format summary used by the callers' peers to know what happened during the call.
#
# ### 1. 60 word summary
#
# Let us first check out the json

# %%
import json

with open("demo-segments.json") as f:
    data = json.load(f)
data
# Out:
# {'language': 'fr-FR',
#  'isStereo': False,
#  'jobname': 'modjo-zoom-b2a540b4da309e1f',
#  'segments': [{'startTime': 13.62,
#    'endTime': 15.36,
#    'content': 'Oui bonjour Celeste.',
#    'speaker': 'spk2',
#    'uuid': 'd4478b0c-ae03-4ee8-bb08-a68a9a357b5b',
#    'blockUuid': '9e6a9250-9fd7-4b49-9b76-0df57ec043a6'},
#   {'startTime': 15.58,
#    'endTime': 18.24,
#    'content': 'Bonjour Merlin. Comment vas-tu ?',
#    'speaker': 'spk0',
#    'uuid': '6b37c91b-6ba0-4911-b551-6338c042988d',
#    'blockUuid': 'd340f539-7c41-4a7c-afb7-68b099ef3f70'},
#   {'startTime': 18.24,
#    'endTime': 19.6,
#    'content': 'Très bien et toi ?',
#    'speaker': 'spk2',
#    'uuid': 'e133d694-bec6-47d1-8190-8fc1e1c71231',
#    'blockUuid': '2383fb4d-fb85-4e37-a66e-875d1600303e'},
#   {'startTime': 19.6,
#    'endTime': 25.98,
#    'content': "Super. Écoute, ça va super. Je suis ravie de commencer mon après-midi avec toi. Je vois que la caméra n'a",
#    'speaker': 'spk0',
#    'uuid': '7976e5e3-af10-4130-aeda-0426e023ce39',
#    'blockUuid': '9621feff-03a5-4c25-99b8-b357742cb8e6'},
#   {'startTime': 25.98,
#    'endTime': 29.18,
#    'content': "pas été réparée. Je sais pas si t'es tout seul ou t'es avec...",
#    'speaker': 'spk0',
#    'uuid': '4af11f27-7a69-4dd0-aded-8b2e9ee3e8e7',
#    'blockUuid': '9621feff-03a5-4c25-99b8-b357742cb8e6'},
#   {'startTime': 30.08,
#    'endTime': 33.42,
#    'content': "Non, là je t'avoue que avec le gros brume que j'ai...",
#    'speaker': 'spk2',
#    'uuid': 'a76695e6-d0ac-4077-a65c-ac92559bc1f0',
#    'blockUuid': '425c9a50-b972-4a7f-9707-b9140ca598f8'},
#   {'startTime': 33.42,
#    'endTime': 39.32,
#    'content': "Ah oui ! Ok, pas de problème. Non, mais je ne savais pas si du coup, Arthur et l'autre Merlin",
#    'speaker': 'spk0',
#    'uuid': '407ae334-7040-48e1-a6a2-f4d5add08e84',
#    'blockUuid': 'bec0d7d5-ec31-436d-b0eb-359b7b51b3f1'},
#   {'startTime': 39.32,
#    'endTime': 41.72,
#    'content': "se connectaient derrière toi ou s'il y avait d'autres personnes qui arrivaient.",
#    'speaker': 'spk0',
#    'uuid': '5970fbb6-3a46-43e3-8b96-8999d9c594a9',
#    'blockUuid': 'bec0d7d5-ec31-436d-b0eb-359b7b51b3f1'},
#   {'startTime': 41.72,
#    'endTime': 45.06,
#    'content': 'Non, alors Merlin, je ne sais pas, mais Arthur, ben voilà, il est là, parfait.',
#    'speaker': 'spk2',
#    'uuid': '1a3f1641-2399-4428-b5b3-b47b45bbd94d',
#    'blockUuid': 'd7cbd015-2f89-429c-81e6-a0c1f17d8763'},
#   {'startTime': 45.46,
#    'endTime': 48.24,
#    'content': 'Ben voilà. Bonjour Arthur, enchanté. Salut Arthur.',
#    'speaker': 'spk0',
#    'uuid': '0e5df3dd-6705-4c05-a800-6520c3867767',
#    'blockUuid': 'c26386eb-ced5-4524-a535-e88dfb4cd1fa'},
#   {'startTime': 48.88,
#    'endTime': 50.32,
#    'content': 'Je suis là, bonjour Celeste.',
#    'speaker': 'spk1',
#    'uuid': '5947caeb-cb8b-4481-a24e-033b4fe03d3c',
#    'blockUuid': '6f6ed017-2512-4512-9d64-9c00546cb1e7'},
#   {'startTime': 50.84,
#    'endTime': 57.72,
#    'content': "Ah c'est Merlin, parfait. Donc, je suis juste contente de reposer le contexte par rapport à notre échange de la",
#    'speaker': 'spk2',
#    'uuid': '1b8b8756-ca46-47de-950e-b10798cbc549',
#    'blockUuid': 'b91b9d79-8659-4215-9c6c-3a3701a2af12'},
#   {'startTime': 57.72,
#    'endTime': 61.82,
#    'content': "dernière fois et puis l'objectif de cette petite call tous ensemble.",
#    'speaker': 'spk2',
#    'uuid': 'f7319d8a-a901-42d4-acd5-186f978d0965',
#    'blockUuid': 'b91b9d79-8659-4215-9c6c-3a3701a2af12'},
#   {'startTime': 63.71,
#    'endTime': 70.49,
#    'content': "Oui, effectivement, l'idée c'était, si ça vous va, l'agenda du coup juste que je vous propose effectivement, c'est peut-être juste",
#    'speaker': 'spk0',
#    'uuid': '5c83795c-81da-40a7-97f9-72234b1f83ac',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 70.49,
#    'endTime': 75.87,
#    'content': 'de faire un petit tour de table avant pour connaître un peu du coup le niveau de connaissance de Merlin et',
#    'speaker': 'spk0',
#    'uuid': '6f970567-d54d-4981-a516-88e3eb1aea0c',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 75.87,
#    'endTime': 81.87,
#    'content': 'de Arthur sur Modjo et connaître un peu exactement vos scopes et vos enjeux un peu personnels justement sur vos',
#    'speaker': 'spk0',
#    'uuid': '500f1f86-93c2-476d-8326-abf9b9ab4254',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 81.87,
#    'endTime': 88.61,
#    'content': "scopes de collectif chez RoundTable. Ensuite, évidemment, je vais faire un récap' des enjeux discutés avec Merlin lors de notre",
#    'speaker': 'spk0',
#    'uuid': '8042cc1d-6961-4539-8bff-ea2bce66cb17',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 88.61,
#    'endTime': 93.83,
#    'content': "précédent call et pour être sûr qu'on est tous les quatre alignés. Et évidemment, on va très vite s'immerger dans",
#    'speaker': 'spk0',
#    'uuid': '443ff530-a59a-40bf-b31c-a16b4ea40f9e',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 93.83,
#    'endTime': 100.45,
#    'content': 'Modjo pour que vous puissiez justement vous projeter et voir en quoi ça pourrait évidemment vous aider sur vos enjeux',
#    'speaker': 'spk0',
#    'uuid': '7a78f948-0bea-4e9d-a640-c34745f77d2b',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 100.45,
#    'endTime': 105.27,
#    'content': "à la fois côté sales et CSM et la fin de l'échange, ça serait du coup de planifier la suite.",
#    'speaker': 'spk0',
#    'uuid': '4498e38b-46dd-4965-a2e6-34a88e5da8af',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 105.65,
#    'endTime': 109.61,
#    'content': "Pour vous, l'idée, c'est d'avoir un peu de la visibilité du coup sur notre business model et pour moi, c'est",
#    'speaker': 'spk0',
#    'uuid': '8a28d77c-140c-4058-8d5c-37f4cfe82f8f',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 109.61,
#    'endTime': 115.87,
#    'content': 'pouvoir vous préparer une proposition tarifaire sur mesure et du coup la plus adaptée que ça soit en termes de',
#    'speaker': 'spk0',
#    'uuid': 'aa25cb1a-a1d1-4a5a-b9cc-5d26b090afff',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 115.87,
#    'endTime': 123.23,
#    'content': "nombre de licences. Est-ce que ça vous va comme comme comme Ouais, pas mal. L'échange. Ouais, OK, juste je peux",
#    'speaker': 'spk0',
#    'uuid': '3df181cd-0a9b-41e5-b509-0f73bf8490f6',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 123.23,
#    'endTime': 127.39,
#    'content': 'me permettre. Merlin et Arthur, est-ce que vous votre caméra fonctionne ou pas?',
#    'speaker': 'spk0',
#    'uuid': '83282514-3a09-4e21-836e-9384d64964b0',
#    'blockUuid': 'c2115dac-143c-4b87-b352-586a2b124f81'},
#   {'startTime': 128.3,
#    'endTime': 129.699,
#    'content': 'La caméra, je vais voir si elle fonctionne.',
#    'speaker': 'spk2',
#    'uuid': '94cd1f43-7623-479d-9dcf-6fbeb1da8cf5',
#    'blockUuid': 'ca434dd5-5431-4e4b-a3f3-dbfc649fc6bb'},
#   {'startTime': 131.82,
#    'endTime': 138.16,
#    'content': "OK, génial, trop cool. OK, ça va super. C'est sympa. Merci. Comme ça, plus qu'en plus, on est trois. Comme",
#    'speaker': 'spk0',
#    'uuid': '01538003-0a1f-41bc-9177-eb31629d4afe',
#    'blockUuid': 'd139b89e-46bf-4d00-997e-acfd5ac94ba1'},
#   {'startTime': 138.16,
#    'endTime': 143.2,
#    'content': "ça, je suis sûre. Si vous avez des questions, peut être aussi d'avoir le visuel. Juste avant du coup de",
#    'speaker': 'spk0',
#    'uuid': '8d154250-e5a8-4fe3-9cab-5ae76e2a8d67',
#    'blockUuid': 'd139b89e-46bf-4d00-997e-acfd5ac94ba1'},
#   {'startTime': 143.2,
#    'endTime': 149.08,
#    'content': 'commencer, je suis juste curieuse de savoir Arthur et du coup Merlin, quel est juste votre niveau de connaissance de',
#    'speaker': 'spk0',
#    'uuid': '9aa9543f-a882-4a2d-bae6-ce679ac80f51',
#    'blockUuid': 'd139b89e-46bf-4d00-997e-acfd5ac94ba1'},
#   {'startTime': 149.08,
#    'endTime': 152.9,
#    'content': "Modjo et qu'est ce que vous faites exactement chez RoundTable pour être sûr de présenter?",
#    'speaker': 'spk0',
#    'uuid': 'b4ec200a-c3f9-432c-97fa-3c7e86b1aa7a',
#    'blockUuid': 'd139b89e-46bf-4d00-997e-acfd5ac94ba1'},
#   {'startTime': 153.9,
#    'endTime': 160.42,
#    'content': "Et bien, on a radé un petit peu, donc c'était pour améliorer les performances commerciales, notamment grâce à l'IA. En",
#    'speaker': 'spk2',
#    'uuid': '7f4d1d6a-2967-493f-af2c-f3eb55322cf4',
#    'blockUuid': '582190e2-665f-408c-8d22-da14ee8e5a9c'},
#   {'startTime': 160.42,
#    'endTime': 166.95,
#    'content': "gros, c'est par rapport à un script, voir à quel degré de similitude on est par rapport au script. Et",
#    'speaker': 'spk2',
#    'uuid': 'b49a2c2c-0611-496f-ac5b-680001f1f5a4',
#    'blockUuid': '582190e2-665f-408c-8d22-da14ee8e5a9c'},
#   {'startTime': 166.95,
#    'endTime': 173.75,
#    'content': "donc, du coup, pour améliorer tout ce qui est nous, les relations clients après l'espèce commerciale et aussi l'espèce commerciale",
#    'speaker': 'spk2',
#    'uuid': '69eb13cc-5f63-4413-81c6-bbbc5939384a',
#    'blockUuid': '582190e2-665f-408c-8d22-da14ee8e5a9c'},
#   {'startTime': 173.75,
#    'endTime': 180.93,
#    'content': "pour avoir de nouveaux clients. Et du coup, quand je suis à RoundTable, l'équipe d'équipe customer success et on est",
#    'speaker': 'spk2',
#    'uuid': '72232d81-b7d0-48f3-b16c-7a4ebc8659b3',
#    'blockUuid': '582190e2-665f-408c-8d22-da14ee8e5a9c'},
#   {'startTime': 180.93,
#    'endTime': 183.49,
#    'content': 'sur la partie commerciale opérationnelle.',
#    'speaker': 'spk2',
#    'uuid': '4bd34dc7-27cf-405d-a9d7-1ffa8682d44b',
#    'blockUuid': '582190e2-665f-408c-8d22-da14ee8e5a9c'},
#   {'startTime': 183.75,
#    'endTime': 188.83,
#    'content': "Ouais, moi, je m'occupe de toute la partie opérationnelle. Je suis associé à Merlin qui est ici dans la call",
#    'speaker': 'spk1',
#    'uuid': '28ecce12-28e0-407c-b0d4-7c645e262446',
#    'blockUuid': 'd8e56efb-0a1d-45f6-811b-21fad5c14f63'},
#   {'startTime': 188.83,
#    'endTime': 194.97,
#    'content': "et connaissance de Modjo au même moment avec Merlin, puisque c'est on était dans la même réunion le jour où",
#    'speaker': 'spk1',
#    'uuid': 'e11db01b-ea95-461f-b163-f32b57a42823',
#    'blockUuid': 'd8e56efb-0a1d-45f6-811b-21fad5c14f63'},
#   {'startTime': 194.97,
#    'endTime': 199.83,
#    'content': 'on nous en a parlé. OK, donc voilà en synthèse.',
#    'speaker': 'spk1',
#    'uuid': 'bed43eea-8c42-41a7-8d79-e3b3ceb81767',
#    'blockUuid': 'd8e56efb-0a1d-45f6-811b-21fad5c14f63'},
#   {'startTime': 200.13,
#    'endTime': 204.47,
#    'content': 'OK, génial. Et du coup, justement, je crois que vous avez passé pas mal de temps ces dernières semaines ou',
#    'speaker': 'spk0',
#    'uuid': '00fbcc25-5c78-45b9-bdfa-dba9433e3d34',
#    'blockUuid': '4a2ffce5-5d51-461c-b4e8-153acaaf8c43'},
#   {'startTime': 204.47,
#    'endTime': 209.47,
#    'content': 'ces derniers jours chez Furnitures. Est ce que vous avez pu échanger avec SquareChair? Enfin, du coup, je crois que',
#    'speaker': 'spk0',
#    'uuid': 'ef8db478-08d4-4c52-8136-dc789fcef8ca',
#    'blockUuid': '4a2ffce5-5d51-461c-b4e8-153acaaf8c43'},
#   {'startTime': 209.67,
#    'endTime': 215.67,
#    'content': "c'est Lancelot et Lancelot. Oui, c'est ça. Lancelot, le CEO de SquareChair qui est dans le même incubateur que vous.",
#    'speaker': 'spk0',
#    'uuid': '257036a1-f186-4660-be1b-1515d85b06a9',
#    'blockUuid': '4a2ffce5-5d51-461c-b4e8-153acaaf8c43'},
#   {'startTime': 216.72,
#    'endTime': 221.92,
#    'content': "Non, on n'a pas parlé avec Lancelot spécialement sur ça, je t'avoue.",
#    'speaker': 'spk1',
#    'uuid': 'a1e87d75-9008-4d64-8f25-9ce66870c700',
#    'blockUuid': 'd68d25ff-560c-4371-860e-7ae29a1933b3'},
#   {'startTime': 222.62,
#    'endTime': 226.66,
#    'content': "OK, non, mais pas de problème. C'était par curiosité. OK, super clair.",
#    'speaker': 'spk0',
#    'uuid': '110772c7-1388-4bb4-8fb7-0edc9c2d02a9',
#    'blockUuid': '6336b4fc-fb35-40b7-98c1-ca3fc3f59591'},
#   {'startTime': 226.84,
#    'endTime': 230.96,
#    'content': 'Pour le savoir, on se gardera avec lui la semaine prochaine.',
#    'speaker': 'spk1',
#    'uuid': '1e2f3afd-6ccc-4f39-9f4a-d094428fb99d',
#    'blockUuid': 'b1f3691e-566b-4a0c-9f72-1b73f88a5092'},
#   {'startTime': 232.12,
#    'endTime': 237.48,
#    'content': "Écoutez, bah écoutez, avec plaisir, effectivement, ces équipes l'utilisent. Depuis, c'était mon premier client parce que moi, je suis à",
#    'speaker': 'spk0',
#    'uuid': '8e3f5cf9-1cb0-414c-8fd4-bcff1179c3b0',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 237.48,
#    'endTime': 245.06,
#    'content': "eux depuis trois mois maintenant et du coup, qui de mieux qu'un utilisateur Modjo pourra vous partager des insights. Donc,",
#    'speaker': 'spk0',
#    'uuid': '75024bb2-f574-4082-bb59-28b3083954a0',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 245.48,
#    'endTime': 251.04,
#    'content': "trop bien si vous le rencontrez. Du coup, pour récapituler ce qu'on s'est dit la dernière fois du coup avec",
#    'speaker': 'spk0',
#    'uuid': 'accf628f-ac87-4118-a11d-b28af8c348ab',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 251.04,
#    'endTime': 255.04,
#    'content': "Merlin et être sûr qu'on est sur le même niveau d'information. Moi, ce que j'ai compris, c'est que vous avez",
#    'speaker': 'spk0',
#    'uuid': 'c11bd649-2518-4827-bf68-1751d98e8d7e',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 255.04,
#    'endTime': 260.459,
#    'content': "des grosses ambitions de croissance. Aujourd'hui, vous avez des équipes principalement à Lyon, mais aussi un peu à Barcelone. Du",
#    'speaker': 'spk0',
#    'uuid': 'e6183a85-c69e-4aad-98c0-1da053ccf7d3',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 260.459,
#    'endTime': 266.0,
#    'content': "coup, il y a un enjeu de manager à distance pour être plus efficient. Vous avez des process aujourd'hui qui",
#    'speaker': 'spk0',
#    'uuid': '479f4501-37ea-447a-8464-ed6197fa9741',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 266.0,
#    'endTime': 269.1,
#    'content': 'est du coup, je reprends tes termes à Merlin. Je ne sais pas du tout de ma bouche, mais qui',
#    'speaker': 'spk0',
#    'uuid': '5dd7d214-9a92-437d-bd53-643af3f10250',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 269.1,
#    'endTime': 273.18,
#    'content': 'sont encore un peu brouillon. Et du coup, vous avez un enjeu de scalaire un peu sur cet aspect. Du',
#    'speaker': 'spk0',
#    'uuid': '258d9919-481d-4ab2-824d-d8e15f2218d7',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 273.18,
#    'endTime': 279.78,
#    'content': 'coup, formaliser plus les process pour aller chercher plus de méthodologie dans votre approche, que ça soit côté CSM et',
#    'speaker': 'spk0',
#    'uuid': 'fa4f06a7-d77a-4fcd-aa67-f0e34e796f9f',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 279.78,
#    'endTime': 286.56,
#    'content': "SAIS. Et du coup, quand vous parlez justement, quand on parle du coup de performance de croissance aujourd'hui, tu parlais",
#    'speaker': 'spk0',
#    'uuid': '09c21ed9-4d80-4b8c-bf2e-e1f89ba76b16',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 286.98,
#    'endTime': 292.84,
#    'content': "aujourd'hui de vos deux enjeux qui étaient augmentés drastiquement. Le MRR généré aujourd'hui, c'est un peu possible que ça soit",
#    'speaker': 'spk0',
#    'uuid': '55d9cf49-1132-41d5-9ab3-88974b14508d',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 292.84,
#    'endTime': 298.06,
#    'content': "sur la partie tunnel d'acquisition en termes de volume ou de panier moyen. Et c'était aussi de fidéliser du coup",
#    'speaker': 'spk0',
#    'uuid': '2396b9f9-b600-4a6d-ae67-4b3f2c5963f4',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 298.06,
#    'endTime': 305.06,
#    'content': "les clients côté CSM. Et pour ça, du coup, vous avez besoin d'un ou vous voudriez vous projeter sur un",
#    'speaker': 'spk0',
#    'uuid': 'b6296a09-f846-4795-982b-4f5bb4474357',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 305.06,
#    'endTime': 312.7,
#    'content': "outil d'intelligence conversationnelle. Du coup, côté sales, c'était vraiment pour l'aspect amélioration du discours, peut être test aussi de discours",
#    'speaker': 'spk0',
#    'uuid': '6c9be454-1cf2-454b-90ef-8828315cec7c',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 312.7,
#    'endTime': 320.14,
#    'content': 'en fonction de vos nouvelles offres pour aller peut être chercher justement un panier moyen plus important. Aussi, réponse aux',
#    'speaker': 'spk0',
#    'uuid': '819311bd-0227-4d20-8c13-549370792a27',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 320.14,
#    'endTime': 327.2,
#    'content': "objections et faire monter tout simplement vos recrues en compétences, parce que notamment, c'est des profils assez juniors et alternants.",
#    'speaker': 'spk0',
#    'uuid': '38e83877-eaeb-46c8-8ed4-9576b71f3276',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 327.52,
#    'endTime': 333.78,
#    'content': "Si je ne m'abuse. Et côté CSM, c'est aussi de challenger sur la partie plutôt démo avec démo et avoir",
#    'speaker': 'spk0',
#    'uuid': '0b623d0e-11f3-4879-98d6-ec4303902cd7',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 333.78,
#    'endTime': 341.6,
#    'content': "une expertise CSM vraiment encore plus poussée sur votre plateforme. Et on avait parlé d'un dernier sujet qui était moins",
#    'speaker': 'spk0',
#    'uuid': 'a70f1474-0e4b-4d2c-a8b1-5277d71818bc',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 341.6,
#    'endTime': 347.96,
#    'content': "lié à la performance, mais qui serait amené certainement à être challenge. C'était la partie productivité sur Hubspot. Merlin, tu",
#    'speaker': 'spk0',
#    'uuid': 'f29f9187-0072-4974-8a59-78480c0502ed',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 347.96,
#    'endTime': 356.22,
#    'content': "disais que que vous l'utilisiez peut être aujourd'hui à 30% et que 99% vous n'étais pas sûr à 99% que",
#    'speaker': 'spk0',
#    'uuid': '063dd636-4c20-459c-add0-f8c8286b4a6b',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 356.22,
#    'endTime': 362.58,
#    'content': "les notes dans les opportunités soient bien prises et qu'il y aurait potentiellement des sujets de passations d'information entre CSM.",
#    'speaker': 'spk0',
#    'uuid': 'ab73fc39-b958-4659-b6fc-4c9fcf90b9d2',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 362.98,
#    'endTime': 368.24,
#    'content': "Et du coup, c'est tout l'idée de Modjo d'un outil global, c'est de vous aider sur ses parties performance et",
#    'speaker': 'spk0',
#    'uuid': '7876b6e3-002e-4171-a40e-d30ce0bc29e5',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 368.24,
#    'endTime': 373.64,
#    'content': "productivité. Est ce qu'on est toujours aligné? Est ce qu'il y a d'autres points que vous vouliez voir et qui",
#    'speaker': 'spk0',
#    'uuid': '0572cfb8-1a46-406e-97ea-b3b4eb541142',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 373.64,
#    'endTime': 375.5,
#    'content': 'sera important pour vous pour la démo?',
#    'speaker': 'spk0',
#    'uuid': '9a950e0d-4b81-493e-b680-3c2a11c5553b',
#    'blockUuid': '2b0b523f-348b-4153-b362-111b04516c93'},
#   {'startTime': 376.96,
#    'endTime': 378.66,
#    'content': 'Non, tu as très bien résumé.',
#    'speaker': 'spk2',
#    'uuid': '63387315-e2a9-41a4-9980-78e0ffc27b52',
#    'blockUuid': '965c3da7-5ca4-48dd-87af-9fd2d574d7e7'},
#   {'startTime': 379.31,
#    'endTime': 385.83,
#    'content': "OK, génial. Et qu'est ce que je veux dire? Oui, non, dernier dernier aspect. Du coup, on avait à parler",
#    'speaker': 'spk0',
#    'uuid': 'e66c637a-21a3-4ff8-a3b4-63cc1c6abc7b',
#    'blockUuid': '1cc4cfbd-d42d-4081-b531-0c108ce18704'},
#   {'startTime': 385.83,
#    'endTime': 391.09,
#    'content': "un tout petit peu moins de ça la dernière fois, Merlin, j'étais curieuse de savoir aujourd'hui concrètement qu'est ce que",
#    'speaker': 'spk0',
#    'uuid': '2b16c48f-2f91-4ded-9f2f-2861a7a71faf',
#    'blockUuid': '1cc4cfbd-d42d-4081-b531-0c108ce18704'},
#   {'startTime': 391.09,
#    'endTime': 397.15,
#    'content': 'vous mettez en place comme routine de coaching à proprement parler, puisque du coup, vous aimeriez bien challenger sur le',
#    'speaker': 'spk0',
#    'uuid': 'f8812e9d-eba9-4e6e-8108-b45dc5ece117',
#    'blockUuid': '1cc4cfbd-d42d-4081-b531-0c108ce18704'},
#   {'startTime': 397.15,
#    'endTime': 402.59,
#    'content': "discours, sur les objections. Mais du coup, à date, sans un Modjo sans un outil pour vous y aider, qu'est",
#    'speaker': 'spk0',
#    'uuid': 'ed91ce61-43b5-4fc1-a958-6ea9b581b559',
#    'blockUuid': '1cc4cfbd-d42d-4081-b531-0c108ce18704'},
#   {'startTime': 402.59,
#    'endTime': 403.79,
#    'content': 'ce qui est mis en place par les managers?',
#    'speaker': 'spk0',
#    'uuid': '60374643-f602-41a2-840c-7bd79a68b2cc',
#    'blockUuid': '1cc4cfbd-d42d-4081-b531-0c108ce18704'},
#   {'startTime': 405.19,
#    'endTime': 412.51,
#    'content': "Pas grand chose. Ce n'est pas le problème. Donc, sur la partie CSM, on met en place depuis un mois,",
#    'speaker': 'spk2',
#    'uuid': 'dbd707e3-80ab-45ce-812c-3bb60b75889e',
#    'blockUuid': '9424af96-7670-482d-b07c-571dd54b9cc4'},
#   {'startTime': 412.51,
#    'endTime': 421.51,
#    'content': "un mois et demi des tests de pitch juste sur la partie pitch démo fonctionnel. Donc, on faut qu'on garde",
#    'speaker': 'spk2',
#    'uuid': '0e7be855-f716-45b4-8ef0-cfb535c75623',
#    'blockUuid': '9424af96-7670-482d-b07c-571dd54b9cc4'},
#   {'startTime': 421.51,
#    'endTime': 426.47,
#    'content': 'justement cette vélocité sur ces tests.',
#    'speaker': 'spk2',
#    'uuid': '250efa13-1920-42e7-aed8-d1baee23ea78',
#    'blockUuid': '9424af96-7670-482d-b07c-571dd54b9cc4'},
#   {'startTime': 428.59,
#    'endTime': 432.23,
#    'content': "Et c'est tout ce que l'on fait, en tout cas sur la partie CSM aujourd'hui. Je pense qu'il y a",
#    'speaker': 'spk2',
#    'uuid': 'cd5e8477-366a-415f-9a51-655dd24ff11e',
#    'blockUuid': 'd0aad5ad-4db4-4a91-940c-72b31f08b651'},
#   {'startTime': 432.63,
#    'endTime': 439.25,
#    'content': "d'autres éléments à prendre en compte aussi sur la qualité des process qui sont traités. Et sur la partie sales,",
#    'speaker': 'spk2',
#    'uuid': '2319da42-5588-4b0f-92fa-09968698b939',
#    'blockUuid': 'd0aad5ad-4db4-4a91-940c-72b31f08b651'},
#   {'startTime': 439.85,
#    'endTime': 444.05,
#    'content': "tu peux dire deux mots, mais voilà, je sais qu'il y a des écoutes pendant un moment qui étaient faites",
#    'speaker': 'spk2',
#    'uuid': '69d29228-225b-4504-8bb8-e3b59790c2ff',
#    'blockUuid': 'd0aad5ad-4db4-4a91-940c-72b31f08b651'},
#   {'startTime': 444.05,
#    'endTime': 449.69,
#    'content': 'sur Ringover, du double écoute ou même après coup, mais par quelque chose de régulièrement.',
#    'speaker': 'spk2',
#    'uuid': '43b5c55e-8714-4e3a-b7dd-4e7032170f91',
#    'blockUuid': 'd0aad5ad-4db4-4a91-940c-72b31f08b651'},
#   {'startTime': 450.13,
#    'endTime': 457.85,
#    'content': "On fait principalement des workshops. OK. Des workshops en règle générale, c'est une fois par mois.",
#    'speaker': 'spk1',
#    'uuid': '6755453c-dbc1-4396-abed-bb87c6958e36',
#    'blockUuid': 'ecac5254-bdbe-4fd3-9853-2191f0bd1511'},
#   {'startTime': 460.43,
#    'endTime': 464.51,
#    'content': "Ça se matérialise comment? Concrètement, ces workshops, c'est quoi l'objectif?",
#    'speaker': 'spk0',
#    'uuid': '4949aa04-dc66-405f-95ed-b321c1b0146d',
#    'blockUuid': '89e3f935-426f-487b-8039-78549d2029e0'},
#   {'startTime': 464.79,
#    'endTime': 471.47,
#    'content': "C'est en gros, moi, je demande, donc il y a des ateliers à Ringover qui nous permettent de les",
#    'speaker': 'spk1',
#    'uuid': '61b143b3-93b2-4d05-8ac4-cae3c8291b13',
#    'blockUuid': '9bd49d07-96ef-4fad-a290-5d488451a3f7'},
#   {'startTime': 471.47,
#    'endTime': 471.89,
#    'content': 'écouter.',
#    'speaker': 'spk1',
#    'uuid': '20d4bbb2-ece5-4aaa-a551-d76bf3857cc1',
#    'blockUuid': '9bd49d07-96ef-4fad-a290-5d488451a3f7'},
#   {'startTime': 474.01,
#    'endTime': 478.37,
#    'content': "Clairement, il n'y a pas de double écoute dans le sens où on n'est à personne qui a le temps",
#    'speaker': 'spk1',
#    'uuid': '075f508b-4ba2-4f2b-a20c-7017ce9a907e',
#    'blockUuid': 'a80dcd5a-9dc5-4e8a-9230-04f618e5d7c0'},
#   {'startTime': 478.37,
#    'endTime': 481.17,
#    'content': "de faire de la double écoute. En tout cas, moi, je n'ai pas le temps de faire la double écoute.",
#    'speaker': 'spk1',
#    'uuid': '9c45a0e7-d23c-432c-a64f-09b19394ec48',
#    'blockUuid': 'a80dcd5a-9dc5-4e8a-9230-04f618e5d7c0'},
#   {'startTime': 481.47,
#    'endTime': 488.89,
#    'content': "Donc, on demande celle de venir avec d'enregistrer des bad calls et des good calls en gros, au nombre de",
#    'speaker': 'spk1',
#    'uuid': 'a0dded21-0a71-4541-8c55-fc12e8beb9fe',
#    'blockUuid': 'a80dcd5a-9dc5-4e8a-9230-04f618e5d7c0'},
#   {'startTime': 488.89,
#    'endTime': 493.53,
#    'content': 'cinq par mois. Et ils viennent avec en atelier.',
#    'speaker': 'spk1',
#    'uuid': '4ec6911d-a9c0-44c8-96d6-b1bc7f099885',
#    'blockUuid': 'a80dcd5a-9dc5-4e8a-9230-04f618e5d7c0'},
#   {'startTime': 493.69,
#    'endTime': 494.01,
#    'content': 'Ouais.',
#    'speaker': 'spk0',
#    'uuid': 'd9e33a1e-d659-41f7-a58f-fb9b2b644b76',
#    'blockUuid': '868e749d-2021-4949-b659-66415e18c608'},
#   {'startTime': 494.99,
#    'endTime': 507.83,
#    'content': "Workshop. On travaille comme ça, notamment beaucoup. Le traitement des objections. Voilà, c'est aujourd'hui, c'est la méthode où qui est",
#    'speaker': 'spk1',
#    'uuid': 'c9ffb3eb-106e-4e35-b49d-5bc2fac7f9f2',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 507.83,
#    'endTime': 516.61,
#    'content': "qui est qui est faite côté sales. Donc, c'est une fois par mois. Sachant que ça, effectivement, ça c'est là",
#    'speaker': 'spk1',
#    'uuid': '573904ee-a605-49e2-ac39-2e3baf633658',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 516.61,
#    'endTime': 521.53,
#    'content': "depuis septembre. Ça s'est arrêté puisqu'on a eu pas mal de nouvelles recrues qui sont rentrées, etc. Donc, en gros,",
#    'speaker': 'spk1',
#    'uuid': 'aaa7573a-e03d-4dbf-9b84-6336b515be74',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 522.15,
#    'endTime': 528.73,
#    'content': "il y a une petite pause sur septembre, octobre. Le temps de remettre l'équipe à flot. Donc là, ça va",
#    'speaker': 'spk1',
#    'uuid': '3ca7644c-b66c-44e5-bdd6-64ed2452169f',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 528.73,
#    'endTime': 535.99,
#    'content': "reprendre. On a arrêté, je crois, le dernier, c'était en juillet, début juillet, en été. Donc voilà, septembre, octobre, il",
#    'speaker': 'spk1',
#    'uuid': '8393081d-f4e0-428f-ad19-6f5bae4d41c5',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 536.03,
#    'endTime': 543.39,
#    'content': "n'y en a pas. Là, on va reprendre en novembre. Sachant que nous, les nouveaux sales, quand ils rentrent, on",
#    'speaker': 'spk1',
#    'uuid': '8a7c71a3-12b1-4384-85b0-f7f096d480ac',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 543.39,
#    'endTime': 549.83,
#    'content': "les fait d'abord travailler sur du pur call à froid. Donc, du pur call à froid, on ne les fait",
#    'speaker': 'spk1',
#    'uuid': '52f69e46-7daa-4be9-babe-c5ebd71fb7c8',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 549.83,
#    'endTime': 559.37,
#    'content': 'pas travailler sur des pros spéciaux de notre CRM. On travaille sur le script, le discours, on va dire en',
#    'speaker': 'spk1',
#    'uuid': '34ae114b-d862-4254-8213-9d8cc882964a',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 559.37,
#    'endTime': 565.83,
#    'content': 'condition dure pour être potentiellement plus efficace en conditions plus clémentes.',
#    'speaker': 'spk1',
#    'uuid': '49f2a69f-6061-4c05-ae7f-6ce378337e84',
#    'blockUuid': '8e9f3a1e-6b9b-4dc4-976e-3a45ebf96674'},
#   {'startTime': 568.84,
#    'endTime': 577.54,
#    'content': "Et au niveau du script, tout est scripté, j'allais dire, en fonction des différents cas, que ce soit du prospect",
#    'speaker': 'spk1',
#    'uuid': '652217c2-9504-4f45-9a52-f02786183662',
#    'blockUuid': 'fe6d4cc9-fbc3-43a6-84fc-5e96ab61125a'},
#   {'startTime': 577.54,
#    'endTime': 587.18,
#    'content': "froid au prospect. Il y a deux doigts de signer et qui a déjà fait une période d'essai. Donc, on",
#    'speaker': 'spk1',
#    'uuid': '6a6aec14-1911-46e1-9edd-42c68481483c',
#    'blockUuid': 'fe6d4cc9-fbc3-43a6-84fc-5e96ab61125a'},
#   {'startTime': 587.18,
#    'endTime': 598.12,
#    'content': "a à peu près tout scripté. Néanmoins, on n'est pas dans une logique de... Moi, j'ai tendance à dire aux",
#    'speaker': 'spk1',
#    'uuid': '74b8abf1-4930-4431-80f9-21ee76b8381b',
#    'blockUuid': 'fe6d4cc9-fbc3-43a6-84fc-5e96ab61125a'},
#   {'startTime': 598.12,
#    'endTime': 606.06,
#    'content': "sales que l'important, c'est qu'ils sont en capacité d'avoir la profondeur de traiter les objections et la résilience de s'accrocher.",
#    'speaker': 'spk1',
#    'uuid': '86bc32a0-fd7e-4102-bd59-73dbe943472c',
#    'blockUuid': 'fe6d4cc9-fbc3-43a6-84fc-5e96ab61125a'},
#   {'startTime': 606.62,
#    'endTime': 613.06,
#    'content': "Après, effectivement, ça reste de l'impro en fonction de qui tu es en face de toi. Donc,",
#    'speaker': 'spk1',
#    'uuid': 'b403fdf3-7ef3-45c1-8d6a-b1274fc97c0c',
#    'blockUuid': 'fe6d4cc9-fbc3-43a6-84fc-5e96ab61125a'},
#   {'startTime': 615.12,
#    'endTime': 622.82,
#    'content': "tu ne peux pas avoir un discours de robot, même si au début, tu l'as un petit peu sur les",
#    'speaker': 'spk1',
#    'uuid': 'e56b6a0f-e297-42a0-9fe2-eba972fb792f',
#    'blockUuid': 'c2e033e2-c356-4454-8665-217674e56924'},
#   {'startTime': 622.82,
#    'endTime': 627.74,
#    'content': "trois et six premiers mois. Ils sont un peu en mode robot et c'est normal. Et j'allais dire, c'est même",
#    'speaker': 'spk1',
#    'uuid': '2cd43685-7b7e-47b4-81c5-dbd429124360',
#    'blockUuid': 'c2e033e2-c356-4454-8665-217674e56924'},
#   {'startTime': 627.74,
#    'endTime': 633.1,
#    'content': "les robots qui sont en mode robot, parce que ça veut dire qu'ils suivent le script. Néanmoins, par la suite,",
#    'speaker': 'spk1',
#    'uuid': 'e6c1f80c-518e-4c4b-8a14-214f922f222b',
#    'blockUuid': 'c2e033e2-c356-4454-8665-217674e56924'},
#   {'startTime': 633.18,
#    'endTime': 636.08,
#    'content': "ce n'est pas le robot qui signe. C'est lui.",
#    'speaker': 'spk1',
#    'uuid': '7f378a56-833c-4586-8bfe-025a3dd81452',
#    'blockUuid': 'c2e033e2-c356-4454-8665-217674e56924'},
#   {'startTime': 638.44,
#    'endTime': 644.72,
#    'content': 'Et du coup, juste petite question. Que ça soit sur les sales qui ont déjà eu leur phase de ramp-up',
#    'speaker': 'spk0',
#    'uuid': 'f03c7967-5f25-405a-962b-3a02c3763494',
#    'blockUuid': '6f8cfd75-d1f2-419e-93ed-55b8878aa3de'},
#   {'startTime': 644.72,
#    'endTime': 654.98,
#    'content': "ou les junior aujourd'hui, donc, effectivement, ils testent le pitch, ils répondent à des objections. Concrètement, là, tu fais comment",
#    'speaker': 'spk0',
#    'uuid': '38e4f58d-3f34-4433-abdf-0e7da5e21045',
#    'blockUuid': '6f8cfd75-d1f2-419e-93ed-55b8878aa3de'},
#   {'startTime': 654.98,
#    'endTime': 660.1,
#    'content': "juste pour t'assurer qu'ils répondent bien? Parce qu'il y a les workshops que vous mettiez en place. Mais aujourd'hui, à",
#    'speaker': 'spk0',
#    'uuid': '9094697b-572d-4c8c-84ea-dc0ab94260ec',
#    'blockUuid': '6f8cfd75-d1f2-419e-93ed-55b8878aa3de'},
#   {'startTime': 660.1,
#    'endTime': 663.8,
#    'content': 'date, tu fais comment? Tu es sur le flot, tu les écoutes comme ça, tu fais de la réécoute via',
#    'speaker': 'spk0',
#    'uuid': '1cfb0dc6-beca-4ca5-ae47-a5cf91ec2adf',
#    'blockUuid': '6f8cfd75-d1f2-419e-93ed-55b8878aa3de'},
#   {'startTime': 664.02,
#    'endTime': 667.44,
#    'content': 'ring-over. Comment tu les accompagnes dans leur montée en compétence?',
#    'speaker': 'spk0',
#    'uuid': '3e391eb2-969a-4a77-aea4-f66fec2053f2',
#    'blockUuid': '6f8cfd75-d1f2-419e-93ed-55b8878aa3de'},
#   {'startTime': 668.26,
#    'endTime': 676.04,
#    'content': "Nous, en gros, on a un suivi hebdo. Le lundi, on a une réunion d'équipe. Le vendredi, on a une",
#    'speaker': 'spk1',
#    'uuid': '36d23804-9514-4a3c-80e1-5d62be881fe6',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 676.04,
#    'endTime': 687.22,
#    'content': "réunion individuelle. En réunion individuelle, ils ont pris l'habitude de venir avec leur, entre guillemets, avec leurs problématiques, leurs objections.",
#    'speaker': 'spk1',
#    'uuid': '6309b318-e876-4353-8ecb-dfc1dc3c1b40',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 687.66,
#    'endTime': 698.48,
#    'content': "Ils viennent souvent me demander des arguments. Effectivement, à l'instant T maintenant, alors avant, ce n'était pas obligatoirement le cas",
#    'speaker': 'spk1',
#    'uuid': '902c0f0d-d6e7-400d-b34a-89aea5ea5d60',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 698.48,
#    'endTime': 706.45,
#    'content': "avant l'été, mais maintenant, on a la chance d'avoir une sorte d'open space sur lequel moi, je peux entendre les",
#    'speaker': 'spk1',
#    'uuid': '2b3d3322-969c-4305-a805-07705b54123e',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 706.45,
#    'endTime': 717.41,
#    'content': "appels. Donc, ça me permet d'intervenir quand je suis là pour éventuellement donner des petits des petits feedbacks. Voilà des",
#    'speaker': 'spk1',
#    'uuid': '43d98234-fd24-4d0e-83b5-2a98f934ea3c',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 717.41,
#    'endTime': 724.59,
#    'content': "tips. Mais jusqu'alors, on va dire que jusqu'alors, on était sur un modèle où, comme je te dis, il n'y",
#    'speaker': 'spk1',
#    'uuid': 'bb947e9f-8233-4af6-84c8-8664f5a5c3e8',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 724.59,
#    'endTime': 735.59,
#    'content': "a pas de réécoute à part le workshop. Il n'y a pas de réécoute. Après, les celles chez nous ont",
#    'speaker': 'spk1',
#    'uuid': 'ed00cf49-9e40-4cc5-a614-636e76a5ec01',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 735.59,
#    'endTime': 742.59,
#    'content': 'participé pour la plupart, ou en tout cas, ont au moins participé une fois un salon. Salon, ça veut dire',
#    'speaker': 'spk1',
#    'uuid': '0212ebac-0733-4e2a-8ddb-093a9cc33d4d',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 742.59,
#    'endTime': 747.09,
#    'content': "que, voilà, j'allais dire, il n'y a pas derrière un téléphone, tu ne peux pas te cacher, tu es face",
#    'speaker': 'spk1',
#    'uuid': '44a8dde1-a855-4be7-ac47-7d57e2e45e08',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 747.09,
#    'endTime': 754.13,
#    'content': "à la personne et tu dois tu dois débiter. Et aujourd'hui, tous les sales, on va dire, ont participé au",
#    'speaker': 'spk1',
#    'uuid': '0bb20f7f-af75-44a1-8b8d-35ce30ac1799',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 754.13,
#    'endTime': 761.33,
#    'content': 'moins à un salon et ils ont déjà conclu des ventes. Donc, on a quand même un niveau de performance',
#    'speaker': 'spk1',
#    'uuid': 'ce4ee0bf-2853-4463-9b5f-44defcf236c0',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 761.33,
#    'endTime': 762.53,
#    'content': 'minimum',
#    'speaker': 'spk1',
#    'uuid': '7bc3b25c-13f7-4372-bcc0-605540b4401b',
#    'blockUuid': '7be9fef9-d65c-49d7-9650-824db1f750ec'},
#   {'startTime': 764.95,
#    'endTime': 775.37,
#    'content': "qu'on sait être capable de tenir. Le problème, c'est la recherche de la... Le problème, c'est de travailler sur l'amélioration",
#    'speaker': 'spk1',
#    'uuid': 'c0ab7e1f-b6d9-4094-8d80-cd2c6340bb37',
#    'blockUuid': '547a2afa-3240-4635-8fcf-f0eaa7c96053'},
#   {'startTime': 775.37,
#    'endTime': 785.33,
#    'content': "de la performance. C'est vraiment ça. C'est augmenter le nombre de conversions par mois, le nombre de closures, c'est le",
#    'speaker': 'spk1',
#    'uuid': '7d4d0521-e97a-48bb-8fe3-3125aa2e75fe',
#    'blockUuid': '547a2afa-3240-4635-8fcf-f0eaa7c96053'},
#   {'startTime': 785.33,
#    'endTime': 785.85,
#    'content': 'sujet.',
#    'speaker': 'spk1',
#    'uuid': '1471381d-f4bf-4cf3-a824-4e1e198fdc59',
#    'blockUuid': '547a2afa-3240-4635-8fcf-f0eaa7c96053'},
#   {'startTime': 787.39,
#    'endTime': 792.87,
#    'content': "Tu vas aller chercher combien en taux de conversion aujourd'hui ? Pardon ? Tu vas aller chercher combien en taux",
#    'speaker': 'spk0',
#    'uuid': 'b4263e13-077c-47c5-9e38-8b9b0129a8db',
#    'blockUuid': '9e8fbd7a-819e-46ec-9058-52f2b23369b4'},
#   {'startTime': 792.87,
#    'endTime': 796.87,
#    'content': "de conversion aujourd'hui ? Enfin, vous êtes à combien en taux de conversion et tu vas aller chercher combien dans",
#    'speaker': 'spk0',
#    'uuid': 'c38ad2de-ab3e-4463-b652-a2752a6dbb57',
#    'blockUuid': '9e8fbd7a-819e-46ec-9058-52f2b23369b4'},
#   {'startTime': 797.01,
#    'endTime': 798.36,
#    'content': "l'idéal ?",
#    'speaker': 'spk0',
#    'uuid': '882197ed-9bcf-4a50-af29-b791330c5fb7',
#    'blockUuid': '9e8fbd7a-819e-46ec-9058-52f2b23369b4'},
#   {'startTime': 798.36,
#    'endTime': 810.69,
#    'content': "En gros, aujourd'hui, on veut aller... On a nous un gros top service qui est la customize, la marque blanche",
#    'speaker': 'spk1',
#    'uuid': 'b7150740-eb96-4cff-ba4e-0ac7d8696ad6',
#    'blockUuid': '9877124e-98d6-4399-bea0-8b040d3a0739'},
#   {'startTime': 810.69,
#    'endTime': 812.93,
#    'content': 'chez nous. Si tu regardes un petit peu...',
#    'speaker': 'spk1',
#    'uuid': '64d66b75-84de-4fd3-a014-8c5fe002d45d',
#    'blockUuid': '9877124e-98d6-4399-bea0-8b040d3a0739'},
#   {'startTime': 812.93,
#    'endTime': 815.61,
#    'content': "Ici, j'ai regardé votre site à 139 euros.",
#    'speaker': 'spk0',
#    'uuid': 'b1b98292-e56d-45d6-888f-7f94e967911c',
#    'blockUuid': '8d279764-a720-4d3b-bab4-1370e7a14142'},
#   {'startTime': 816.35,
#    'endTime': 826.41,
#    'content': "Voilà, notre objectif, c'est d'être tous les mois au moins 10. Donc, ça, c'est vraiment notre objectif d'être à 10.",
#    'speaker': 'spk1',
#    'uuid': '5db0348a-f679-41ec-870b-6546e050a823',
#    'blockUuid': '1a0664fd-cc0e-4ab7-bfc8-58771e4937af'},
#   {'startTime': 826.57,
#    'endTime': 828.59,
#    'content': "Et aujourd'hui, vous êtes à combien ?",
#    'speaker': 'spk0',
#    'uuid': 'a9df17c7-8269-45ab-87d5-7cdbcab1f798',
#    'blockUuid': 'ce12df91-f517-449c-9bb4-d81530ac4c2e'},
#   {'startTime': 829.07,
#    'endTime': 835.69,
#    'content': "Aujourd'hui, on tourne entre 6 et 8 en gros. Donc, on est un cran en dessous. Ce mois-ci, on va aller",
#    'speaker': 'spk1',
#    'uuid': 'ad93c3f7-545d-4ff4-9cef-615b49e9a697',
#    'blockUuid': '58a6db0b-e936-4d31-abbf-a9691bd6c26e'},
#   {'startTime': 835.69,
#    'endTime': 837.81,
#    'content': "faire les 10 parce qu'on sort d'un salon.",
#    'speaker': 'spk1',
#    'uuid': '7e402af2-974f-4d2a-8f86-705e50fb15d7',
#    'blockUuid': '58a6db0b-e936-4d31-abbf-a9691bd6c26e'},
#   {'startTime': 840.69,
#    'endTime': 848.67,
#    'content': "On va dire que le taf a été bien fait, mais dans la récurrence... Et d'ailleurs, on a une performance",
#    'speaker': 'spk1',
#    'uuid': '362d3cb1-991d-48c4-968f-108b4759e74f',
#    'blockUuid': 'be814bef-e8bc-403d-92d0-5122ee79350f'},
#   {'startTime': 848.67,
#    'endTime': 854.51,
#    'content': 'assez ératique dans le sens où il y a des mois, je ne sais plus, en juin, on en fait',
#    'speaker': 'spk1',
#    'uuid': '44ed9d8b-756f-4702-9efc-010fca206271',
#    'blockUuid': 'be814bef-e8bc-403d-92d0-5122ee79350f'},
#   {'startTime': 854.51,
#    'endTime': 859.67,
#    'content': '5 et en juillet, par exemple, on en fait 10. Donc, en fait, on est vraiment comptable au niveau de',
#    'speaker': 'spk1',
#    'uuid': '140a49b5-4c5b-4ead-9bd5-8fbd9498e307',
#    'blockUuid': 'be814bef-e8bc-403d-92d0-5122ee79350f'},
#   {'startTime': 859.67,
#    'endTime': 872.19,
#    'content': "la perfo. C'est ça qui est le plus frustrant. C'est là qu'on aimerait avoir un outil qui potentiellement nous permette",
#    'speaker': 'spk1',
#    'uuid': 'b1bc250f-646d-4798-aaff-c652eccb30c2',
#    'blockUuid': 'be814bef-e8bc-403d-92d0-5122ee79350f'},
#   {'startTime': 872.91,
#    'endTime': 876.85,
#    'content': "d'améliorer de manière continue la performance des sales.",
#    'speaker': 'spk1',
#    'uuid': '70110fad-1e7f-46d5-9568-e86e69e63f4a',
#    'blockUuid': 'be814bef-e8bc-403d-92d0-5122ee79350f'},
#   {'startTime': 878.07,
#    'endTime': 883.43,
#    'content': "En termes de chiffre d'affaires ou de MRR ou ARR à aller chercher sur l'année, tu as une idée de",
#    'speaker': 'spk0',
#    'uuid': '534542e0-f9e7-40a6-a40c-6b07709135a1',
#    'blockUuid': '1f8a2d5c-060f-451e-b880-70c1dd6f35e2'},
#   {'startTime': 883.43,
#    'endTime': 891.09,
#    'content': "ce que ça représenterait d'augmenter justement cette performance qui est aujourd'hui pas forcément stable de moins en moins.",
#    'speaker': 'spk0',
#    'uuid': '401c87b0-5f43-4c62-93ed-7139d27069ca',
#    'blockUuid': '1f8a2d5c-060f-451e-b880-70c1dd6f35e2'},
#   {'startTime': 892.71,
#    'endTime': 896.91,
#    'content': "C'est-à-dire le fait d'atteindre l'objectif, qu'est-ce que ça apporte ton MRR en plus ?",
#    'speaker': 'spk1',
#    'uuid': '5a34634c-c513-4818-95ea-17309153d15c',
#    'blockUuid': '9f390029-958b-4be1-8eca-4a8438febf28'},
#   {'startTime': 897.37,
#    'endTime': 904.19,
#    'content': "Aujourd'hui, c'est quoi ton objectif ? C'est quoi le manque à gagner en termes d'ARR que tu as en visibilité",
#    'speaker': 'spk0',
#    'uuid': 'a4ab242a-fe30-458b-b3d3-285945f2996e',
#    'blockUuid': 'bdb5f6b9-2c36-4138-9704-a0440ba716d4'},
#   {'startTime': 904.19,
#    'endTime': 906.51,
#    'content': "le fait de ne pas être à 10 aujourd'hui ?",
#    'speaker': 'spk0',
#    'uuid': '6bef90ec-f913-4e04-9004-a94f7684352c',
#    'blockUuid': 'bdb5f6b9-2c36-4138-9704-a0440ba716d4'},
#   {'startTime': 906.51,
#    'endTime': 909.09,
#    'content': 'Tu peux parler de son MRR.',
#    'speaker': 'spk1',
#    'uuid': '8d4c9a87-055b-4d1d-9e79-fb77727962aa',
#    'blockUuid': '3a82c51c-591e-421b-85ce-3e40f25d510f'},
#   {'startTime': 909.77,
#    'endTime': 910.45,
#    'content': 'MRR, oui.',
#    'speaker': 'spk0',
#    'uuid': 'e7cfa41d-b4df-4dbe-8b10-0b06de299fdc',
#    'blockUuid': '1324b002-62db-4189-b241-5b898d171ecf'},
#   {'startTime': 911.43,
#    'endTime': 918.03,
#    'content': "C'est un jeu galère quand il met son niveau. Là, c'est simple. On a fait 7 marques blanches en septembre.",
#    'speaker': 'spk1',
#    'uuid': 'd16723ba-5d81-455d-b7ce-cc7eaf1ca438',
#    'blockUuid': '7dcddbe1-a593-4578-a17e-0417ca28b984'},
#   {'startTime': 919.31,
#    'endTime': 927.23,
#    'content': "L'objectif, c'est 10. C'est à peu près 500 euros par mois la marque blanche. C'est 1500 euros mensuels qui tournent",
#    'speaker': 'spk1',
#    'uuid': '175e77dc-1f82-42be-8d39-306e0764f1fe',
#    'blockUuid': '7dcddbe1-a593-4578-a17e-0417ca28b984'},
#   {'startTime': 927.23,
#    'endTime': 927.85,
#    'content': 'par an.',
#    'speaker': 'spk1',
#    'uuid': '8accb014-0e77-4de9-bd7f-2c798d965dab',
#    'blockUuid': '7dcddbe1-a593-4578-a17e-0417ca28b984'},
#   {'startTime': 928.51,
#    'endTime': 934.96,
#    'content': "Et du coup, ça c'est par sales ? Pour l'équipe ? Au global ?",
#    'speaker': 'spk0',
#    'uuid': '3441adea-b824-4d55-8441-149e457e92d1',
#    'blockUuid': '13b6f84b-73c4-4de0-9841-3a54ede1f4f7'},
#   {'startTime': 936.24,
#    'endTime': 944.6,
#    'content': "Le sales doit faire 3 marques blanches par mois. Si on voudrait qu'ils soient au niveau, il faut qu'ils fassent",
#    'speaker': 'spk1',
#    'uuid': 'd83655fa-043f-487a-80e2-db6e33be8a03',
#    'blockUuid': 'dd6d4f8e-08a5-424e-a7fb-b925ed51c063'},
#   {'startTime': 944.6,
#    'endTime': 950.56,
#    'content': "3 marques blanches par mois. Normalement, s'ils en font 3 par mois, sachant que moi également j'en fais aussi, ça",
#    'speaker': 'spk1',
#    'uuid': '9d2a78aa-5d76-4dea-bc53-d1efd0007b6a',
#    'blockUuid': 'dd6d4f8e-08a5-424e-a7fb-b925ed51c063'},
#   {'startTime': 950.56,
#    'endTime': 951.88,
#    'content': 'en fait 12 tout de moins.',
#    'speaker': 'spk1',
#    'uuid': 'af06800d-994c-456f-a319-d225f43666a8',
#    'blockUuid': 'dd6d4f8e-08a5-424e-a7fb-b925ed51c063'},
#   {'startTime': 953.2,
#    'endTime': 959.72,
#    'content': "Attention, ça c'est nos chiffres aujourd'hui. Les chiffres de TAM4, c'est pas ce que ça donne. On leur fait le",
#    'speaker': 'spk2',
#    'uuid': '1b22170e-bc4a-4c89-af73-1e6a565e084d',
#    'blockUuid': '4ff48764-e43a-4079-894a-da4b2c2b326c'},
#   {'startTime': 959.72,
#    'endTime': 961.36,
#    'content': 'calcul avec Samuel pas plus tard que ce matin.',
#    'speaker': 'spk2',
#    'uuid': '709d903d-afd7-4c39-8bb1-b28ec945a6b2',
#    'blockUuid': '4ff48764-e43a-4079-894a-da4b2c2b326c'},
#   {'startTime': 961.92,
#    'endTime': 963.8,
#    'content': 'Ça serait plutôt combien du coup ?',
#    'speaker': 'spk0',
#    'uuid': '36c57e32-3517-4c8d-b2cc-ed4fdbac9298',
#    'blockUuid': '5a811e10-e512-4e3f-970a-115410604868'},
#   {'startTime': 963.8,
#    'endTime': 968.18,
#    'content': 'Là, on serait plutôt à nombre de marques blanches',
#    'speaker': 'spk2',
#    'uuid': 'd80cbd43-6851-4b32-8eba-96cc0f669be9',
#    'blockUuid': 'bbb80692-8bc6-4c9e-99f0-ffe041aa9748'},
#   {'startTime': 971.34,
#    'endTime': 973.06,
#    'content': 'par personne par mois, 5.',
#    'speaker': 'spk2',
#    'uuid': 'c120fd78-7e1a-4e47-938a-39e91b73bfc6',
#    'blockUuid': 'e03e59e7-83d9-4d9e-84ce-1240793f2e7c'},
#   {'startTime': 975.89,
#    'endTime': 976.77,
#    'content': "Après, on s'est fixé des objectifs.",
#    'speaker': 'spk2',
#    'uuid': '259c74da-e690-4489-9eb3-f63ba8d2444e',
#    'blockUuid': '1b4b3929-d7c8-4cf4-ac25-aa7b2de83bf0'},
#   {'startTime': 976.77,
#    'endTime': 979.85,
#    'content': "Par mois, c'est pas possible. T'es à 15 marques blanches.",
#    'speaker': 'spk1',
#    'uuid': 'fc00cb08-d9ba-423d-91c1-2f397d6bb50b',
#    'blockUuid': 'fc9eda6c-7391-4aaf-b653-8c45314358e2'},
#   {'startTime': 981.51,
#    'endTime': 995.49,
#    'content': "Si on veut suivre ce qu'on est censé progresser, comment on est censé progresser, en tout cas sur 2024, on",
#    'speaker': 'spk2',
#    'uuid': 'e6d41250-8e70-48aa-8d8a-dacc8b52748b',
#    'blockUuid': '2d88c4ee-dc37-47d9-9619-8cc585a14adb'},
#   {'startTime': 995.49,
#    'endTime': 1001.65,
#    'content': 'devrait être à terme à ce nombre-là. Dans tous les cas, on a un gros gap entre haut et bas.',
#    'speaker': 'spk2',
#    'uuid': '8c624e4f-8496-4dc3-87f7-267d7ea5b0ae',
#    'blockUuid': '2d88c4ee-dc37-47d9-9619-8cc585a14adb'},
#   {'startTime': 1001.65,
#    'endTime': 1009.39,
#    'content': 'Il y a un gros gap. On parle juste de marques blanches. Les autres sont complètement dépriorisés ? Est-ce que',
#    'speaker': 'spk0',
#    'uuid': '7d97e088-eaef-4cd7-aef1-35f5fd88ea31',
#    'blockUuid': '71f4af87-2db3-453b-b62c-2c4b4077f2fe'},
#   {'startTime': 1009.39,
#    'endTime': 1012.43,
#    'content': 'vos sales performent plus sur les autres ?',
#    'speaker': 'spk0',
#    'uuid': '5a216783-49d6-4117-a449-fad490073658',
#    'blockUuid': '71f4af87-2db3-453b-b62c-2c4b4077f2fe'},
#   {'startTime': 1012.79,
#    'endTime': 1017.03,
#    'content': "Là-dessus, Celeste, c'est compliqué parce que tu poses des questions auxquelles on n'a pas de réponse.",
#    'speaker': 'spk1',
#    'uuid': '9407efe1-2204-482d-9c19-60f163fa2b05',
#    'blockUuid': '91973165-1cf0-4169-8772-316ce23d6e44'},
#   {'startTime': 1017.57,
#    'endTime': 1018.43,
#    'content': 'Ok, pas de problème.',
#    'speaker': 'spk0',
#    'uuid': '49951659-8a8c-4617-871f-3f58f54996f0',
#    'blockUuid': '0e455c1b-07c1-46a1-8fb8-f9ee65b6f9d8'},
# ...
#    'speaker': 'spk0',
#    'uuid': '3a25d1b6-9aa8-436a-9488-9e1557996c97',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4329.55,
#    'endTime': 4333.19,
#    'content': "une fois, ils n'ont pas du tout mis en place Modjo quand ils étaient Gymlib de maintenant. Ils sont",
#    'speaker': 'spk0',
#    'uuid': 'ea3cb691-79cd-4d4a-91dd-f31733eefcab',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4333.19,
#    'endTime': 4337.47,
#    'content': "une armée de ça. Ils l'ont mis en place au démarrage où justement ils avaient besoin de gagner en temps",
#    'speaker': 'spk0',
#    'uuid': 'fa3946d3-4ec4-43b9-b2d7-9e33a29a5ba7',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4337.47,
#    'endTime': 4343.59,
#    'content': "à comprendre exactement les besoins du marché, comment pitcher leurs équipes, comment ils répondaient aux objections et justement passer d'un",
#    'speaker': 'spk0',
#    'uuid': '358d37ff-d936-4913-993f-9d741388f043',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4343.59,
#    'endTime': 4351.41,
#    'content': 'mode un peu bricolage artisanal à un mode crescendo beaucoup plus processé pour aller chercher des parts de marché, pour',
#    'speaker': 'spk0',
#    'uuid': 'f12ba016-2e01-4ce6-878d-16f1ffa90ffa',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4351.41,
#    'endTime': 4358.99,
#    'content': "aller chercher de la productivité, pour faire en sorte que leur leur junior arrive très rapidement au niveau d'un justement",
#    'speaker': 'spk0',
#    'uuid': 'b158e653-8696-4c21-bfdd-528a18214b57',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4358.99,
#    'endTime': 4364.83,
#    'content': "Antonique cofondeur qui, évidemment, est le meilleur sales aujourd'hui, mais que lui se détache progressivement du coup de la vente",
#    'speaker': 'spk0',
#    'uuid': '4a87c2e4-f75a-4da4-95c9-bc0c335d58bd',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4364.83,
#    'endTime': 4370.37,
#    'content': "pour avoir des sales qui prennent le relais. Donc c'est tout l'idée d'un Modjo aujourd'hui.",
#    'speaker': 'spk0',
#    'uuid': '95f8eebc-359e-41cc-8433-2bc0dd0c9a27',
#    'blockUuid': '340b461b-9790-4bfc-9d60-d799b8e8d1ef'},
#   {'startTime': 4371.17,
#    'endTime': 4371.95,
#    'content': 'OK, OK, OK.',
#    'speaker': 'spk2',
#    'uuid': '72023d95-9a0f-47db-99f5-bf3a0a81212f',
#    'blockUuid': '82bf1afa-ed30-4b8d-a129-cbeeaf99e84d'},
#   {'startTime': 4372.13,
#    'endTime': 4373.49,
#    'content': "J'ai bien répondu à ta question.",
#    'speaker': 'spk0',
#    'uuid': '61f1ef9c-f771-4854-b9b6-7e577e4a58ea',
#    'blockUuid': 'bb024fc1-3072-4da3-afb0-41415ce586d9'},
#   {'startTime': 4374.11,
#    'endTime': 4376.21,
#    'content': "J'avais saisi effectivement ça.",
#    'speaker': 'spk2',
#    'uuid': 'd62406a0-a010-48aa-bcf3-3c196be99b3b',
#    'blockUuid': '9b4ec358-0895-40cf-9501-ea9834c0a702'},
#   {'startTime': 4378.98,
#    'endTime': 4386.3,
#    'content': "Et sur les évolutions du produit, est-ce qu'on reste sur le même prix ou est-ce qu'on va être bloqué? Si",
#    'speaker': 'spk2',
#    'uuid': '3ed45fe3-9698-461e-8ae4-8c85469a592f',
#    'blockUuid': '56f6f8aa-cbd3-4e3b-972d-3815ca5b3bdf'},
#   {'startTime': 4386.3,
#    'endTime': 4390.98,
#    'content': "on veut passer à des évolutions là dans tu dis dans un mois là, est-ce que c'est un complémentaire?",
#    'speaker': 'spk2',
#    'uuid': '21d703eb-e5be-42f1-9933-f7e61378c5c3',
#    'blockUuid': '56f6f8aa-cbd3-4e3b-972d-3815ca5b3bdf'},
#   {'startTime': 4391.94,
#    'endTime': 4398.82,
#    'content': "Non, effectivement, il y a absolument ce qui est signé restera signé. Ce que je veux dire, c'est que c'est",
#    'speaker': 'spk0',
#    'uuid': '5f068b31-f177-4e1b-974c-c1d259f41228',
#    'blockUuid': '8fe76768-25e2-46f0-8679-923197841f79'},
#   {'startTime': 4398.82,
#    'endTime': 4405.18,
#    'content': "notamment la fonctionnalité dont je t'ai parlé. Tu vas en bénéficier. On n'a pas de coût supplémentaire en fonction des",
#    'speaker': 'spk0',
#    'uuid': 'c62ffe73-936e-4917-8531-d3e707905276',
#    'blockUuid': '8fe76768-25e2-46f0-8679-923197841f79'},
#   {'startTime': 4405.18,
#    'endTime': 4410.02,
#    'content': 'features que tu choisis. Tu auras accès à toutes les nouveautés. Bref, à tout.',
#    'speaker': 'spk0',
#    'uuid': '27d8a9d2-e1f8-4316-8a51-ed50c41e6645',
#    'blockUuid': '8fe76768-25e2-46f0-8679-923197841f79'},
#   {'startTime': 4411.19,
#    'endTime': 4417.11,
#    'content': 'Parce que je te dis ça parce que Intercom, par exemple, qui est un excellent outil, il sort des fonctionnalités',
#    'speaker': 'spk2',
#    'uuid': 'c648dbd9-b424-414a-8389-c3f3fc831c38',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4417.11,
#    'endTime': 4423.51,
#    'content': "régulièrement et il y en a qui ne font pas partie du scope. C'est des modules en fait additionnels. C'est",
#    'speaker': 'spk2',
#    'uuid': '5d7415a8-6de7-4d02-97bf-526e8dff5213',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4423.51,
#    'endTime': 4430.57,
#    'content': "pareil avec des ardoises qui sont colossales pour des boîtes comme nous. Même si c'est des outils qui sont très",
#    'speaker': 'spk2',
#    'uuid': 'c082df8d-bea8-44f9-9d05-6e4168ef5ea1',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4430.57,
#    'endTime': 4436.71,
#    'content': "pertinents. Donc voilà, nous, ce que je peux juste te dire, en tout cas, c'est que on est prêt à",
#    'speaker': 'spk2',
#    'uuid': '384ef335-8a4f-4590-98fc-2290190dfedf',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4436.83,
#    'endTime': 4445.13,
#    'content': "s'engager. En tout cas, sur les 18 prochains mois avec un tarif très très préférentiel. Très sincèrement et après, continue",
#    'speaker': 'spk2',
#    'uuid': 'd59aeea7-1820-4652-9f08-f0acdb9cf0ae',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4445.13,
#    'endTime': 4448.75,
#    'content': "avec vous. Il n'y a pas de raison à ce que, en tout cas, moi, je crois en cet outil",
#    'speaker': 'spk2',
#    'uuid': '973b7a37-1dff-4901-b154-2fdcaa3a2470',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4448.75,
#    'endTime': 4454.69,
#    'content': "là. Ce n'est pas le problème. Aujourd'hui, nous, le frein, c'est à la fois le tarif et un frein mineur.",
#    'speaker': 'spk2',
#    'uuid': '8477e6af-0061-4465-9270-5f4a7ce99df1',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4455.25,
#    'endTime': 4460.15,
#    'content': "C'est ça, il faut qu'on en discute en interne. C'est le temps à accorder après sur cet outil là. Si",
#    'speaker': 'spk2',
#    'uuid': '52da108e-24fb-4cfe-a5a8-4fe74896034d',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4460.31,
#    'endTime': 4466.85,
#    'content': "c'est pour avoir un outil pour dire qu'on a Modjo mais derrière qu'on ne l'exploite pas. Parce que aujourd'hui, on",
#    'speaker': 'spk2',
#    'uuid': '7e62e659-f44e-4c23-b48d-8c500a7b41f5',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4466.85,
#    'endTime': 4472.65,
#    'content': "a des outils qu'on n'exploite pas comme il se devrait, comme il devrait. Ça ne nous servira à rien. Mais",
#    'speaker': 'spk2',
#    'uuid': 'f075b1f5-81b7-488a-8cd8-2bbf8bfac028',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4472.65,
#    'endTime': 4475.41,
#    'content': "ça, c'est plus surprenant à se mettre d'avis.",
#    'speaker': 'spk2',
#    'uuid': '3af26787-0290-478f-b4af-f087af0ed649',
#    'blockUuid': '6d3c7eca-56cd-4784-acfb-a0f6df4881a5'},
#   {'startTime': 4475.63,
#    'endTime': 4481.65,
#    'content': "OK, effectivement, après, tu vois, sur la partie productivité, notes. Aujourd'hui, du coup, c'est l'IA qui fait tout. Et donc,",
#    'speaker': 'spk0',
#    'uuid': 'f7d51c4e-f3d3-46be-ba2e-630746ff781b',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4481.65,
#    'endTime': 4486.45,
#    'content': 'pour le coup, ça remonte directement dans ton Hubspot. Donc, en fait, de toute façon, les calls, ils sont enregistrés.',
#    'speaker': 'spk0',
#    'uuid': '741c9aa4-33b2-47e0-bca1-354922ab6282',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4486.63,
#    'endTime': 4490.47,
#    'content': 'Donc ça, de toute façon, on va dire que vous avez entre guillemets plus la main mise sur est-ce que',
#    'speaker': 'spk0',
#    'uuid': 'a962dbc3-f52f-483a-b6e6-023536039785',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4490.47,
#    'endTime': 4496.01,
#    'content': 'mon IA prend des notes. De toute façon, elle prendra les notes. Et sur la partie du coup réécoute. Pour',
#    'speaker': 'spk0',
#    'uuid': 'fdd58f22-ae44-4713-8f69-51b7a1a11f78',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4496.01,
#    'endTime': 4499.57,
#    'content': "moi, c'est on vient pas modifier vos routines, ce qui est mis en place par Merlin, ce qui est mis",
#    'speaker': 'spk0',
#    'uuid': '5dda6b14-d360-4113-8862-0878bd25827d',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4499.57,
#    'endTime': 4506.27,
#    'content': 'en place par Arthur, peut être sur toi, sur la partie management des équipes CSM. On vient juste vous faire',
#    'speaker': 'spk0',
#    'uuid': '31b6c74a-65f9-413f-9f37-3af8b5c48b95',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4506.27,
#    'endTime': 4511.01,
#    'content': "gagner du temps d'écoupler votre force de coaching et surtout donner les moyens à des sales aujourd'hui ou des CSM",
#    'speaker': 'spk0',
#    'uuid': 'ed200dee-d1af-4f86-bf37-dfcd4d918862',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4511.01,
#    'endTime': 4517.27,
#    'content': "de s'améliorer. Et du coup, aujourd'hui, honnêtement, en termes de connexion, c'est évidemment qu'il y a des managers. Mais en",
#    'speaker': 'spk0',
#    'uuid': '24a734c8-1217-4370-bea6-fee1d00dfd6d',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4517.27,
#    'endTime': 4521.55,
#    'content': "fait, aujourd'hui, c'est un outil. Il y a des équipes aujourd'hui qui font des sales aujourd'hui qui demandent de leur",
#    'speaker': 'spk0',
#    'uuid': '7970947b-a2dc-43aa-b1af-a213e9fd0349',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4521.55,
#    'endTime': 4525.69,
#    'content': "de leurs entretiens. Est ce que vous avez Modjo ? Parce qu'en fait, ça leur simplifie à mort la vie. La",
#    'speaker': 'spk0',
#    'uuid': 'bba50e7d-26e6-4892-9705-9af6a3622681',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4525.69,
#    'endTime': 4530.37,
#    'content': 'dernière fois, on avait parlé du fait que vous ayez des grands comptes et six mois de cycles de ventes.',
#    'speaker': 'spk0',
#    'uuid': '2714fcaa-51ca-493e-8524-123fec8194df',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4530.69,
#    'endTime': 4536.61,
#    'content': "Si je ne m'abuse, justement, un outil comme ça, ça te permet de revenir sur tes échanges, de te remettre",
#    'speaker': 'spk0',
#    'uuid': '08f36651-d006-4544-b528-fefa12e71385',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4536.61,
#    'endTime': 4543.19,
#    'content': "dedans, de préparer des rendez-vous, être beaucoup plus pertinent. Et en fait, c'est vraiment comment dire? C'est en fait, ça",
#    'speaker': 'spk0',
#    'uuid': 'e02bb521-b9d1-419a-9fb4-847e883ba371',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4543.19,
#    'endTime': 4551.75,
#    'content': "devient indispensable pour les équipes. Du coup, en termes d'usage, je comprends effectivement le côté. On n'a pas envie de",
#    'speaker': 'spk0',
#    'uuid': 'a0a2c05d-d66a-4c2d-be5b-6782da33b344',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4551.75,
#    'endTime': 4555.21,
#    'content': 'mettre en place un outil pour un outil. Mais alors là, pour le coup, moi, je sais que tu vois',
#    'speaker': 'spk0',
#    'uuid': '28efd23c-b801-4457-83cc-faf6e5774c34',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4555.21,
#    'endTime': 4560.05,
#    'content': 'le jour où je bosse de Modjo je sais que je veux une équipe, une boîte où il y a',
#    'speaker': 'spk0',
#    'uuid': '0479625e-5a6a-4a6c-a70f-ce5a60b34d7e',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4560.05,
#    'endTime': 4567.99,
#    'content': "un Modjo aujourd'hui. Parce que moi, je m'y imagine pas repasser à des tâches manuelles, revenir sur des enregistrements pour",
#    'speaker': 'spk0',
#    'uuid': 'ee534408-b121-417e-bba5-da57b22ba329',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4567.99,
#    'endTime': 4573.25,
#    'content': "me préparer. Ça me paraît aberrant de faire ça. Voilà, voilà. Écoute, ce que je te propose, c'est qu'on se",
#    'speaker': 'spk0',
#    'uuid': 'adbc7d2a-f373-470f-98ee-12b5c2a499dc',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4573.25,
#    'endTime': 4576.63,
#    'content': 'prenne un petit créneau du coup, effectivement, pour la partie tarifaire.',
#    'speaker': 'spk0',
#    'uuid': '7d02f3da-e7d3-429e-bd2f-b679c15d757a',
#    'blockUuid': '86f2037d-a959-42c4-add4-1b6e15097deb'},
#   {'startTime': 4576.89,
#    'endTime': 4577.13,
#    'content': 'Oui.',
#    'speaker': 'spk2',
#    'uuid': '71eccb31-da3c-48c8-a9ce-f8a03dbb4713',
#    'blockUuid': '73d5e4e1-357b-4eab-84ac-1a495e6c8428'},
#   {'startTime': 4578.37,
#    'endTime': 4584.61,
#    'content': "Qu'est ce que tu penses? Moi, j'ai un créneau demain si tu veux ou autrement lundi.",
#    'speaker': 'spk0',
#    'uuid': 'b1b6eaa1-9ea7-4179-b34c-7cf273b3613f',
#    'blockUuid': '1882ec02-5a8d-4bea-8d5b-9ce867bc7fab'},
#   {'startTime': 4585.56,
#    'endTime': 4586.6,
#    'content': 'Lundi, ce sera mieux.',
#    'speaker': 'spk2',
#    'uuid': '47681d9b-d63e-4882-ae6a-75e5e00246bf',
#    'blockUuid': 'dd364536-ccc0-4ab1-9684-c6e75e530adc'},
#   {'startTime': 4589.3,
#    'endTime': 4590.82,
#    'content': 'Lundi, lundi, lundi.',
#    'speaker': 'spk2',
#    'uuid': '3f5bc827-7663-46f3-b734-2f3673eea900',
#    'blockUuid': '516863ed-a0d6-432b-a014-c3c93241db0f'},
#   {'startTime': 4591.26,
#    'endTime': 4592.44,
#    'content': "Qu'est ce que c'est?",
#    'speaker': 'spk1',
#    'uuid': 'a11fb102-4aab-4d11-a9d3-d24a8247f0bb',
#    'blockUuid': 'a0b5e034-9621-41f8-877f-17821ba9d250'},
#   {'startTime': 4594.92,
#    'endTime': 4596.76,
#    'content': 'Lundi 16h30.',
#    'speaker': 'spk2',
#    'uuid': '95faac4c-2dad-4f7f-8c22-c659f4eae748',
#    'blockUuid': '42865dba-c9db-4464-9e6d-a9e1927c6caa'},
#   {'startTime': 4597.66,
#    'endTime': 4603.34,
#    'content': "Eh ben parfait. Lundi 16h30. On fait ça. Je t'envoie un peu. Je t'envoie l'invit du coup. Que on",
#    'speaker': 'spk0',
#    'uuid': 'c83c9415-c5dd-4d84-9cba-1efef86fd35b',
#    'blockUuid': '85434d96-7deb-4ce8-8da7-ca1097e6690f'},
#   {'startTime': 4603.34,
#    'endTime': 4610.22,
#    'content': "sera tous les deux, c'est ça? Oui. OK, très bien. Eh ben écoute, je t'envoie l'invitation et on en discute",
#    'speaker': 'spk0',
#    'uuid': 'adad914a-e764-4627-9c30-7cb701bbc739',
#    'blockUuid': '85434d96-7deb-4ce8-8da7-ca1097e6690f'},
#   {'startTime': 4610.22,
#    'endTime': 4618.94,
#    'content': "à 16h30 lundi. Et écoute, je prépare une offre tarifaire la plus ajustée que je peux faire aujourd'hui. Et puis",
#    'speaker': 'spk0',
#    'uuid': 'b7b18d94-84e8-475a-8b66-97bd521419cb',
#    'blockUuid': '85434d96-7deb-4ce8-8da7-ca1097e6690f'},
#   {'startTime': 4618.94,
#    'endTime': 4624.66,
#    'content': 'on la finira en fonction. OK, super. Merci Merlin. Bonne après-midi. Oui, toi aussi. Au revoir.',
#    'speaker': 'spk0',
#    'uuid': '418db0ae-418f-4fb5-a8df-dd4c87f131fe',
#    'blockUuid': '85434d96-7deb-4ce8-8da7-ca1097e6690f'}]}

# %% [markdown]
# Based on this excerpt, there can be the following strategies:
# - Directly ask chatgpt for a summary if the context is not too big
# - Use a local db of vectors with the json contents and then ask for a summary
# - Get only the text with a "-" symbol whenever there is a speaker change and then get the summary (with or without local vectors)
#
# The prompt must include the limit of 60 words as a constraint.

# %%
def organize_json(json_dict):
    out = ""
    tmp = ""
    previous_speaker = ""
    for block in json_dict["segments"]:
        speaker = block["speaker"]
        if speaker == previous_speaker:
            tmp += " " + block["content"]
        else:
            out += tmp
            tmp = "\n- " + block["content"]
            previous_speaker = speaker
    return out


textified_conversation = organize_json(data)
print(textified_conversation)
# Out:
# - Oui bonjour Celeste.
# - Bonjour Merlin. Comment vas-tu ?
# - Très bien et toi ?
# - Super. Écoute, ça va super. Je suis ravie de commencer mon après-midi avec toi. Je vois que la caméra n'a pas été réparée. Je sais pas si t'es tout seul ou t'es avec...
# - Non, là je t'avoue que avec le gros brume que j'ai...
# - Ah oui ! Ok, pas de problème. Non, mais je ne savais pas si du coup, Arthur et l'autre Merlin se connectaient derrière toi ou s'il y avait d'autres personnes qui arrivaient.
# - Non, alors Merlin, je ne sais pas, mais Arthur, ben voilà, il est là, parfait.
# - Ben voilà. Bonjour Arthur, enchanté. Salut Arthur.
# - Je suis là, bonjour Celeste.
# - Ah c'est Merlin, parfait. Donc, je suis juste contente de reposer le contexte par rapport à notre échange de la dernière fois et puis l'objectif de cette petite call tous ensemble.
# - Oui, effectivement, l'idée c'était, si ça vous va, l'agenda du coup juste que je vous propose effectivement, c'est peut-être juste de faire un petit tour de table avant pour connaître un peu du coup le niveau de connaissance de Merlin et de Arthur sur Modjo et connaître un peu exactement vos scopes et vos enjeux un peu personnels justement sur vos scopes de collectif chez RoundTable. Ensuite, évidemment, je vais faire un récap' des enjeux discutés avec Merlin lors de notre précédent call et pour être sûr qu'on est tous les quatre alignés. Et évidemment, on va très vite s'immerger dans Modjo pour que vous puissiez justement vous projeter et voir en quoi ça pourrait évidemment vous aider sur vos enjeux à la fois côté sales et CSM et la fin de l'échange, ça serait du coup de planifier la suite. Pour vous, l'idée, c'est d'avoir un peu de la visibilité du coup sur notre business model et pour moi, c'est pouvoir vous préparer une proposition tarifaire sur mesure et du coup la plus adaptée que ça soit en termes de nombre de licences. Est-ce que ça vous va comme comme comme Ouais, pas mal. L'échange. Ouais, OK, juste je peux me permettre. Merlin et Arthur, est-ce que vous votre caméra fonctionne ou pas?
# - La caméra, je vais voir si elle fonctionne.
# - OK, génial, trop cool. OK, ça va super. C'est sympa. Merci. Comme ça, plus qu'en plus, on est trois. Comme ça, je suis sûre. Si vous avez des questions, peut être aussi d'avoir le visuel. Juste avant du coup de commencer, je suis juste curieuse de savoir Arthur et du coup Merlin, quel est juste votre niveau de connaissance de Modjo et qu'est ce que vous faites exactement chez RoundTable pour être sûr de présenter?
# - Et bien, on a radé un petit peu, donc c'était pour améliorer les performances commerciales, notamment grâce à l'IA. En gros, c'est par rapport à un script, voir à quel degré de similitude on est par rapport au script. Et donc, du coup, pour améliorer tout ce qui est nous, les relations clients après l'espèce commerciale et aussi l'espèce commerciale pour avoir de nouveaux clients. Et du coup, quand je suis à RoundTable, l'équipe d'équipe customer success et on est sur la partie commerciale opérationnelle.
# - Ouais, moi, je m'occupe de toute la partie opérationnelle. Je suis associé à Merlin qui est ici dans la call et connaissance de Modjo au même moment avec Merlin, puisque c'est on était dans la même réunion le jour où on nous en a parlé. OK, donc voilà en synthèse.
# - OK, génial. Et du coup, justement, je crois que vous avez passé pas mal de temps ces dernières semaines ou ces derniers jours chez Furnitures. Est ce que vous avez pu échanger avec SquareChair? Enfin, du coup, je crois que c'est Lancelot et Lancelot. Oui, c'est ça. Lancelot, le CEO de SquareChair qui est dans le même incubateur que vous.
# - Non, on n'a pas parlé avec Lancelot spécialement sur ça, je t'avoue.
# - OK, non, mais pas de problème. C'était par curiosité. OK, super clair.
# - Pour le savoir, on se gardera avec lui la semaine prochaine.
# - Écoutez, bah écoutez, avec plaisir, effectivement, ces équipes l'utilisent. Depuis, c'était mon premier client parce que moi, je suis à eux depuis trois mois maintenant et du coup, qui de mieux qu'un utilisateur Modjo pourra vous partager des insights. Donc, trop bien si vous le rencontrez. Du coup, pour récapituler ce qu'on s'est dit la dernière fois du coup avec Merlin et être sûr qu'on est sur le même niveau d'information. Moi, ce que j'ai compris, c'est que vous avez des grosses ambitions de croissance. Aujourd'hui, vous avez des équipes principalement à Lyon, mais aussi un peu à Barcelone. Du coup, il y a un enjeu de manager à distance pour être plus efficient. Vous avez des process aujourd'hui qui est du coup, je reprends tes termes à Merlin. Je ne sais pas du tout de ma bouche, mais qui sont encore un peu brouillon. Et du coup, vous avez un enjeu de scalaire un peu sur cet aspect. Du coup, formaliser plus les process pour aller chercher plus de méthodologie dans votre approche, que ça soit côté CSM et SAIS. Et du coup, quand vous parlez justement, quand on parle du coup de performance de croissance aujourd'hui, tu parlais aujourd'hui de vos deux enjeux qui étaient augmentés drastiquement. Le MRR généré aujourd'hui, c'est un peu possible que ça soit sur la partie tunnel d'acquisition en termes de volume ou de panier moyen. Et c'était aussi de fidéliser du coup les clients côté CSM. Et pour ça, du coup, vous avez besoin d'un ou vous voudriez vous projeter sur un outil d'intelligence conversationnelle. Du coup, côté sales, c'était vraiment pour l'aspect amélioration du discours, peut être test aussi de discours en fonction de vos nouvelles offres pour aller peut être chercher justement un panier moyen plus important. Aussi, réponse aux objections et faire monter tout simplement vos recrues en compétences, parce que notamment, c'est des profils assez juniors et alternants. Si je ne m'abuse. Et côté CSM, c'est aussi de challenger sur la partie plutôt démo avec démo et avoir une expertise CSM vraiment encore plus poussée sur votre plateforme. Et on avait parlé d'un dernier sujet qui était moins lié à la performance, mais qui serait amené certainement à être challenge. C'était la partie productivité sur Hubspot. Merlin, tu disais que que vous l'utilisiez peut être aujourd'hui à 30% et que 99% vous n'étais pas sûr à 99% que les notes dans les opportunités soient bien prises et qu'il y aurait potentiellement des sujets de passations d'information entre CSM. Et du coup, c'est tout l'idée de Modjo d'un outil global, c'est de vous aider sur ses parties performance et productivité. Est ce qu'on est toujours aligné? Est ce qu'il y a d'autres points que vous vouliez voir et qui sera important pour vous pour la démo?
# - Non, tu as très bien résumé.
# - OK, génial. Et qu'est ce que je veux dire? Oui, non, dernier dernier aspect. Du coup, on avait à parler un tout petit peu moins de ça la dernière fois, Merlin, j'étais curieuse de savoir aujourd'hui concrètement qu'est ce que vous mettez en place comme routine de coaching à proprement parler, puisque du coup, vous aimeriez bien challenger sur le discours, sur les objections. Mais du coup, à date, sans un Modjo sans un outil pour vous y aider, qu'est ce qui est mis en place par les managers?
# - Pas grand chose. Ce n'est pas le problème. Donc, sur la partie CSM, on met en place depuis un mois, un mois et demi des tests de pitch juste sur la partie pitch démo fonctionnel. Donc, on faut qu'on garde justement cette vélocité sur ces tests. Et c'est tout ce que l'on fait, en tout cas sur la partie CSM aujourd'hui. Je pense qu'il y a d'autres éléments à prendre en compte aussi sur la qualité des process qui sont traités. Et sur la partie sales, tu peux dire deux mots, mais voilà, je sais qu'il y a des écoutes pendant un moment qui étaient faites sur Ringover, du double écoute ou même après coup, mais par quelque chose de régulièrement.
# - On fait principalement des workshops. OK. Des workshops en règle générale, c'est une fois par mois.
# - Ça se matérialise comment? Concrètement, ces workshops, c'est quoi l'objectif?
# - C'est en gros, moi, je demande, donc il y a des ateliers à Ringover qui nous permettent de les écouter. Clairement, il n'y a pas de double écoute dans le sens où on n'est à personne qui a le temps de faire de la double écoute. En tout cas, moi, je n'ai pas le temps de faire la double écoute. Donc, on demande celle de venir avec d'enregistrer des bad calls et des good calls en gros, au nombre de cinq par mois. Et ils viennent avec en atelier.
# - Ouais.
# - Workshop. On travaille comme ça, notamment beaucoup. Le traitement des objections. Voilà, c'est aujourd'hui, c'est la méthode où qui est qui est qui est faite côté sales. Donc, c'est une fois par mois. Sachant que ça, effectivement, ça c'est là depuis septembre. Ça s'est arrêté puisqu'on a eu pas mal de nouvelles recrues qui sont rentrées, etc. Donc, en gros, il y a une petite pause sur septembre, octobre. Le temps de remettre l'équipe à flot. Donc là, ça va reprendre. On a arrêté, je crois, le dernier, c'était en juillet, début juillet, en été. Donc voilà, septembre, octobre, il n'y en a pas. Là, on va reprendre en novembre. Sachant que nous, les nouveaux sales, quand ils rentrent, on les fait d'abord travailler sur du pur call à froid. Donc, du pur call à froid, on ne les fait pas travailler sur des pros spéciaux de notre CRM. On travaille sur le script, le discours, on va dire en condition dure pour être potentiellement plus efficace en conditions plus clémentes. Et au niveau du script, tout est scripté, j'allais dire, en fonction des différents cas, que ce soit du prospect froid au prospect. Il y a deux doigts de signer et qui a déjà fait une période d'essai. Donc, on a à peu près tout scripté. Néanmoins, on n'est pas dans une logique de... Moi, j'ai tendance à dire aux sales que l'important, c'est qu'ils sont en capacité d'avoir la profondeur de traiter les objections et la résilience de s'accrocher. Après, effectivement, ça reste de l'impro en fonction de qui tu es en face de toi. Donc, tu ne peux pas avoir un discours de robot, même si au début, tu l'as un petit peu sur les trois et six premiers mois. Ils sont un peu en mode robot et c'est normal. Et j'allais dire, c'est même les robots qui sont en mode robot, parce que ça veut dire qu'ils suivent le script. Néanmoins, par la suite, ce n'est pas le robot qui signe. C'est lui.
# - Et du coup, juste petite question. Que ça soit sur les sales qui ont déjà eu leur phase de ramp-up ou les junior aujourd'hui, donc, effectivement, ils testent le pitch, ils répondent à des objections. Concrètement, là, tu fais comment juste pour t'assurer qu'ils répondent bien? Parce qu'il y a les workshops que vous mettiez en place. Mais aujourd'hui, à date, tu fais comment? Tu es sur le flot, tu les écoutes comme ça, tu fais de la réécoute via ring-over. Comment tu les accompagnes dans leur montée en compétence?
# - Nous, en gros, on a un suivi hebdo. Le lundi, on a une réunion d'équipe. Le vendredi, on a une réunion individuelle. En réunion individuelle, ils ont pris l'habitude de venir avec leur, entre guillemets, avec leurs problématiques, leurs objections. Ils viennent souvent me demander des arguments. Effectivement, à l'instant T maintenant, alors avant, ce n'était pas obligatoirement le cas avant l'été, mais maintenant, on a la chance d'avoir une sorte d'open space sur lequel moi, je peux entendre les appels. Donc, ça me permet d'intervenir quand je suis là pour éventuellement donner des petits des petits feedbacks. Voilà des tips. Mais jusqu'alors, on va dire que jusqu'alors, on était sur un modèle où, comme je te dis, il n'y a pas de réécoute à part le workshop. Il n'y a pas de réécoute. Après, les celles chez nous ont participé pour la plupart, ou en tout cas, ont au moins participé une fois un salon. Salon, ça veut dire que, voilà, j'allais dire, il n'y a pas derrière un téléphone, tu ne peux pas te cacher, tu es face à la personne et tu dois tu dois débiter. Et aujourd'hui, tous les sales, on va dire, ont participé au moins à un salon et ils ont déjà conclu des ventes. Donc, on a quand même un niveau de performance minimum qu'on sait être capable de tenir. Le problème, c'est la recherche de la... Le problème, c'est de travailler sur l'amélioration de la performance. C'est vraiment ça. C'est augmenter le nombre de conversions par mois, le nombre de closures, c'est le sujet.
# - Tu vas aller chercher combien en taux de conversion aujourd'hui ? Pardon ? Tu vas aller chercher combien en taux de conversion aujourd'hui ? Enfin, vous êtes à combien en taux de conversion et tu vas aller chercher combien dans l'idéal ?
# - En gros, aujourd'hui, on veut aller... On a nous un gros top service qui est la customize, la marque blanche chez nous. Si tu regardes un petit peu...
# - Ici, j'ai regardé votre site à 139 euros.
# - Voilà, notre objectif, c'est d'être tous les mois au moins 10. Donc, ça, c'est vraiment notre objectif d'être à 10.
# - Et aujourd'hui, vous êtes à combien ?
# - Aujourd'hui, on tourne entre 6 et 8 en gros. Donc, on est un cran en dessous. Ce mois-ci, on va aller faire les 10 parce qu'on sort d'un salon. On va dire que le taf a été bien fait, mais dans la récurrence... Et d'ailleurs, on a une performance assez ératique dans le sens où il y a des mois, je ne sais plus, en juin, on en fait 5 et en juillet, par exemple, on en fait 10. Donc, en fait, on est vraiment comptable au niveau de la perfo. C'est ça qui est le plus frustrant. C'est là qu'on aimerait avoir un outil qui potentiellement nous permette d'améliorer de manière continue la performance des sales.
# - En termes de chiffre d'affaires ou de MRR ou ARR à aller chercher sur l'année, tu as une idée de ce que ça représenterait d'augmenter justement cette performance qui est aujourd'hui pas forcément stable de moins en moins.
# - C'est-à-dire le fait d'atteindre l'objectif, qu'est-ce que ça apporte ton MRR en plus ?
# - Aujourd'hui, c'est quoi ton objectif ? C'est quoi le manque à gagner en termes d'ARR que tu as en visibilité le fait de ne pas être à 10 aujourd'hui ?
# - Tu peux parler de son MRR.
# - MRR, oui.
# - C'est un jeu galère quand il met son niveau. Là, c'est simple. On a fait 7 marques blanches en septembre. L'objectif, c'est 10. C'est à peu près 500 euros par mois la marque blanche. C'est 1500 euros mensuels qui tournent par an.
# - Et du coup, ça c'est par sales ? Pour l'équipe ? Au global ?
# - Le sales doit faire 3 marques blanches par mois. Si on voudrait qu'ils soient au niveau, il faut qu'ils fassent 3 marques blanches par mois. Normalement, s'ils en font 3 par mois, sachant que moi également j'en fais aussi, ça en fait 12 tout de moins.
# - Attention, ça c'est nos chiffres aujourd'hui. Les chiffres de TAM4, c'est pas ce que ça donne. On leur fait le calcul avec Samuel pas plus tard que ce matin.
# - Ça serait plutôt combien du coup ?
# - Là, on serait plutôt à nombre de marques blanches par personne par mois, 5. Après, on s'est fixé des objectifs.
# - Par mois, c'est pas possible. T'es à 15 marques blanches.
# - Si on veut suivre ce qu'on est censé progresser, comment on est censé progresser, en tout cas sur 2024, on devrait être à terme à ce nombre-là. Dans tous les cas, on a un gros gap entre haut et bas.
# - Il y a un gros gap. On parle juste de marques blanches. Les autres sont complètement dépriorisés ? Est-ce que vos sales performent plus sur les autres ?
# - Là-dessus, Celeste, c'est compliqué parce que tu poses des questions auxquelles on n'a pas de réponse.
# - Ok, pas de problème.
# - La question est pertinente, mais tu poses des questions auxquelles on n'a pas de réponse.
# - Ok, c'est pas grave.
# - Le problème, c'est que le sales contribue à la vente de licence les deux autres, sauf qu'on ne sait pas le traquer. On ne sait pas pourquoi nos clients, quand le sales leur donne un code, ils ne l'utilisent pas spécialement. On se trouve des sales qui aident à vendre la licence à 49 ou 69 euros, mais on ne sait pas si la vente a été faite par X ou Y. On sait que l'équipe contribue, donc on a une sorte de prime d'équipe là-dessus. Mais on n'arrive pas à l'individualiser. Aujourd'hui, alors que pour la marque blanche, on sait parce que le devis est fait par le sales, par le propriétaire de la transaction, donc là, c'est beaucoup plus facile. Moi, alors, dans le suivi mensuel, comme je les ai deux fois par semaine, je sais quel deal X ou Y a signé, donc je suis capable d'identifier qui a fait son taff, si c'est bon, si ou non.
# - Traquer dans un call, tel ou tel offre, ça vous permettrait d'avoir plus de visibilité sur ce qui pourrait être poussé par vos sales ?
# - Oui, identifier ce qui a été vendu dans le call et être capable de dire que c'était Jacky qui a vendu ça. Oui, ça peut être intéressant.
# - Ok, clairement, c'est un truc que je n'avais pas en tête, donc je vous montrerai. J'ai une dernière question et après, je vous promets, on switch sur la démo, mais on n'a pas trop parlé du coup de la partie CSM. J'ai compris qu'il y avait un enjeu sur la partie plutôt démo de votre côté. Juste pour comprendre aujourd'hui, c'est quoi les axes d'amélioration d'une démo. Concrètement, qu'est-ce que vous cherchez exactement à faire ?
# - Je pense qu'on peut rester sur le périmètre size.
# - Size, ok.
# - Très clair. Le démo, effectivement, peut l'améliorer, mais la personne est déjà sur le produit et c'est des informations qu'on vient lui donner. Donc oui, il y a de l'amélioration à faire, mais là pour la démo, je pense qu'on peut focusser sur les sales.
# - Ok, donc, focussons dans ce cas-là sur les sales. On n'avait pas sur la partie compte rendu, prise de notes. Tu me disais, Merlin, pendant le dernier échange que du coup, à ta connaissance en tout cas, aujourd'hui, c'est qu'il y avait peu de prise de notes de fait. Du coup, l'autre, Merlin, je crois que c'est toi qui manage les sales. À ton niveau, c'est quoi ta connaissance ?
# - C'est dans les deux sens. Aujourd'hui, on n'est pas bon dans les deux sens, dans le sens où le sales n'a pas tout le temps pris les notes et souvent le CS ne prend pas les notes du tout en post démo, ce qui fait qu'on a eu sur mai-juin des signatures qu'on a perdu par mauvaise communication CS Sales et Sales CS. Ce qui est sûr, c'est que je suis sûr à 99% qu'il n'y a pas toutes les informations entre les Arthur-Panthéonier vu que deux ou trois fois...
# - Ok, je mets les pieds là où il ne faut pas, mais l'idée, c'est de faire en sorte que ça ne se passe plus.
# - C'est clair que les notes, c'est quelque chose qui est très important. Tout le monde a une fois commis l'erreur, voire même la commet de temps à autre, ça, c'est certain. Et si on peut avoir un système de prise de notes automatisée grâce à une IA, oui, c'est intéressant.
# - Ok. Du coup, aujourd'hui, vous savez pourquoi ce n'est pas fait ?
# - Pourquoi ce n'est pas fait ? Parce qu'en fait, le CS, il a du mal à le faire parce qu'il fait sa démo en live avec son ordinateur. Et du coup, pour faire son CR, il faut qu'il s'arrête 5 minutes après et qu'il se dise, je fais ma synthèse. Donc là, il faut enlever la synthèse, il faut y penser. Et des fois, le pauvre CS, il enchaîne une réunion avec un autre CS.
# - Et côté sales sur la partie call ?
# - Alors côté sales, j'allais dire chez les sales, c'est peut-être l'endroit où c'est peut-être le plus fait parce que déjà, il est libre même. Donc en fait, un sales pour lui-même, il va prendre des notes. Mais les fois où il ne va pas le faire, ça peut être parce qu'il n'est pas à l'aise dans son call et qu'il se fait malmener et que du coup, on va dire que voilà, il a subi le rendez-vous et du coup, il a potentiellement besoin de souffler derrière. Et voilà, soit il enchaîne aussi des réunions, ça peut arriver puisqu'il peut avoir plusieurs réunions prévues avec des prospects. Et après, il y a aussi au-delà de l'aspect faire, il y a la qualité de la synthèse, il y a la qualité du CR, c'est deux choses différentes. Il y a faire et faire et effectivement, certains ont moins l'esprit synthétique que d'autres.
# - Ok, écoutez, très clair, dans ce cas-là, on regardera bien cet aspect aide à la prise de notes qui aidera du coup les deux équipes. Est-ce que vous avez des choses à rajouter ou est-ce qu'on peut passer du coup au partage d'écran et à la démo ?
# - Non, c'est complet.
# - Ok, génial. Merci en tout cas pour ce complément d'information qui va très certainement enrichir cette démo. Je vous partage dès maintenant mon écran, est-ce que vous le voyez bien ?
# - Oui.
# - Génial. Du coup, je compte sur vous pour vraiment m'arrêter si vous avez des questions et de me dire si jamais vous voulez passer parce que ça ne vous intéresse pas particulièrement. Normalement, j'ai bien préparé, donc ça ne devrait pas être le cas, mais n'hésitez pas vraiment à m'interrompre pour que ça soit le plus interactif possible. Du coup, bienvenue sur Modjo Comme vous pouvez le voir, c'est mon Modjo à moi. Je vous partage vraiment en toute transparence tous les échanges que j'ai au quotidien avec mes prospects et mes clients. Techniquement, comment ça va se passer ? Modjo ça va venir se plugger à votre outil de VOIP, donc Ringover, à vos outils de Visio et à votre CRM Hubspot. L'idée du coup, c'est qu'on va venir récupérer les enregistrements de ces échanges à des fins de performance, de productivité. Ce qu'on va faire concrètement, c'est qu'on va retranscrire en texte tout ce qui va être abordé, on va dire toute la dialectique, que ça soit côté commercial, CS ou client prospect. Concrètement, juste pour que vous ayez une idée, rien ne va changer pour côté Sales ou CS. Ce que je veux dire, c'est qu'il n'y a pas de manip manuel à faire pour qu'un call, une Visio remonte, tout est fait automatiquement.
# - Excusez-moi, Celeste, les CS font beaucoup de Google Meet ?
# - Oui. C'est géré ?
# - Du coup, Google Meet, exactement, c'est bien pris en compte. Toutes les vidéos Google Meet vont remonter automatiquement aujourd'hui dans Modjo. On off ? On off, non. On off aujourd'hui, on n'est pas intégré à on off. En revanche, on est intégré à Ringover et à d'autres outils de VOIP, mais pas à on off aujourd'hui.
# - Ce n'est pas grave, on off, normalement, c'est fait que pour beaucoup, pour des réceptions de SMS, pour débloquer des comptes, etc. Donc, ce n'est pas problématique.
# - C'est plus de l'écrit du coup plutôt que de l'audio finalement ?
# - C'est plus pour l'opérationnel que de l'échange pur avec du client.
# - En tout cas, effectivement, à date, on n'a pas encore d'intégration avec on off. Du coup, à date, on ne récupérerait pas ces échanges. OK. Du coup, l'ADN de Modjo c'est d'être le plus collaboratif possible. Et du coup, que ça soit au sein des équipes sales, customer success, entre managers, managers. Et du coup, comme vous pouvez le voir, on peut avoir accès à mes échanges, aux échanges du coup de mon équipe et aux échanges de toute l'entreprise. Une fois que j'ai dit ça, Modjo c'est également aussi la mémoire de l'entreprise, la mémoire client. Donc, par exemple, si je veux prendre par exemple un de mes, je vais faire encore mieux, je vais prendre SquareChair. SquareChair, comme je vous le disais, c'est une des start-up incubées chez Furnitures. Et du coup, ce qu'on peut faire, c'est qu'on va pouvoir filtrer finalement sur ce compte client. Là, vous pouvez voir qu'il y a effectivement aujourd'hui 10 échanges qui sont remontés. Ça passe de mon appel de prospection, ma discovery, bref, ma démo, l'offre tarifaire, comme aussi tous les échanges que l'équipe aujourd'hui de Modjo Customer Success a avec les équipes. Donc vous voyez vraiment, on part vraiment d'une base énorme d'échanges et on peut filtrer en fonction évidemment des clients pour avoir vraiment une historisation maximum des échanges. Déjà, est-ce que pour vous, ça c'est clair ?
# - Oui, oui, oui.
# - Ok, j'ai une idée. Alors, du coup, ce que je vous propose, c'est qu'on va partir sur le premier pilier qui est vraiment le pilier performance. Donc on va prendre du coup la performance commerciale. Aujourd'hui, vous avez des vrais enjeux d'amélioration du discours, de comprendre aujourd'hui ce qui est dit dans les échanges, d'amélioration aussi des réponses à des objections. Vous avez vraiment besoin d'avoir de la visibilité sur ce qui se passe dans les calls. Je ne me trompe pas, je suis fidèle. On est d'accord ? Ok, génial.
# - On va avoir surtout de l'information de ce qui se passe dans les calls.
# - Ok, et ce qui va se passer, c'est que par exemple, je vais prendre du coup des échanges qui ont eu lieu, par exemple, sur le quarter. Donc ce que vous pouvez voir déjà, c'est qu'il y a des tags en fonction de la typologie des échanges. Il y a effectivement des calls de qualification, de démos. Vous aurez des typologies d'échanges évidemment en fonction de votre cycle de ventre.
# - Comment ces tags sont mis en fait ?
# - Alors typiquement, là, c'est des appels, donc c'est des appels de prospection. Donc là, vous pouvez voir que c'est du cold call. Autrement, c'est l'intelligence artificielle.
# - Comment Modjo sait que c'est du cold call ?
# - Parce que c'est lié du coup à votre ringover ou à votre aircall ou à votre outil de VOIP. Ça remonte automatiquement ce tag.
# - D'accord, donc c'est sur ringover et il faut mettre la bonne information.
# - Quand tu raccroches… Ce qui a été dit.
# - Il y a deux choses en fait. Par exemple, il y a le nom du meeting. Vous faites une intro, l'intelligence artificielle va venir identifier la typologie de rendez-vous.
# - Donc là, par exemple, on a accès… Par rapport à l'intro qui a été faite, si tu présentes le produit, c'est que c'est un cold call froid. Si tu attaques directement sur une… Comme on s'est dit la dernière fois… C'est la même chose pour le démo.
# - Modjo sait à tous les coups classifier ses échanges.
# - Il sait classifier ses échanges. Alors là, qu'est-ce qui se passe ? Parce que j'ai mis tous les appels. Ça va pas aller. Attendez. Il sait classifier ses échanges. Ces échanges, pardon. Ça m'épette en fonction de la typologie des calls. Ça peut mettre deux, trois minutes. Par exemple, moi, j'ai une démo qui remonte. C'était une heure de démo. Le temps que la plateforme identifique, c'est une démo. Ça peut mettre deux, trois minutes à être taggé comme une démo. Mais effectivement, c'est l'outil qui vient le tagger. Là, par exemple, vous pourriez avoir accès à toutes les démos aujourd'hui qui ont eu lieu chez Modjo sur le mot. OK ? Est-ce que c'est plus clair pour vous déjà, ça ? Oui, oui, oui. OK, génial. Par exemple, ce qu'on voudrait faire, c'est regarder tous les échanges qui ont eu lieu sur ce quarter, par exemple, des discoveries. Parce que notamment, généralement, dans les discoveries…. Parce que je vous demande un exemple où on pitche Modjo. Dans les discoveries, c'est souvent des échanges où effectivement, il y a un pitch ou des objections qui reviennent régulièrement. Ce qui va se passer, c'est que du coup, là, déjà, vous avez accès à l'ensemble des discoveries qui ont eu lieu sur le quarter. Vous allez aussi pouvoir filtrer par équipe ou par user si par exemple, vous voulez coacher en particulier telle ou telle personne. Vous pouvez aussi vous dire, bon, bah moi, je voudrais regarder les meilleurs pitchs qui ont eu lieu ou les meilleures qualifications, les meilleures démos qui ont eu lieu aujourd'hui sur le quarter et qui ont abouti à une vente. Vu que c'est lié à un Hubspot aujourd'hui, vous allez pouvoir filtrer sur, par exemple, toutes les discoveries qui ont abouti à une vente aujourd'hui chez Modjo Donc, vu que c'est effectivement plugé à votre Hubspot, on vient récupérer des informations. Et là, typiquement, on a aujourd'hui neuf masterclass qui sont officiellement des très bonnes discoveries puisqu'en fait, aujourd'hui, ça aboutit à une vente. Est-ce que déjà vous voyez un peu l'idée d'aller chercher de l'information et cette idée d'entonnoir ?
# - Oui.
# - Super. Alors maintenant, je vais reprendre aussi un call de discovery. Et là, l'idée, du coup, vous voulez suivre finalement la manière dont est pitché aujourd'hui, dont est pitché Modjo en fonction, par exemple, selon vos interlocuteurs, selon les personnes qui aujourd'hui travaillent chez vous. Ce qui va se passer, c'est que du coup, vous allez pouvoir arriver dans un échange. Donc, qu'est-ce que je vais pouvoir prendre comme échange ? Par exemple, je vais prendre groupe Endless, donc une introduction que j'ai eue récemment avec un de mes prospects. Donc là, vous arrivez sur une fenêtre de réécoute d'appels. Vous avez énormément d'informations. Il y a les crescendo. Déjà, vous pouvez voir que directement, c'est lié à votre CRM. Nous, c'est Salesforce, mais vous aurez la même chose avec Hubspot. Vous avez la durée de l'échange. Vous avez la possibilité d'accélérer le moment de réécoute. Sélectionnez du coup que le speaker, si vous voulez réécouter qu'un speaker. Et même traduire et avoir les sous-titres pour être plus efficace dans le moment où vous réécoutez un moment d'appel. Une fois que je vous ai présenté cette fenêtre de réécoute d'appels, il y a un vrai sujet qui est aujourd'hui comprendre comment est pitché, comment est présenté aujourd'hui Modjo. Il y a une fonction, enfin Modjo pardon, excusez-moi, assez haut. Ce qui va se passer, c'est que du coup, avec les chapters, ça va vous permettre de découper déjà votre échange en plusieurs phases. Et déjà, ça va vous permettre de se focusser exactement au bon moment que vous voulez réécouter et challenger. Parce que toute l'idée, c'est de challenger vos sales sur justement leur manière de pitcher ou de répondre à des objections. Ce qui va se passer, c'est que du coup, là, on peut voir qu'à la minute, donc à une minute 15, je vais faire une présentation, du coup ma prospect coralie de Modjo Et ce qui va se passer, c'est qu'un manager aujourd'hui va pouvoir, attendez, hop. Un manager va pouvoir venir cliquer sur justement ce passage du call et pouvoir le réécouter. Est-ce que vous avez entendu le son ou pas ? Non. Non, OK. Écoutez, j'ai pas du… Mais ce qui va se passer, c'est que du coup, vous allez pouvoir réécouter juste le passage où effectivement, « tile size pitch Modjo », pitch à zéro. Donc l'idée, c'est qu'en fait, comprendre comment est pitché, comment est présenté aujourd'hui à zéro et du coup pouvoir challenger sur cet aspect-là du cycle de vente. Je ne comprends pas.
# - Qu'est-ce que vous apportez de plus que Ringover ?
# - Alors Ringover, déjà, il faut que tu sélectionnes tes appels un peu à l'aveugle, déjà. Deuxièmement, et tu ne peux pas venir focusser sur un aspect particulier de l'échange, enfin que ça soit une démo, du coup Ringover, ce n'est pas une démo, mais que ça soit… Tu ne peux pas focusser à un moment particulier de l'échange. Là, avec Modjo du coup, on va t'aider à justement pas avoir réécouter 10 minutes d'appels ou 29 minutes d'appels, mais réécouter finalement pile le moment qui paraît essentiel à coacher.
# - Ouais, OK. Sauf que…, juste le moment de l'objection ou le moment OK dans le sens où… J'ai envie de dire tout le moment de l'appel.
# - Tout le moment de l'appel est important ?
# - On a eu le chien de nos colocs qui est venu s'exploser contre la porte.
# - D'accord, pas de problème.
# - Pour montrer le pauvre Padi. J'allais dire, ouais, tout le moment de l'appel amène en partie à cette situation. L'appel en lui-même en complet est important. Par contre, effectivement, dans le cadre d'une objection auquel le sales n'arrive pas à répondre ou un manque de résilience, ça peut être intéressant, mais souvent ça se passe ça à la fin du call. Il y a rarement un truc qui se passe au milieu du call. Moi, clairement, aujourd'hui, quand on fait les appels et les écoutes ring-over, je réécoute rarement tous les appels. Je vais écouter les 30 dernières secondes. En fait, les 30 dernières secondes, tu vois là où ça décroche, tu vois là où le sales a manqué de résilience ou alors il a manqué d'argument. Il n'y a pas besoin. Et s'il n'y a même pas eu 30 secondes, là tu sais que c'est sur la manière de faire le discovery que le sales n'a pas été bon, il n'a pas suffisamment rentré. J'avoue que comme ça, je comprends l'idée. L'idée, même si du coup, je me dis que pour moi, soit ça se passe tout au début, soit ça se passe à la fin. Je vois rarement un élément qui se passe au milieu. À part une information importante, et là, le seul endroit où ça me paraît intéressant d'avoir ça, c'est que si vous avez une fonction compte rendu qui reprend tout et toutes les informations importantes du milieu comme de la fin, ça, ça peut être intéressant parce qu'on sait que les sales, ils font des CR où ils oublient des informations.
# - Oui, effectivement. Du coup, sur cette partie compte rendu, je vais te le montrer. Mais du coup, je vais peut-être prendre un exemple plus parlant sur un cold call. Là, ce que je voulais te montrer, c'était aujourd'hui, comment font les managers ? Ils vont réécouter des moments de présentation de pitch pour pouvoir savoir comment Celeste, comment Charles, comment X ou Y personne, pitch Modjo RoundTable, et savoir justement où est-ce qu'il faut l'améliorer. Il y a cette première aspect, mais du coup, par exemple, si on part justement sur la partie objections, on va prendre par exemple des exemples de cold call. Aujourd'hui, tu vas pouvoir filtrer sur tous les appels où il y a eu des objections. Soit tu veux traquer un sujet en particulier, tous les appels où on a abordé telle ou telle offre, ou les appels où il y a eu des objections, ou des appels où on a partie de concurrence. Ça dépend de quels sont les sujets que tu veux traquer. Par exemple, je prends les appels où il y a eu des objections. Et par exemple, je prends les appels de Caradoc, qui est un de nos nouveaux arrivants et qui a souvent des objections dans ses appels. Ce que je vais faire, c'est que ça te permet déjà d'identifier concrètement où est-ce que des objections ont été abordées. Si je prends un exemple, du coup, de… Ça, c'est quoi le pourcentage de précision ? C'est-à-dire ?
# - Les objections, comment on va parler d'algorithme, est-ce qu'à 98%, toutes les objections sont bien remontées, sont bien détectées ?
# - En fait, c'est paramétré lors de la mise en place de Modjo. Par exemple, si tu veux traquer tous les sujets où ont été apportés par exemple des concurrents, grâce au paramétrage, on va pouvoir créer un… On appelle ça un Topix, mais en gros un champ l'écritacle autour de ce sujet-là. Et du coup, on va flagger des mots qui ont été abordés dans le call. Et du coup, ça, c'est l'IA qui identifie que, OK, on a parlé de tel concurrent, on a parlé du mot concurrence. Et ça, pour le coup, c'est 100% fiable, vu que tout dépend du transcript. Mais pour le coup, on a une équipe de data scientists qui travail sur le transcript. Et du coup, aujourd'hui, en termes de qualité, c'est exactement pour ça que des équipes sales font appel à nous. Et autrement, c'est juste l'intelligence artificielle qui le reconnaît dans le discours. Donc ce que je voulais vous partager, par exemple, je prends un appel de prospection qui a été perdu aujourd'hui. L'IA, ce qui permet d'identifier, comme je vous disais, c'était l'objection. Donc tu peux identifier différents sujets. Donc là, par exemple, c'est objection. Là, le manager, ce qu'il va faire, c'est du coup, il va juste venir réécouter ou d'ailleurs juste lire, réécouter ce passage, ce passage et réécouter aussi son size pour voir comment il y a répondu. Là, tu vois, l'objection, elle n'est pas du coup, il y en avait aussi une à la fin, mais l'objection, elle est, on peut l'identifier, la flaguer directement. Du coup, l'idée, c'est pas que tu réécoutes 7 minutes d'appel, mais c'est bien que tu réécoutes potentiellement que cette partie là de l'appel. OK. OK. Donc ça, il y a sa première aspect là. Donc déjà, c'est l'IA identifie des sujets abordés. Le deuxième point, c'est qu'en fait, c'est aussi, c'est évidemment un noté de coaching. Donc là, tu vois, en fait, Catalin, il est venu taguer son manager parce qu'il a besoin d'être sur ce call là. Il va venir taguer son manager et son manager va pouvoir faire une review, donc des feedbacks formalisés, concrets pour justement coacher son sales, son BDR. Pour ça, on a une fonctionnalité qui s'appelle du coup la review, pardon, qui permet en fonction effectivement de la typologie de call de finalement noter, apporter une grille lecture à ton à ton size pour qu'il puisse comprendre ses axes d'amélioration et pouvoir revenir aussi sur ce qui est les feedbacks de son manager. Au lieu que ce soit des feedbacks qui soient faits à la volée et que ça soit entre guillemets un peu oublié et du coup qu'il puisse finalement revenir sur son call. Comment ça se matérialise? Je vous montre. Ça se matérialise de cette manière là. Donc là, typiquement, à la fin, tu as une petite note et du coup le manager là aujourd'hui, Gabriel, il a pu venir réécouter ce call où son manager l'a identifié à telle minute et pouvoir prendre des notes et du coup l'accompagner justement dans sa réponse à des objections. Qu'est ce que tu en penses de ça?
# - Ça apporte de la précision sur ton appel et pour le retravailler derrière. Ça, c'est sûr. La question que je te poserai à la fin de la réunion, c'est aujourd'hui, comme tu connais notre contexte, est ce que c'est un outil qu'il faudrait mettre en place ou est ce qu'il faut attendre que nous, on soit plus carrés pour après améliorer quelque chose sur un socle propre?
# - Aujourd'hui, ce que vous me disiez, c'est que vous aviez besoin justement de comprendre un peu les pitches, les réponses à des objections, tester, challenger. La l'idée de cet outil, c'est justement vous donner les moyens de réécouter, challenger, avoir du feedback, comprendre comment réagissent votre prospect aux fonctions de par exemple, quand on pousse telle ou telle offre, par exemple, pourquoi vous avez aujourd'hui un sales qui pousse, enfin, pourquoi vous avez un sales par exemple qui pousse quatre offres de marque blanche et pourquoi il y en a un qui arrive à en pousser qu'une? En gros, c'est comprendre la différence de discours, comment y répondre aux objections. Sans un outil comme ça, c'est beaucoup plus compliqué à suivre, analyser, challenger, faire du feedback en tant que manager.
# - Après, je pense que aujourd'hui, moi, ce qui m'interpelle avec Modjo c'est le temps que ça doit prendre un manager de faire ce travail là. Ça, c'est le premier point. Je t'avoue que là, comme ça, à chaud, je n'identifie pas trop la différence de temps entre les écoutes Ringover et Modjo. Je n'ai pas le sentiment, moi, je me connecte à Ringover. J'écoute les appels, Merlin peut le faire. On a les appels qui sont dans Hubspot. J'ai du mal à voir à quel endroit vous faites gagner du temps à ce niveau là. Ce qui est sûr, c'est que pour écouter l'appel, il faut prendre du temps. Moi ou Merlin, si on veut écouter les appels, il faut qu'on se mette et qu'on s'assoit et qu'on se dise pendant 30 minutes, on fait des coups de l'appel et qu'on soit sur Ringover ou que ce soit sur Modjo Dans tous les cas, il faut prendre les 30 minutes. Donc après, tu as le fameux sujet où tu dis que vous vous isolez, etc. Mais comme je t'ai dit, pour moi aujourd'hui, j'ai une manière d'isoler parce que quand tu connais un peu la structuration des appels, tu sais que tout se passe au début, voire à la fin. La notion de commentaire, je trouve ça intéressant, mais je vais du mal à comprendre en quoi ce n'est pas un doublon par rapport à Hubspot où tu as ta ligne avec ton call écouté. En fait, tu peux faire un commentaire dessus si tu as écouté en disant ton Sales il dit, il tag Merlin, il dit Merlin, ce call là, j'ai eu des problèmes. Moi, je le réécoute et je lui dis, en gros, je trouve l'UX et la manière dont c'est disposé plus sympa que sur Hubspot dans les faits, ce que je vous accorde. Pour moi, vous venez faire mieux que Hubspot quelque chose qu'ils essaient de faire aussi. Mais il va falloir qu'on rationnalise notre décision car ça a un coût supplémentaire.
# - Ok, alors du coup, je fais mon mea culpa parce que je pense que je n'ai pas été assez pertinente dans ma présentation. Première chose, c'est que déjà, c'est pas que pour challenger les calls, mais du coup, vous avez un sujet aussi sur la partie démo et du coup, c'est vraiment un outil global. Le deuxième point que je peux partager, c'est qu'aujourd'hui, toutes les équipes qu'on accompagne sont sur du Hubspot téléphonie et par exemple, ou sur du aircall et par exemple, toutes les équipes d'aircall aujourd'hui n'utilisent absolument pas les enregistrements aircall pour réécouter leurs équipes. Pourquoi ? Parce que justement, ils ont besoin absolument de gagner du temps et du coup, tu me disais, ben en fait, je vois pas en quoi ça me fait gagner du temps. Là, l'idée, c'est qu'effectivement, tu puisses vraiment te focuser sur les, enfin sur tous les appels où il y a tel ou tel sujet qui ont été abordés et en fait, pas par un, c'est vraiment industrier. T'as ton process de réécoute aujourd'hui au lieu de...
# - C'est juste, je rebondirais sur la question et je pense que, alors je sais pas, on ne s'est pas parlé, mais je pense que, en fait, dans la question, c'est est-ce que nous, on n'est pas trop petit aujourd'hui et on n'est pas trop dans un stade de croissance et de manque d'industrialisation pour prendre un Modjo. Je comprends tout à fait Modjo dans un, tu dis, Hubspot, Hubspot l'utilise et tout, une grosse boîte qui a déjà, qui a déjà ranqué, qui a déjà staffé avec différents niveaux. Je comprends tout à fait l'outil, mais là, nous, à l'instant T, moi, j'ai l'impression que ça prend beaucoup de temps. Et effectivement, je rebondis sur la question posée dans le sens où, à quel moment c'est opportun de le prendre ? Parce que là, c'est vrai que moi, comme ça, à chaud, je pense que ça me paraît très très lourd pour nous. Notre première problématique, c'est le manque de temps. Et en fait, en voyant tout ce que Modjo fait, c'est très bien, mais en gros, c'est encore du temps à prendre.
# - Ok, merci pour ces infos. Toute l'idée, c'est d'un Modjo c'est de faire gagner du temps. Donc effectivement, si tu ne l'ai pas présenté de la manière à aujourd'hui, ça te permet de faire gagner du temps. Je comprends que ça te paraisse pas cohérent. Concrètement, un Modjo au contraire, c'est absolument pas pour les, c'est vraiment pas pour des équipes qui ont déjà squelé, qui ont déjà industrialisé leur process. Pour la petite info et justement pour du SquareChair qui était au démarrage ou même Planity qu'on accompagnait quand ils étaient 4 sales. C'était vraiment pour justement leur donner des bies sur comment mettre en place des process. Une fois que les process sont mis en place, on n'a absolument pas besoin d'un outil justement d'aide à la mise en place de process. Donc c'est vraiment pour le coup, pour aider à processer plus la partie coaching, pour aider à processer toute la partie CRM que je vais vous montrer, pour aider à processer toute la partie onboarding, avoir un outil qui compile toute cette base de connaissances et de performances. Et c'est un outil à la fois côté manager parce que l'idée c'est de gagner du temps sur les aspects où ils vont coacher individuellement les reps. Et après du côté sales ou CSM, c'est aussi un outil pour s'améliorer, se réécouter, demander du feedback à son manager sans attendre des one one ou des workshops qui arrivent au fil de l'eau, mais qui sont du coup plus occasionnels.
# - Moi en tout cas, je comprends effectivement l'utilité d'un outil avec justement cette analyse qui permet de bien découper. Et je pense que c'est dans ta deuxième partie de présentation. Qu'est ce qui peut ou Modjo peut nous challenger?
# - Est ce que tu peux préciser cette question?
# - Alors c'est peut être moi qui n'avais pas compris tout le permettre de l'outil. Là, le fait d'analyser les séquences et de dire ce que tu as montré tout à l'heure, effectivement, c'est super pertinent. Et à la fois pour quelqu'un qui analyse, comme tu dis, il peut aller directement à l'essentiel, tout est trié, tout est catégorisé. Donc ça, c'est top. Mais je pensais qu'il y avait aussi une analyse où il y avait un challenge sur comment la présentation était faite, comment le pitch commercial était fait. Mais encore une fois, je suis peut être gouré dans l'interprétation de ce type de plateforme.
# - Non, non, je te confirme que nous, j'avais compris comme toi, dans le sens où on pensait que l'IA, on allait rentrer un pitch, un sorte de script de base, un template. Et l'IA, elle devait dire si le script a été respecté ou pas.
# - Respecté sans forcément avoir cette notion là, mais nous challenger dessus par rapport à l'IA, à toutes les possibilités de l'IA pour améliorer notre pitch en nous faisant des propositions d'amélioration.
# - OK, alors effectivement, aujourd'hui, l'IA ne va pas vous pousser du contenu. Par contre, elle vous permet d'identifier aujourd'hui quelles sont les bonnes pratiques. Donc, par exemple, si on reprend par exemple de la démo, c'est effectivement vous dire, vous dire écoutez aujourd'hui une bonne démo. C'est une démo qui a été gagnée et du coup vous permettent justement de identifier un peu le on va dire le déroulé, l'aménagement clôture du bon démo et d'un rendez vous. Et c'est réécouter aujourd'hui justement cette manière de faire pour la partager. Une fois qu'on l'a identifié, vous allez pouvoir le partager. Donc ça, c'est quelque chose, une fonctionnalité que je ne vous ai pas montré, mais vous allez pouvoir partager à votre équipe en disant super réponse ou manière de faire. Et vous pouvez aussi ou alors tout simplement venir taguer une équipe produit en disant ça, c'est un super retour. Retour client et il faut qu'on le mette en place dans notre roadmap d'évolution. Donc c'est un outil qui vous permet à la fois de partager des bonnes pratiques et de partager en interne des informations. Il y a cet aspect là et il y a aussi cet aspect où aujourd'hui, par exemple, ça, c'est une super bonne démo. Vous allez pouvoir l'enregistrer dans enregistrer une réponse à une objection dans une librairie, dans une c'est un csm, je ne sais pas comment vous appelez ça, csm répertoire des bonnes pratiques d'onboarding. Et sur aujourd'hui, c'est une super bonne réponse à des objections. Je veux le graver, par exemple, j'ai une trop petite équipe, je veux le graver dans la roche, je l'ajoute à une librairie et du coup, j'ai un contenu actionnable pour justement former un bordé, mes nouvelles recrues. Donc ça aujourd'hui, Modjo peut vous challenger parce qu'il permet d'identifier aujourd'hui quelles sont les bonnes pratiques. Tout à l'heure, vous parliez justement du fait d'avoir d'avoir un peu un template de un template de rendez vous. Aujourd'hui, il y a une autre fonctionnalité, donc c'est pour faire le lien avec ce que vous vous partagez. Il y a une fonctionnalité qui s'appelle la live note. Cette petite live note, c'est justement un template aujourd'hui d'un fil rouge ou de questions que vous voulez que vos équipes abordent avec vos prospects. Vous vous avez vous parliez de plusieurs scénarios. Aujourd'hui, par exemple, si on prend une qualification de discovery chez Modjo cette live note permet justement d'un nouvel arrivant d'avoir un peu la nomenclature d'un rendez vous d'un beau rendez vous. Aujourd'hui, quelles sont les bonnes informations qu'il faut que je récupère? Comment je pose des questions? Comment je piche? Et aussi pour remplir automatiquement certains champs CRM pendant le pendant l'échange. Ça, c'est quelque chose qui vous permet justement d'avoir ce template de rendez vous et en amont d'un échange, s'assurer que finalement la bonne pratique est respectée et que votre site est en tête. Qu'est ce que vous en pensez de cette fonctionnalité?
# - Oui, oui, ça, c'est bien. Après, peu importe l'outil, j'ai envie de te dire que ce soit un Hubspot ou autre. Il faut que il faut que l'équipe joue le jeu pour pour que toutes les données soient le plus le mieux rempli possible. En tout cas, là, t'as des mots pour la question.
# ...
# - Merci pour ton soutien.
# - Je ne sais pas pourquoi on discute, mais c'est quoi le budget?
# - Ok, donc on parle du budget avant même de parler de VA.
# - De quoi?
# - De valeur. Non, mais je voudrais juste savoir en termes de valeur. Aujourd'hui, si c'est 0 euros ou même 10 balles, est ce que tu le prendrais cet outil? Est ce que tu penses que ça répond à tes peines? Parce qu'en fait, si ce n'est pas le cas, effectivement, 0 euros ou 1 euro, je le prends Celeste. Ok. Et 1000 euros?
# - Non. Juste pour compléter ce que dit, moi je trouve que c'est un outil qui manque et fort, d'autant plus avec les features dont tu nous as parlé juste avant là, et qui je pense va évoluer encore. Donc c'est sûr que c'est un très bon outil à voir. Aujourd'hui, nous, on est dans une phase où le budget est quand même ricrac. Aujourd'hui, on a deux outils qui nous goûtent une blinde. C'est Intercom et Hubspot. Je n'en parle même pas. Donc là, de se remettre 1000 euros mensuel, clairement, non. 500 euros, je te dis qu'on n'y arrivera pas non plus. Donc je ne sais pas du tout après quel est le facteur de prix, mais c'est sûr que nous aujourd'hui, on ne pourra pas. À l'instant, on ne pourra pas.
# - Ok. En termes de user, du coup, on parlait de quoi?
# - Vous m'avez dit 4, 5, 6, 7, 5, 6, 7. On mettrai que l'essai pour le moment. Donc c'est 3, 4 personnes. 4 personnes, Merlin en écoute, en analyse en manager.
# - Sachant qu'Merlin, aujourd'hui, je crois que tu fais des calls. Tu me disais que tu poussais encore. Donc tu imagines que tes pratiques commerciales, elles sont quand même, c'est censé être des références pour les nouveaux arrivants et les alternants.
# - Donc typiquement, j'appelle avec mon téléphone. J'appelle avec une ligne classique.
# - Tu n'appelles pas avec du coup un Hubspot ou un Ringover?
# - Non. Mais bon, je pourrais. Mais c'est vrai que tu vois, on a fait un challenge prospection hier et en fait, on s'aperçoit que j'ai un taux de réponse qui est vachement plus élevé que moi. Je tourne à 70% de réponses à mes appels, alors que les sales que RingGover, ils sont à 20. Et en fait, la seule différence, c'est que j'utilise une ligne orange.
# - Et parce que RingGover, ils sont sur un 0?
# - Non, ils sont sur un 0755. Mais il paraît qu'aujourd'hui, les 0755 et 0765, ils sont identifiés comme ça.
# - OK. Eh ben écoute, c'est la première fois que j'entends ça.
# - Bah écoute, tu vois, on l'a vu hier, les pauvres, ils étaient frustrés. Du coup, ils ont perdu le challenge.
# - Mais c'est pas sympa. Ça, c'est toi qui a gagné le resto. OK. Oui, bon, du coup, pour revenir. Pour revenir au sujet, du coup, ça sera entre 4 et 5 licences, enfin, ou 4 licences.
# - Si le manager est compris dedans, ça serait 5.
# - OK. Mais du coup, toute la partie, donc ça serait que sur la partie call, pas du tout sur la partie vidéo.
# - Alors la partie vidéo, elle est faite plus par les CSM. Donc dans un deuxième temps, parce que ça, c'est pas aujourd'hui, c'est pas le gros du sujet.
# - Bah du coup, sur la partie aujourd'hui, du coup, notre business model. Du coup, notre business model, c'est à la licence enregistreuse. Donc, c'est toutes les personnes qui importent de la matière des enregistrements dans Modjo Donc là, ça serait les 4, 5 personnes côté sales. On a un business model où aujourd'hui, du coup, c'est un engagement annuel. Et du coup, le prix à la licence, le prix d'entrée, c'est de 99 euros par licence enregistreuse. Il y a des leviers de négociation, évidemment, possibles en fonction des marges de manoeuvre que vous pouvez avoir. Mais aujourd'hui, du coup, c'est 99 euros par licence par mois.
# - Nous, on n'a pas de marge de manoeuvre. C'est toi, éventuellement, tu en as. Mais nous, on n'en a pas.
# - Mais tu imagines bien que si on fait des discounts, il y a forcément des contreparties. Tu dois être meilleur sales que moi. Et du coup, j'imagine que tu as l'habitude de négocier. Du coup, les contreparties, c'est la vélocité en termes de la vélocité en termes de signature, la durée d'engagement et la possibilité aussi de nous faire des introductions auprès de CEO, VP sales, manager sales qui auraient justement les mêmes problématiques, les mêmes enjeux aujourd'hui que vous ou que en tout cas, qui répondraient dont Modjo répondrait en termes de valeur.
# - Et du coup, pour les trois introductions, combien je gagne ?
# - 5 %. Mais alors aujourd'hui, non, mais écoutez, aujourd'hui, là, le tout, enfin, le sujet de cet échange, c'est du coup de faire une démo et de valider aujourd'hui la valeur et de vous présenter le business model. Moi, ce que je voudrais faire, c'est vous, du coup, vous partage, enfin, vous faire une offre tarifaire personnalisée. Justement, qu'on voit aujourd'hui les leviers de négociation que vous seriez, enfin, qu'on pourrait activer, actionner, pardon, pour effectivement réduire ce prix à la licence. Du coup, moi, ce que je voudrais vous proposer, c'est plutôt un call d'offre tarifaire parce qu'aujourd'hui, c'est comme ça qu'on fonctionne et comme ça, ça nous permettrait d'avoir plus de temps justement sur l'aspect ROI et budget. Je sais pas ce que vous en pensez.
# - Ouais, alors moi, je veux juste te donner une autre information. On a 18 mois pour performer. Voilà. Donc, tout budget supplémentaire qui arrive dans ces 18 mois, il faut qu'il soit justifié ou alors avoir un discount comme Hubspot va nous faire là, même si c'est un discount, il y aura des bananes qui nous font.
# - Aujourd'hui, de toute façon, Modjo c'est pas un outil qui est mis en place parce qu'il n'y a pas de ROI. Et le ROI ne serait-ce qu'en termes de taux de conversion, si je reste juste sur le taux de conversion et pas le temps économisé et bref et pas mal d'autres aspects. Aujourd'hui, le ROI, c'est plus 20% sur le taux de conversion dans les équipes aujourd'hui qui sont équipées d'un Modjo versus avant avant mise en place d'un Modjo Donc, c'est pour ça que quand tu parlais de coûts tout à l'heure, il faut vraiment voir ça. En fait, aujourd'hui, combien ça peut vous rapporter versus combien ça va vous coûter. Et du coup, c'est tout l'idée d'un prochain échange, c'est de justement voir combien ça pourrait vous rapporter aujourd'hui. Mais du coup, aujourd'hui, quand tu me parlais d'enveloppes budgétaires, tu en as une ou dans tous les cas, vous n'en avez pas?
# - On en a une. Oui, on en a une après de donner un montant exact. J'en serais incapable. En tout cas, c'est sûr que c'est un montant qui est vraiment minime. Je te dis avec Hubspot, on est en train de négocier à 200 euros près. Donc, tu vois, on en est rendu.
# - OK. Et du coup, là, je te partageais juste.
# - C'est normal de négocier Hubspot, vu ce qui nous prenne 200 euros, c'est de survoir un point. Aujourd'hui, on n'a pas de. Ce n'était pas prévu. On a obligatoirement le besoin d'un e-media. Faut voir le ROI. C'est ce que tu as expliqué. Tu as répondu à deux, trois de me pain. Ça donne. Non, ça donne une bonne vision. Fais nous une offre du coup avec. Avec la meilleure offre que tu peux faire. Et puis, on regardera ça. Là, il faut vraiment qu'on coupe parce qu'il faut que l'on enchaine. C'était intéressant. C'était intéressant. Donc, je te remercie pour ton temps.
# - Juste sur quoi tu as un doute du coup? Ce que tu m'as dit deux, trois pain, ça veut dire qu'il y en a au moins une auxquelles on n'a pas répondu.
# - C'est pas que vous n'y répondez pas. C'est que, en gros, je ne sais pas si votre... Déjà, j'ai identifié des bonnes pratiques. Donc, merci. Du coup, je vais dire à mes six de faire certaines choses avec maintenant pour à être Hubspotté qui est un peu du Modjo Ça, c'est métier pour rien dans le sens où c'est. C'est j'allais dire, ça fait partie des choses. Vous faites mieux quelque chose que ce qu'est capable de faire en fait concrètement. Mais vous faites beaucoup mieux. Encore une fois, lui, c'est très sympa. C'est vrai que, par contre, à l'instant T, il y a. Je pense des choses qui sont permises par votre outil qu'on peut faire de manière un peu différente avec des outils un peu. On peut bricoler quoi. Après, le bricolage, ça reste du bricolage. Soyons, j'en ai conscience. Mais bon, à voir après, faites nous une bonne offre et puis on rediscute. La notion des CR, c'est un sujet. Vous avez l'air de le faire. La notion de la synthèse d'analytics à la fin, j'aime bien. Donc, live note aussi.
# - Tu as bien aimé la live note.
# - Voilà, deux, trois pains. En règle générale, je perds pas le temps. Mais, mais, mais, on va voir ton offre. Et derrière, nous, on va rediscuter en interne. Mais évidemment, effectivement, du budget, il n'y en avait pas de base. Faut voir le ROI. Par contre, clairement, à 1000 euros et 1000 euros ou 500, je suis d'accord avec Antoine. On n'ira pas.
# - Par mois. Oui, on y va. Là, de toute façon, là, du coup, ce que je vous disais, c'était cinq users à 99 euros. Le prix de base, c'est du coup, ça ferait un 495 de mémoire sans levier d'action.
# - Voilà, je pense que comme t'as beaucoup de levier d'action, je pense que tu vas actionner plein de leviers pour que ce soit potentiellement.
# - Bah, écoutez, dans ce cas là, prenons nous un créneau parce que je sais que votre temps est compté. Et du coup, ce que je vous propose, c'est qu'on se prenne un créneau pour vous présenter l'offre.
# - Au pire, tu nous refais un mail et tu nous redis ou tu nous envoies ton calendrier. On prend le calendrier.
# - C'est pas plus simple de croiser nos agendas maintenant.
# - Non, mais je vais gérer le troisième rendez-vous.
# - Voilà, parfait. OK, super.
# - Allez, ça marche. Merci à tous les trois. Je reste le Celeste juste pour finir. Oui, ça marche.
# - Merci. Merci Antoine. Donc, Celeste, oui, encore une fois, outil très intéressant. J'avais une autre question au niveau du on boarding. Comment ça se passe chez vous?
# - Oui, alors du coup, en termes d'onboarding, du coup, effectivement, Modjo c'est 70 80% la plateforme. Mais c'est surtout que vous avez un accompte manager, donc un consultant qui est là pour vous accompagner de la paramétrage. L'onboarding jusqu'à la fin d'utilisation de Modjo Donc ce que je veux dire, c'est qu'en termes d'onboarding, il y a effectivement un onboarding manager, un onboarding équipe qui est qui est prévu en plus du paramétrage. Et ensuite, tout au long de l'utilisation, vous avez un consultant qui est là pour vous partager des tips marché, comment améliorer votre productivité, comment mieux coacher vos équipes, comment les sales peuvent être plus utilisé Modjo Et donc, ça, c'est tout ça, c'est pris en compte dans le prix de la licence du coup enregistreuse. Donc, en fait, il n'y a aucun coût additionnel par rapport à ce que je vous présenterai. Est ce que je vous ai présenté ne serait ce que les 495 euros. Vous avez vraiment un compte manager qui est dédié. Et on a notamment des gens qui sont qui sont qui sont experts sur des secteurs. On accompagne pas mal de saas dans justement le domaine de la chevalerie comme Gymlib, qui est notre premier premier client aujourd'hui. Ils étaient que trois à l'époque et tu vois maintenant à la taille de Gymlib Gymlib.
# - Ah c'est Gymlib.
# - Voilà, donc tu vas très bien connaître. Donc tu vois, ça, c'était un de nos premiers clients. Et vraiment, encore une fois, ils n'ont pas du tout mis en place Modjo quand ils étaient Gymlib de maintenant. Ils sont une armée de ça. Ils l'ont mis en place au démarrage où justement ils avaient besoin de gagner en temps à comprendre exactement les besoins du marché, comment pitcher leurs équipes, comment ils répondaient aux objections et justement passer d'un mode un peu bricolage artisanal à un mode crescendo beaucoup plus processé pour aller chercher des parts de marché, pour aller chercher de la productivité, pour faire en sorte que leur leur junior arrive très rapidement au niveau d'un justement Antonique cofondeur qui, évidemment, est le meilleur sales aujourd'hui, mais que lui se détache progressivement du coup de la vente pour avoir des sales qui prennent le relais. Donc c'est tout l'idée d'un Modjo aujourd'hui.
# - OK, OK, OK.
# - J'ai bien répondu à ta question.
# - J'avais saisi effectivement ça. Et sur les évolutions du produit, est-ce qu'on reste sur le même prix ou est-ce qu'on va être bloqué? Si on veut passer à des évolutions là dans tu dis dans un mois là, est-ce que c'est un complémentaire?
# - Non, effectivement, il y a absolument ce qui est signé restera signé. Ce que je veux dire, c'est que c'est notamment la fonctionnalité dont je t'ai parlé. Tu vas en bénéficier. On n'a pas de coût supplémentaire en fonction des features que tu choisis. Tu auras accès à toutes les nouveautés. Bref, à tout.
# - Parce que je te dis ça parce que Intercom, par exemple, qui est un excellent outil, il sort des fonctionnalités régulièrement et il y en a qui ne font pas partie du scope. C'est des modules en fait additionnels. C'est pareil avec des ardoises qui sont colossales pour des boîtes comme nous. Même si c'est des outils qui sont très pertinents. Donc voilà, nous, ce que je peux juste te dire, en tout cas, c'est que on est prêt à s'engager. En tout cas, sur les 18 prochains mois avec un tarif très très préférentiel. Très sincèrement et après, continue avec vous. Il n'y a pas de raison à ce que, en tout cas, moi, je crois en cet outil là. Ce n'est pas le problème. Aujourd'hui, nous, le frein, c'est à la fois le tarif et un frein mineur. C'est ça, il faut qu'on en discute en interne. C'est le temps à accorder après sur cet outil là. Si c'est pour avoir un outil pour dire qu'on a Modjo mais derrière qu'on ne l'exploite pas. Parce que aujourd'hui, on a des outils qu'on n'exploite pas comme il se devrait, comme il devrait. Ça ne nous servira à rien. Mais ça, c'est plus surprenant à se mettre d'avis.
# - OK, effectivement, après, tu vois, sur la partie productivité, notes. Aujourd'hui, du coup, c'est l'IA qui fait tout. Et donc, pour le coup, ça remonte directement dans ton Hubspot. Donc, en fait, de toute façon, les calls, ils sont enregistrés. Donc ça, de toute façon, on va dire que vous avez entre guillemets plus la main mise sur est-ce que mon IA prend des notes. De toute façon, elle prendra les notes. Et sur la partie du coup réécoute. Pour moi, c'est on vient pas modifier vos routines, ce qui est mis en place par Merlin, ce qui est mis en place par Arthur, peut être sur toi, sur la partie management des équipes CSM. On vient juste vous faire gagner du temps d'écoupler votre force de coaching et surtout donner les moyens à des sales aujourd'hui ou des CSM de s'améliorer. Et du coup, aujourd'hui, honnêtement, en termes de connexion, c'est évidemment qu'il y a des managers. Mais en fait, aujourd'hui, c'est un outil. Il y a des équipes aujourd'hui qui font des sales aujourd'hui qui demandent de leur de leurs entretiens. Est ce que vous avez Modjo ? Parce qu'en fait, ça leur simplifie à mort la vie. La dernière fois, on avait parlé du fait que vous ayez des grands comptes et six mois de cycles de ventes. Si je ne m'abuse, justement, un outil comme ça, ça te permet de revenir sur tes échanges, de te remettre dedans, de préparer des rendez-vous, être beaucoup plus pertinent. Et en fait, c'est vraiment comment dire? C'est en fait, ça devient indispensable pour les équipes. Du coup, en termes d'usage, je comprends effectivement le côté. On n'a pas envie de mettre en place un outil pour un outil. Mais alors là, pour le coup, moi, je sais que tu vois le jour où je bosse de Modjo je sais que je veux une équipe, une boîte où il y a un Modjo aujourd'hui. Parce que moi, je m'y imagine pas repasser à des tâches manuelles, revenir sur des enregistrements pour me préparer. Ça me paraît aberrant de faire ça. Voilà, voilà. Écoute, ce que je te propose, c'est qu'on se prenne un petit créneau du coup, effectivement, pour la partie tarifaire.
# - Oui.
# - Qu'est ce que tu penses? Moi, j'ai un créneau demain si tu veux ou autrement lundi.
# - Lundi, ce sera mieux. Lundi, lundi, lundi.
# - Qu'est ce que c'est?
# - Lundi 16h30.

# %%
import configparser

# import openai
from langchain.text_splitter import RecursiveCharacterTextSplitter

# from langchain.llms import OpenAI
from langchain.chat_models import (
    ChatOpenAI,
)  # bug with langchain_openai library on my machine
from langchain.chains.question_answering import load_qa_chain
from langchain.schema import Document

config = configparser.ConfigParser()
config.read("config.cfg")
OPENAI_API_KEY = config["OPENAI"]["OPENAI_API_KEY"]
# openai.api_key = OPENAI_API_KEY

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_text(textified_conversation)
documents = [Document(page_content=text) for text in texts]
# llm = OpenAI(openai_api_key=OPENAI_API_KEY)
llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")
qa_chain = load_qa_chain(llm, chain_type="map_reduce")

question = """Provide a summary in maximum 60 words of what happened during the call, given the transcript provided. Use the language of the transcript for summarization"""
answer = qa_chain.run(input_documents=documents, question=question)
print(answer)
# Out:
# c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# During the call, the participants discussed the benefits and implementation of Modjo, a tool for transparently sharing interactions with prospects and clients. They emphasized the importance of improving commercial performance, enhancing discourse, tracking sales activities, and using AI for note-taking and coaching. The speaker mentioned budget limitations and negotiations, the onboarding process, and scheduling a meeting for further discussion.

# %%
# Checking that the 60 words condition is respected
len(answer.split(" "))
# Out:
# 59

# %%
# # Trying directly though a prompt template
# from langchain.chains.llm import LLMChain
# from langchain.chains.combine_documents.stuff import StuffDocumentsChain
# from langchain_core.prompts import PromptTemplate
# query_template = f"""
# Write a concise summary of the following text, in fewer than 60 words using the same language as the original text which is here below:
# "{textified_conversation}"
# consise summary:
# """

# llm_chain = LLMChain(llm=llm, prompt=PromptTemplate(input_variables=[textified_conversation], template=query_template
#         ))
# result = llm_chain.run("summary")

# # failure: too long text?

# %%
# Problem using jq library on windows... Hence using own definition of the JSOLoader following https://github.com/langchain-ai/langchain/issues/4396
import json
from pathlib import Path
from typing import Callable, Dict, List, Optional, Union

from langchain.docstore.document import Document
from langchain.document_loaders.base import BaseLoader


# def organize_json(json_dict):
#     out = ""
#     tmp = ""
#     previous_speaker = ""
#     for block in json_dict["segments"]:
#         speaker = block["speaker"]
#         if speaker == previous_speaker:
#             tmp += " " + block["content"]
#         else:
#             out += tmp
#             tmp = "\n- " + block["content"]
#             previous_speaker = speaker
#     return out


class JSONLoader(BaseLoader):
    def __init__(
        self,
        file_path: Union[str, Path],
        metadata_func: Optional[Callable[[dict, dict], dict]] = None,
    ):
        """
        Initializes the JSONLoader with a file path, an optional content key to extract specific content,
        and an optional metadata function to extract metadata from each record.
        """
        self.file_path = Path(file_path).resolve()
        self.metadata_func = metadata_func

    def create_documents(self, processed_data):
        """
        Creates Document objects from processed data.
        """
        documents = []
        for item in processed_data:
            content = item.get("content", "")
            metadata = item.get("metadata", {})
            document = Document(page_content=content, metadata=metadata)
            documents.append(document)
        return documents

    def process_json(self, data):
        """
        Processes JSON data to prepare for document creation, extracting content based on the content_key
        and applying the metadata function if provided.
        """
        processed_data = []
        for item in data["segments"]:
            content = item["content"]
            metadata = {"speaker": item["speaker"]}
            processed_data.append({"content": content, "metadata": metadata})
        return processed_data

    def load(self) -> List[Document]:
        """
        Load and return documents from the JSON file.
        """
        docs = []
        with open(self.file_path, mode="r", encoding="utf-8") as json_file:
            try:
                data = json.load(json_file)
                processed_json = self.process_json(data)
                docs = self.create_documents(processed_json)
            except json.JSONDecodeError:
                print("Error: Invalid JSON format in the file.")
        return docs

# %%
# Trying directly with the full json and appropriate langchain tools
# from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(file_path="demo-segments.json")
docs = loader.load()
docs
# Out:
# [Document(page_content='Oui bonjour Celeste.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Bonjour Merlin. Comment vas-tu ?', metadata={'speaker': 'spk0'}),
#  Document(page_content='Très bien et toi ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Super. Écoute, ça va super. Je suis ravie de commencer mon après-midi avec toi. Je vois que la caméra n'a", metadata={'speaker': 'spk0'}),
#  Document(page_content="pas été réparée. Je sais pas si t'es tout seul ou t'es avec...", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, là je t'avoue que avec le gros brume que j'ai...", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ah oui ! Ok, pas de problème. Non, mais je ne savais pas si du coup, Arthur et l'autre Merlin", metadata={'speaker': 'spk0'}),
#  Document(page_content="se connectaient derrière toi ou s'il y avait d'autres personnes qui arrivaient.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, alors Merlin, je ne sais pas, mais Arthur, ben voilà, il est là, parfait.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Ben voilà. Bonjour Arthur, enchanté. Salut Arthur.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Je suis là, bonjour Celeste.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Ah c'est Merlin, parfait. Donc, je suis juste contente de reposer le contexte par rapport à notre échange de la", metadata={'speaker': 'spk2'}),
#  Document(page_content="dernière fois et puis l'objectif de cette petite call tous ensemble.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui, effectivement, l'idée c'était, si ça vous va, l'agenda du coup juste que je vous propose effectivement, c'est peut-être juste", metadata={'speaker': 'spk0'}),
#  Document(page_content='de faire un petit tour de table avant pour connaître un peu du coup le niveau de connaissance de Merlin et', metadata={'speaker': 'spk0'}),
#  Document(page_content='de Arthur sur Modjo et connaître un peu exactement vos scopes et vos enjeux un peu personnels justement sur vos', metadata={'speaker': 'spk0'}),
#  Document(page_content="scopes de collectif chez RoundTable. Ensuite, évidemment, je vais faire un récap' des enjeux discutés avec Merlin lors de notre", metadata={'speaker': 'spk0'}),
#  Document(page_content="précédent call et pour être sûr qu'on est tous les quatre alignés. Et évidemment, on va très vite s'immerger dans", metadata={'speaker': 'spk0'}),
#  Document(page_content='Modjo pour que vous puissiez justement vous projeter et voir en quoi ça pourrait évidemment vous aider sur vos enjeux', metadata={'speaker': 'spk0'}),
#  Document(page_content="à la fois côté sales et CSM et la fin de l'échange, ça serait du coup de planifier la suite.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Pour vous, l'idée, c'est d'avoir un peu de la visibilité du coup sur notre business model et pour moi, c'est", metadata={'speaker': 'spk0'}),
#  Document(page_content='pouvoir vous préparer une proposition tarifaire sur mesure et du coup la plus adaptée que ça soit en termes de', metadata={'speaker': 'spk0'}),
#  Document(page_content="nombre de licences. Est-ce que ça vous va comme comme comme Ouais, pas mal. L'échange. Ouais, OK, juste je peux", metadata={'speaker': 'spk0'}),
#  Document(page_content='me permettre. Merlin et Arthur, est-ce que vous votre caméra fonctionne ou pas?', metadata={'speaker': 'spk0'}),
#  Document(page_content='La caméra, je vais voir si elle fonctionne.', metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, génial, trop cool. OK, ça va super. C'est sympa. Merci. Comme ça, plus qu'en plus, on est trois. Comme", metadata={'speaker': 'spk0'}),
#  Document(page_content="ça, je suis sûre. Si vous avez des questions, peut être aussi d'avoir le visuel. Juste avant du coup de", metadata={'speaker': 'spk0'}),
#  Document(page_content='commencer, je suis juste curieuse de savoir Arthur et du coup Merlin, quel est juste votre niveau de connaissance de', metadata={'speaker': 'spk0'}),
#  Document(page_content="Modjo et qu'est ce que vous faites exactement chez RoundTable pour être sûr de présenter?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Et bien, on a radé un petit peu, donc c'était pour améliorer les performances commerciales, notamment grâce à l'IA. En", metadata={'speaker': 'spk2'}),
#  Document(page_content="gros, c'est par rapport à un script, voir à quel degré de similitude on est par rapport au script. Et", metadata={'speaker': 'spk2'}),
#  Document(page_content="donc, du coup, pour améliorer tout ce qui est nous, les relations clients après l'espèce commerciale et aussi l'espèce commerciale", metadata={'speaker': 'spk2'}),
#  Document(page_content="pour avoir de nouveaux clients. Et du coup, quand je suis à RoundTable, l'équipe d'équipe customer success et on est", metadata={'speaker': 'spk2'}),
#  Document(page_content='sur la partie commerciale opérationnelle.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Ouais, moi, je m'occupe de toute la partie opérationnelle. Je suis associé à Merlin qui est ici dans la call", metadata={'speaker': 'spk1'}),
#  Document(page_content="et connaissance de Modjo au même moment avec Merlin, puisque c'est on était dans la même réunion le jour où", metadata={'speaker': 'spk1'}),
#  Document(page_content='on nous en a parlé. OK, donc voilà en synthèse.', metadata={'speaker': 'spk1'}),
#  Document(page_content='OK, génial. Et du coup, justement, je crois que vous avez passé pas mal de temps ces dernières semaines ou', metadata={'speaker': 'spk0'}),
#  Document(page_content='ces derniers jours chez Furnitures. Est ce que vous avez pu échanger avec SquareChair? Enfin, du coup, je crois que', metadata={'speaker': 'spk0'}),
#  Document(page_content="c'est Lancelot et Lancelot. Oui, c'est ça. Lancelot, le CEO de SquareChair qui est dans le même incubateur que vous.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, on n'a pas parlé avec Lancelot spécialement sur ça, je t'avoue.", metadata={'speaker': 'spk1'}),
#  Document(page_content="OK, non, mais pas de problème. C'était par curiosité. OK, super clair.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Pour le savoir, on se gardera avec lui la semaine prochaine.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Écoutez, bah écoutez, avec plaisir, effectivement, ces équipes l'utilisent. Depuis, c'était mon premier client parce que moi, je suis à", metadata={'speaker': 'spk0'}),
#  Document(page_content="eux depuis trois mois maintenant et du coup, qui de mieux qu'un utilisateur Modjo pourra vous partager des insights. Donc,", metadata={'speaker': 'spk0'}),
#  Document(page_content="trop bien si vous le rencontrez. Du coup, pour récapituler ce qu'on s'est dit la dernière fois du coup avec", metadata={'speaker': 'spk0'}),
#  Document(page_content="Merlin et être sûr qu'on est sur le même niveau d'information. Moi, ce que j'ai compris, c'est que vous avez", metadata={'speaker': 'spk0'}),
#  Document(page_content="des grosses ambitions de croissance. Aujourd'hui, vous avez des équipes principalement à Lyon, mais aussi un peu à Barcelone. Du", metadata={'speaker': 'spk0'}),
#  Document(page_content="coup, il y a un enjeu de manager à distance pour être plus efficient. Vous avez des process aujourd'hui qui", metadata={'speaker': 'spk0'}),
#  Document(page_content='est du coup, je reprends tes termes à Merlin. Je ne sais pas du tout de ma bouche, mais qui', metadata={'speaker': 'spk0'}),
#  Document(page_content='sont encore un peu brouillon. Et du coup, vous avez un enjeu de scalaire un peu sur cet aspect. Du', metadata={'speaker': 'spk0'}),
#  Document(page_content='coup, formaliser plus les process pour aller chercher plus de méthodologie dans votre approche, que ça soit côté CSM et', metadata={'speaker': 'spk0'}),
#  Document(page_content="SAIS. Et du coup, quand vous parlez justement, quand on parle du coup de performance de croissance aujourd'hui, tu parlais", metadata={'speaker': 'spk0'}),
#  Document(page_content="aujourd'hui de vos deux enjeux qui étaient augmentés drastiquement. Le MRR généré aujourd'hui, c'est un peu possible que ça soit", metadata={'speaker': 'spk0'}),
#  Document(page_content="sur la partie tunnel d'acquisition en termes de volume ou de panier moyen. Et c'était aussi de fidéliser du coup", metadata={'speaker': 'spk0'}),
#  Document(page_content="les clients côté CSM. Et pour ça, du coup, vous avez besoin d'un ou vous voudriez vous projeter sur un", metadata={'speaker': 'spk0'}),
#  Document(page_content="outil d'intelligence conversationnelle. Du coup, côté sales, c'était vraiment pour l'aspect amélioration du discours, peut être test aussi de discours", metadata={'speaker': 'spk0'}),
#  Document(page_content='en fonction de vos nouvelles offres pour aller peut être chercher justement un panier moyen plus important. Aussi, réponse aux', metadata={'speaker': 'spk0'}),
#  Document(page_content="objections et faire monter tout simplement vos recrues en compétences, parce que notamment, c'est des profils assez juniors et alternants.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Si je ne m'abuse. Et côté CSM, c'est aussi de challenger sur la partie plutôt démo avec démo et avoir", metadata={'speaker': 'spk0'}),
#  Document(page_content="une expertise CSM vraiment encore plus poussée sur votre plateforme. Et on avait parlé d'un dernier sujet qui était moins", metadata={'speaker': 'spk0'}),
#  Document(page_content="lié à la performance, mais qui serait amené certainement à être challenge. C'était la partie productivité sur Hubspot. Merlin, tu", metadata={'speaker': 'spk0'}),
#  Document(page_content="disais que que vous l'utilisiez peut être aujourd'hui à 30% et que 99% vous n'étais pas sûr à 99% que", metadata={'speaker': 'spk0'}),
#  Document(page_content="les notes dans les opportunités soient bien prises et qu'il y aurait potentiellement des sujets de passations d'information entre CSM.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Et du coup, c'est tout l'idée de Modjo d'un outil global, c'est de vous aider sur ses parties performance et", metadata={'speaker': 'spk0'}),
#  Document(page_content="productivité. Est ce qu'on est toujours aligné? Est ce qu'il y a d'autres points que vous vouliez voir et qui", metadata={'speaker': 'spk0'}),
#  Document(page_content='sera important pour vous pour la démo?', metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, tu as très bien résumé.', metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, génial. Et qu'est ce que je veux dire? Oui, non, dernier dernier aspect. Du coup, on avait à parler", metadata={'speaker': 'spk0'}),
#  Document(page_content="un tout petit peu moins de ça la dernière fois, Merlin, j'étais curieuse de savoir aujourd'hui concrètement qu'est ce que", metadata={'speaker': 'spk0'}),
#  Document(page_content='vous mettez en place comme routine de coaching à proprement parler, puisque du coup, vous aimeriez bien challenger sur le', metadata={'speaker': 'spk0'}),
#  Document(page_content="discours, sur les objections. Mais du coup, à date, sans un Modjo sans un outil pour vous y aider, qu'est", metadata={'speaker': 'spk0'}),
#  Document(page_content='ce qui est mis en place par les managers?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Pas grand chose. Ce n'est pas le problème. Donc, sur la partie CSM, on met en place depuis un mois,", metadata={'speaker': 'spk2'}),
#  Document(page_content="un mois et demi des tests de pitch juste sur la partie pitch démo fonctionnel. Donc, on faut qu'on garde", metadata={'speaker': 'spk2'}),
#  Document(page_content='justement cette vélocité sur ces tests.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Et c'est tout ce que l'on fait, en tout cas sur la partie CSM aujourd'hui. Je pense qu'il y a", metadata={'speaker': 'spk2'}),
#  Document(page_content="d'autres éléments à prendre en compte aussi sur la qualité des process qui sont traités. Et sur la partie sales,", metadata={'speaker': 'spk2'}),
#  Document(page_content="tu peux dire deux mots, mais voilà, je sais qu'il y a des écoutes pendant un moment qui étaient faites", metadata={'speaker': 'spk2'}),
#  Document(page_content='sur Ringover, du double écoute ou même après coup, mais par quelque chose de régulièrement.', metadata={'speaker': 'spk2'}),
#  Document(page_content="On fait principalement des workshops. OK. Des workshops en règle générale, c'est une fois par mois.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ça se matérialise comment? Concrètement, ces workshops, c'est quoi l'objectif?", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est en gros, moi, je demande, donc il y a des ateliers à Ringover qui nous permettent de les", metadata={'speaker': 'spk1'}),
#  Document(page_content='écouter.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Clairement, il n'y a pas de double écoute dans le sens où on n'est à personne qui a le temps", metadata={'speaker': 'spk1'}),
#  Document(page_content="de faire de la double écoute. En tout cas, moi, je n'ai pas le temps de faire la double écoute.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Donc, on demande celle de venir avec d'enregistrer des bad calls et des good calls en gros, au nombre de", metadata={'speaker': 'spk1'}),
#  Document(page_content='cinq par mois. Et ils viennent avec en atelier.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Ouais.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Workshop. On travaille comme ça, notamment beaucoup. Le traitement des objections. Voilà, c'est aujourd'hui, c'est la méthode où qui est", metadata={'speaker': 'spk1'}),
#  Document(page_content="qui est qui est faite côté sales. Donc, c'est une fois par mois. Sachant que ça, effectivement, ça c'est là", metadata={'speaker': 'spk1'}),
#  Document(page_content="depuis septembre. Ça s'est arrêté puisqu'on a eu pas mal de nouvelles recrues qui sont rentrées, etc. Donc, en gros,", metadata={'speaker': 'spk1'}),
#  Document(page_content="il y a une petite pause sur septembre, octobre. Le temps de remettre l'équipe à flot. Donc là, ça va", metadata={'speaker': 'spk1'}),
#  Document(page_content="reprendre. On a arrêté, je crois, le dernier, c'était en juillet, début juillet, en été. Donc voilà, septembre, octobre, il", metadata={'speaker': 'spk1'}),
#  Document(page_content="n'y en a pas. Là, on va reprendre en novembre. Sachant que nous, les nouveaux sales, quand ils rentrent, on", metadata={'speaker': 'spk1'}),
#  Document(page_content="les fait d'abord travailler sur du pur call à froid. Donc, du pur call à froid, on ne les fait", metadata={'speaker': 'spk1'}),
#  Document(page_content='pas travailler sur des pros spéciaux de notre CRM. On travaille sur le script, le discours, on va dire en', metadata={'speaker': 'spk1'}),
#  Document(page_content='condition dure pour être potentiellement plus efficace en conditions plus clémentes.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Et au niveau du script, tout est scripté, j'allais dire, en fonction des différents cas, que ce soit du prospect", metadata={'speaker': 'spk1'}),
#  Document(page_content="froid au prospect. Il y a deux doigts de signer et qui a déjà fait une période d'essai. Donc, on", metadata={'speaker': 'spk1'}),
#  Document(page_content="a à peu près tout scripté. Néanmoins, on n'est pas dans une logique de... Moi, j'ai tendance à dire aux", metadata={'speaker': 'spk1'}),
#  Document(page_content="sales que l'important, c'est qu'ils sont en capacité d'avoir la profondeur de traiter les objections et la résilience de s'accrocher.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Après, effectivement, ça reste de l'impro en fonction de qui tu es en face de toi. Donc,", metadata={'speaker': 'spk1'}),
#  Document(page_content="tu ne peux pas avoir un discours de robot, même si au début, tu l'as un petit peu sur les", metadata={'speaker': 'spk1'}),
#  Document(page_content="trois et six premiers mois. Ils sont un peu en mode robot et c'est normal. Et j'allais dire, c'est même", metadata={'speaker': 'spk1'}),
#  Document(page_content="les robots qui sont en mode robot, parce que ça veut dire qu'ils suivent le script. Néanmoins, par la suite,", metadata={'speaker': 'spk1'}),
#  Document(page_content="ce n'est pas le robot qui signe. C'est lui.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Et du coup, juste petite question. Que ça soit sur les sales qui ont déjà eu leur phase de ramp-up', metadata={'speaker': 'spk0'}),
#  Document(page_content="ou les junior aujourd'hui, donc, effectivement, ils testent le pitch, ils répondent à des objections. Concrètement, là, tu fais comment", metadata={'speaker': 'spk0'}),
#  Document(page_content="juste pour t'assurer qu'ils répondent bien? Parce qu'il y a les workshops que vous mettiez en place. Mais aujourd'hui, à", metadata={'speaker': 'spk0'}),
#  Document(page_content='date, tu fais comment? Tu es sur le flot, tu les écoutes comme ça, tu fais de la réécoute via', metadata={'speaker': 'spk0'}),
#  Document(page_content='ring-over. Comment tu les accompagnes dans leur montée en compétence?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Nous, en gros, on a un suivi hebdo. Le lundi, on a une réunion d'équipe. Le vendredi, on a une", metadata={'speaker': 'spk1'}),
#  Document(page_content="réunion individuelle. En réunion individuelle, ils ont pris l'habitude de venir avec leur, entre guillemets, avec leurs problématiques, leurs objections.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ils viennent souvent me demander des arguments. Effectivement, à l'instant T maintenant, alors avant, ce n'était pas obligatoirement le cas", metadata={'speaker': 'spk1'}),
#  Document(page_content="avant l'été, mais maintenant, on a la chance d'avoir une sorte d'open space sur lequel moi, je peux entendre les", metadata={'speaker': 'spk1'}),
#  Document(page_content="appels. Donc, ça me permet d'intervenir quand je suis là pour éventuellement donner des petits des petits feedbacks. Voilà des", metadata={'speaker': 'spk1'}),
#  Document(page_content="tips. Mais jusqu'alors, on va dire que jusqu'alors, on était sur un modèle où, comme je te dis, il n'y", metadata={'speaker': 'spk1'}),
#  Document(page_content="a pas de réécoute à part le workshop. Il n'y a pas de réécoute. Après, les celles chez nous ont", metadata={'speaker': 'spk1'}),
#  Document(page_content='participé pour la plupart, ou en tout cas, ont au moins participé une fois un salon. Salon, ça veut dire', metadata={'speaker': 'spk1'}),
#  Document(page_content="que, voilà, j'allais dire, il n'y a pas derrière un téléphone, tu ne peux pas te cacher, tu es face", metadata={'speaker': 'spk1'}),
#  Document(page_content="à la personne et tu dois tu dois débiter. Et aujourd'hui, tous les sales, on va dire, ont participé au", metadata={'speaker': 'spk1'}),
#  Document(page_content='moins à un salon et ils ont déjà conclu des ventes. Donc, on a quand même un niveau de performance', metadata={'speaker': 'spk1'}),
#  Document(page_content='minimum', metadata={'speaker': 'spk1'}),
#  Document(page_content="qu'on sait être capable de tenir. Le problème, c'est la recherche de la... Le problème, c'est de travailler sur l'amélioration", metadata={'speaker': 'spk1'}),
#  Document(page_content="de la performance. C'est vraiment ça. C'est augmenter le nombre de conversions par mois, le nombre de closures, c'est le", metadata={'speaker': 'spk1'}),
#  Document(page_content='sujet.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Tu vas aller chercher combien en taux de conversion aujourd'hui ? Pardon ? Tu vas aller chercher combien en taux", metadata={'speaker': 'spk0'}),
#  Document(page_content="de conversion aujourd'hui ? Enfin, vous êtes à combien en taux de conversion et tu vas aller chercher combien dans", metadata={'speaker': 'spk0'}),
#  Document(page_content="l'idéal ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="En gros, aujourd'hui, on veut aller... On a nous un gros top service qui est la customize, la marque blanche", metadata={'speaker': 'spk1'}),
#  Document(page_content='chez nous. Si tu regardes un petit peu...', metadata={'speaker': 'spk1'}),
#  Document(page_content="Ici, j'ai regardé votre site à 139 euros.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Voilà, notre objectif, c'est d'être tous les mois au moins 10. Donc, ça, c'est vraiment notre objectif d'être à 10.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Et aujourd'hui, vous êtes à combien ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Aujourd'hui, on tourne entre 6 et 8 en gros. Donc, on est un cran en dessous. Ce mois-ci, on va aller", metadata={'speaker': 'spk1'}),
#  Document(page_content="faire les 10 parce qu'on sort d'un salon.", metadata={'speaker': 'spk1'}),
#  Document(page_content="On va dire que le taf a été bien fait, mais dans la récurrence... Et d'ailleurs, on a une performance", metadata={'speaker': 'spk1'}),
#  Document(page_content='assez ératique dans le sens où il y a des mois, je ne sais plus, en juin, on en fait', metadata={'speaker': 'spk1'}),
#  Document(page_content='5 et en juillet, par exemple, on en fait 10. Donc, en fait, on est vraiment comptable au niveau de', metadata={'speaker': 'spk1'}),
#  Document(page_content="la perfo. C'est ça qui est le plus frustrant. C'est là qu'on aimerait avoir un outil qui potentiellement nous permette", metadata={'speaker': 'spk1'}),
#  Document(page_content="d'améliorer de manière continue la performance des sales.", metadata={'speaker': 'spk1'}),
#  Document(page_content="En termes de chiffre d'affaires ou de MRR ou ARR à aller chercher sur l'année, tu as une idée de", metadata={'speaker': 'spk0'}),
#  Document(page_content="ce que ça représenterait d'augmenter justement cette performance qui est aujourd'hui pas forcément stable de moins en moins.", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est-à-dire le fait d'atteindre l'objectif, qu'est-ce que ça apporte ton MRR en plus ?", metadata={'speaker': 'spk1'}),
#  Document(page_content="Aujourd'hui, c'est quoi ton objectif ? C'est quoi le manque à gagner en termes d'ARR que tu as en visibilité", metadata={'speaker': 'spk0'}),
#  Document(page_content="le fait de ne pas être à 10 aujourd'hui ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Tu peux parler de son MRR.', metadata={'speaker': 'spk1'}),
#  Document(page_content='MRR, oui.', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est un jeu galère quand il met son niveau. Là, c'est simple. On a fait 7 marques blanches en septembre.", metadata={'speaker': 'spk1'}),
#  Document(page_content="L'objectif, c'est 10. C'est à peu près 500 euros par mois la marque blanche. C'est 1500 euros mensuels qui tournent", metadata={'speaker': 'spk1'}),
#  Document(page_content='par an.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Et du coup, ça c'est par sales ? Pour l'équipe ? Au global ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Le sales doit faire 3 marques blanches par mois. Si on voudrait qu'ils soient au niveau, il faut qu'ils fassent", metadata={'speaker': 'spk1'}),
#  Document(page_content="3 marques blanches par mois. Normalement, s'ils en font 3 par mois, sachant que moi également j'en fais aussi, ça", metadata={'speaker': 'spk1'}),
#  Document(page_content='en fait 12 tout de moins.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Attention, ça c'est nos chiffres aujourd'hui. Les chiffres de TAM4, c'est pas ce que ça donne. On leur fait le", metadata={'speaker': 'spk2'}),
#  Document(page_content='calcul avec Samuel pas plus tard que ce matin.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Ça serait plutôt combien du coup ?', metadata={'speaker': 'spk0'}),
#  Document(page_content='Là, on serait plutôt à nombre de marques blanches', metadata={'speaker': 'spk2'}),
#  Document(page_content='par personne par mois, 5.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Après, on s'est fixé des objectifs.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Par mois, c'est pas possible. T'es à 15 marques blanches.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Si on veut suivre ce qu'on est censé progresser, comment on est censé progresser, en tout cas sur 2024, on", metadata={'speaker': 'spk2'}),
#  Document(page_content='devrait être à terme à ce nombre-là. Dans tous les cas, on a un gros gap entre haut et bas.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Il y a un gros gap. On parle juste de marques blanches. Les autres sont complètement dépriorisés ? Est-ce que', metadata={'speaker': 'spk0'}),
#  Document(page_content='vos sales performent plus sur les autres ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Là-dessus, Celeste, c'est compliqué parce que tu poses des questions auxquelles on n'a pas de réponse.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Ok, pas de problème.', metadata={'speaker': 'spk0'}),
#  Document(page_content="La question est pertinente, mais tu poses des questions auxquelles on n'a pas de réponse.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, c'est pas grave.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Le problème, c'est que le sales contribue à la vente de licence les deux autres, sauf qu'on ne sait pas", metadata={'speaker': 'spk1'}),
#  Document(page_content="le traquer. On ne sait pas pourquoi nos clients, quand le sales leur donne un code, ils ne l'utilisent pas", metadata={'speaker': 'spk1'}),
#  Document(page_content='spécialement. On se trouve des sales qui aident à vendre la licence à 49 ou 69 euros, mais on ne', metadata={'speaker': 'spk1'}),
#  Document(page_content="sait pas si la vente a été faite par X ou Y. On sait que l'équipe contribue, donc on a", metadata={'speaker': 'spk1'}),
#  Document(page_content="une sorte de prime d'équipe là-dessus.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Mais on n'arrive pas à l'individualiser. Aujourd'hui, alors que pour la marque blanche, on sait parce que le devis est", metadata={'speaker': 'spk1'}),
#  Document(page_content="fait par le sales, par le propriétaire de la transaction, donc là, c'est beaucoup plus facile. Moi, alors, dans le", metadata={'speaker': 'spk1'}),
#  Document(page_content='suivi mensuel, comme je les ai deux fois par semaine, je sais quel deal X ou Y a signé, donc', metadata={'speaker': 'spk1'}),
#  Document(page_content="je suis capable d'identifier qui a fait son taff, si c'est bon, si ou non.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Traquer dans un call, tel ou tel offre, ça vous permettrait d'avoir plus de visibilité sur ce qui pourrait être", metadata={'speaker': 'spk0'}),
#  Document(page_content='poussé par vos sales ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Oui, identifier ce qui a été vendu dans le call et être capable de dire que c'était Jacky qui a", metadata={'speaker': 'spk1'}),
#  Document(page_content='vendu ça. Oui, ça peut être intéressant.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, clairement, c'est un truc que je n'avais pas en tête, donc je vous montrerai. J'ai une dernière question et", metadata={'speaker': 'spk0'}),
#  Document(page_content="après, je vous promets, on switch sur la démo, mais on n'a pas trop parlé du coup de la partie", metadata={'speaker': 'spk0'}),
#  Document(page_content="CSM. J'ai compris qu'il y avait un enjeu sur la partie plutôt démo de votre côté. Juste pour comprendre aujourd'hui,", metadata={'speaker': 'spk0'}),
#  Document(page_content="c'est quoi les axes d'amélioration d'une démo. Concrètement, qu'est-ce que vous cherchez exactement à faire ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Je pense qu'on peut rester sur le périmètre size.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Size, ok.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Très clair. Le démo, effectivement, peut l'améliorer, mais la personne est déjà sur le produit et c'est des informations qu'on", metadata={'speaker': 'spk2'}),
#  Document(page_content="vient lui donner. Donc oui, il y a de l'amélioration à faire, mais là pour la démo, je pense qu'on", metadata={'speaker': 'spk2'}),
#  Document(page_content='peut focusser sur les sales.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Ok, donc, focussons dans ce cas-là sur les sales.', metadata={'speaker': 'spk0'}),
#  Document(page_content="On n'avait pas sur la partie compte rendu, prise de notes. Tu me disais, Merlin, pendant le dernier échange que", metadata={'speaker': 'spk0'}),
#  Document(page_content="du coup, à ta connaissance en tout cas, aujourd'hui, c'est qu'il y avait peu de prise de notes de fait.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Du coup, l'autre, Merlin, je crois que c'est toi qui manage les sales. À ton niveau, c'est quoi ta connaissance", metadata={'speaker': 'spk0'}),
#  Document(page_content='?', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est dans les deux sens. Aujourd'hui, on n'est pas bon dans les deux sens, dans le sens où le sales", metadata={'speaker': 'spk1'}),
#  Document(page_content="n'a pas tout le temps pris les notes et souvent le CS ne prend pas les notes du tout en", metadata={'speaker': 'spk1'}),
#  Document(page_content="post démo, ce qui fait qu'on a eu sur mai-juin des signatures qu'on a perdu par mauvaise communication CS Sales", metadata={'speaker': 'spk1'}),
#  Document(page_content="et Sales CS. Ce qui est sûr, c'est que je suis sûr à 99% qu'il n'y a pas toutes les", metadata={'speaker': 'spk1'}),
#  Document(page_content='informations entre les Arthur-Panthéonier vu que deux ou trois fois...', metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, je mets les pieds là où il ne faut pas, mais l'idée, c'est de faire en sorte que ça", metadata={'speaker': 'spk0'}),
#  Document(page_content='ne se passe plus.', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est clair que les notes,", metadata={'speaker': 'spk1'}),
#  Document(page_content="c'est quelque chose qui est très important.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Tout le monde a une fois commis l'erreur, voire même la commet de temps à autre, ça, c'est certain.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Et si on peut avoir un système de prise de notes automatisée grâce à une IA, oui, c'est intéressant.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok. Du coup, aujourd'hui, vous savez pourquoi ce n'est pas fait ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Pourquoi ce n'est pas fait ? Parce qu'en fait, le CS, il a du mal à le faire parce qu'il", metadata={'speaker': 'spk1'}),
#  Document(page_content="fait sa démo en live avec son ordinateur. Et du coup, pour faire son CR, il faut qu'il s'arrête 5", metadata={'speaker': 'spk1'}),
#  Document(page_content="minutes après et qu'il se dise, je fais ma synthèse. Donc là, il faut enlever la synthèse, il faut y", metadata={'speaker': 'spk1'}),
#  Document(page_content='penser. Et des fois, le pauvre CS, il enchaîne une réunion avec un autre CS.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Et côté sales sur la partie call ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Alors côté sales, j'allais dire chez les sales, c'est peut-être l'endroit où c'est peut-être le plus fait parce que déjà,", metadata={'speaker': 'spk1'}),
#  Document(page_content='il est libre même. Donc en fait, un sales pour lui-même, il va prendre des notes.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Mais les fois où il ne va pas le faire, ça peut être parce qu'il n'est pas à l'aise dans", metadata={'speaker': 'spk1'}),
#  Document(page_content="son call et qu'il se fait malmener et que du coup, on va dire que voilà, il a subi le", metadata={'speaker': 'spk1'}),
#  Document(page_content='rendez-vous et du coup, il a potentiellement besoin de souffler derrière. Et voilà, soit il enchaîne aussi des réunions, ça', metadata={'speaker': 'spk1'}),
#  Document(page_content="peut arriver puisqu'il peut avoir plusieurs réunions prévues avec des prospects. Et après, il y a aussi au-delà de l'aspect", metadata={'speaker': 'spk1'}),
#  Document(page_content="faire, il y a la qualité de la synthèse, il y a la qualité du CR, c'est deux choses différentes.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Il y a faire et faire et effectivement, certains ont moins l'esprit synthétique que d'autres.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Ok, écoutez, très clair, dans ce cas-là, on regardera bien cet aspect aide à la prise de notes qui aidera', metadata={'speaker': 'spk0'}),
#  Document(page_content="du coup les deux équipes. Est-ce que vous avez des choses à rajouter ou est-ce qu'on peut passer du coup", metadata={'speaker': 'spk0'}),
#  Document(page_content="au partage d'écran et à la démo ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, c'est complet.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ok, génial. Merci en tout cas pour ce complément d'information qui va très certainement enrichir cette démo. Je vous partage", metadata={'speaker': 'spk0'}),
#  Document(page_content='dès maintenant mon écran, est-ce que vous le voyez bien ?', metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Génial. Du coup, je compte sur vous pour vraiment m'arrêter si vous avez des questions et de me dire si", metadata={'speaker': 'spk0'}),
#  Document(page_content="jamais vous voulez passer parce que ça ne vous intéresse pas particulièrement. Normalement, j'ai bien préparé, donc ça ne devrait", metadata={'speaker': 'spk0'}),
#  Document(page_content="pas être le cas, mais n'hésitez pas vraiment à m'interrompre pour que ça soit le plus interactif possible. Du coup,", metadata={'speaker': 'spk0'}),
#  Document(page_content="bienvenue sur Modjo Comme vous pouvez le voir, c'est mon Modjo à moi. Je vous partage vraiment en toute transparence", metadata={'speaker': 'spk0'}),
#  Document(page_content="tous les échanges que j'ai au quotidien avec mes prospects et mes clients. Techniquement, comment ça va se passer ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Modjo ça va venir se plugger à votre outil de VOIP, donc Ringover, à vos outils de Visio et à', metadata={'speaker': 'spk0'}),
#  Document(page_content="votre CRM Hubspot. L'idée du coup, c'est qu'on va venir récupérer les enregistrements de ces échanges à des fins de", metadata={'speaker': 'spk0'}),
#  Document(page_content="performance, de productivité. Ce qu'on va faire concrètement, c'est qu'on va retranscrire en texte tout ce qui va être abordé,", metadata={'speaker': 'spk0'}),
#  Document(page_content='on va dire toute la dialectique, que ça soit côté commercial, CS ou client prospect. Concrètement, juste pour que vous', metadata={'speaker': 'spk0'}),
#  Document(page_content="ayez une idée, rien ne va changer pour côté Sales ou CS. Ce que je veux dire, c'est qu'il n'y", metadata={'speaker': 'spk0'}),
#  Document(page_content="a pas de manip manuel à faire pour qu'un call, une Visio remonte, tout est fait automatiquement.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Excusez-moi, Celeste, les CS font beaucoup de Google Meet ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui. C'est géré ?", metadata={'speaker': 'spk1'}),
#  Document(page_content="Du coup, Google Meet, exactement, c'est bien pris en compte. Toutes les vidéos Google Meet vont remonter automatiquement aujourd'hui dans", metadata={'speaker': 'spk0'}),
#  Document(page_content="Modjo. On off ? On off, non. On off aujourd'hui, on n'est pas intégré à on off. En revanche, on", metadata={'speaker': 'spk0'}),
#  Document(page_content="est intégré à Ringover et à d'autres outils de VOIP, mais pas à on off aujourd'hui.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ce n'est pas grave, on off, normalement, c'est fait que pour beaucoup, pour des réceptions de SMS, pour débloquer des", metadata={'speaker': 'spk2'}),
#  Document(page_content="comptes, etc. Donc, ce n'est pas problématique.", metadata={'speaker': 'spk2'}),
#  Document(page_content="C'est plus de l'écrit du coup plutôt que de l'audio finalement ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est plus pour l'opérationnel que de l'échange pur avec du client.", metadata={'speaker': 'spk2'}),
#  Document(page_content="En tout cas, effectivement, à date, on n'a pas encore d'intégration avec on off. Du coup, à date, on ne", metadata={'speaker': 'spk0'}),
#  Document(page_content="récupérerait pas ces échanges. OK. Du coup, l'ADN de Modjo c'est d'être le plus collaboratif possible. Et du coup, que", metadata={'speaker': 'spk0'}),
#  Document(page_content='ça soit au sein des équipes sales, customer success, entre managers, managers. Et du coup, comme vous pouvez le voir,', metadata={'speaker': 'spk0'}),
#  Document(page_content="on peut avoir accès à mes échanges, aux échanges du coup de mon équipe et aux échanges de toute l'entreprise.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Une fois que j'ai dit ça, Modjo c'est également aussi la mémoire de l'entreprise, la mémoire client. Donc, par exemple,", metadata={'speaker': 'spk0'}),
#  Document(page_content='si je veux prendre par exemple un de mes, je vais faire encore mieux, je vais prendre SquareChair. SquareChair, comme', metadata={'speaker': 'spk0'}),
#  Document(page_content="je vous le disais, c'est une des start-up incubées chez Furnitures. Et du coup, ce qu'on peut faire, c'est qu'on", metadata={'speaker': 'spk0'}),
#  Document(page_content="va pouvoir filtrer finalement sur ce compte client. Là, vous pouvez voir qu'il y a effectivement aujourd'hui 10 échanges qui", metadata={'speaker': 'spk0'}),
#  Document(page_content="sont remontés. Ça passe de mon appel de prospection, ma discovery, bref, ma démo, l'offre tarifaire, comme aussi tous", metadata={'speaker': 'spk0'}),
#  Document(page_content="les échanges que l'équipe aujourd'hui de Modjo Customer Success a avec les équipes. Donc vous voyez vraiment, on part vraiment", metadata={'speaker': 'spk0'}),
#  Document(page_content="d'une base énorme d'échanges et on peut filtrer en fonction évidemment des clients pour avoir vraiment une historisation maximum des", metadata={'speaker': 'spk0'}),
#  Document(page_content="échanges. Déjà, est-ce que pour vous, ça c'est clair ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui, oui, oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Ok, j'ai une idée. Alors, du coup, ce que je vous propose, c'est qu'on va partir sur le premier pilier", metadata={'speaker': 'spk0'}),
#  Document(page_content="qui est vraiment le pilier performance. Donc on va prendre du coup la performance commerciale. Aujourd'hui, vous avez des vrais", metadata={'speaker': 'spk0'}),
#  Document(page_content="enjeux d'amélioration du discours, de comprendre aujourd'hui ce qui est dit dans les échanges, d'amélioration aussi des réponses à des", metadata={'speaker': 'spk0'}),
#  Document(page_content="objections. Vous avez vraiment besoin d'avoir de la visibilité sur ce qui se passe dans les calls. Je ne me", metadata={'speaker': 'spk0'}),
#  Document(page_content="trompe pas, je suis fidèle. On est d'accord ? Ok, génial.", metadata={'speaker': 'spk0'}),
#  Document(page_content="On va avoir surtout de l'information de ce qui se passe dans les calls.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, et ce qui va se passer, c'est que par exemple, je vais prendre du coup des échanges qui ont", metadata={'speaker': 'spk0'}),
#  Document(page_content="eu lieu, par exemple, sur le quarter. Donc ce que vous pouvez voir déjà, c'est qu'il y a des tags", metadata={'speaker': 'spk0'}),
#  Document(page_content='en fonction de la typologie des échanges. Il y a effectivement des calls de qualification, de démos. Vous aurez des', metadata={'speaker': 'spk0'}),
#  Document(page_content="typologies d'échanges évidemment en fonction de votre cycle de ventre.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Comment ces tags sont mis en fait ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Alors typiquement, là, c'est des appels, donc c'est des appels de prospection. Donc là, vous pouvez voir que c'est du", metadata={'speaker': 'spk0'}),
#  Document(page_content="cold call. Autrement, c'est l'intelligence artificielle.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Comment Modjo sait que c'est du cold call ?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Parce que c'est lié du coup à votre ringover ou à votre aircall ou à votre outil de VOIP. Ça", metadata={'speaker': 'spk0'}),
#  Document(page_content='remonte automatiquement ce tag.', metadata={'speaker': 'spk0'}),
#  Document(page_content="D'accord, donc c'est sur ringover et il faut mettre la bonne information.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Quand tu raccroches… Ce qui a été dit.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Il y a deux choses en fait. Par exemple, il y a le nom du meeting. Vous faites une intro,', metadata={'speaker': 'spk0'}),
#  Document(page_content="l'intelligence artificielle va venir identifier la typologie de rendez-vous.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Donc là, par exemple, on a accès… Par rapport à l'intro qui a été faite, si tu présentes le produit,", metadata={'speaker': 'spk1'}),
#  Document(page_content="c'est que c'est un cold call froid. Si tu attaques directement sur une… Comme on s'est dit la dernière fois…", metadata={'speaker': 'spk1'}),
#  Document(page_content="C'est la même chose pour le démo.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Modjo sait à tous les coups classifier ses échanges.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Il sait classifier ses échanges. Alors là, qu'est-ce qui se passe ? Parce que j'ai mis tous les appels. Ça", metadata={'speaker': 'spk0'}),
#  Document(page_content="va pas aller. Attendez. Il sait classifier ses échanges. Ces échanges, pardon. Ça m'épette en fonction de la typologie des", metadata={'speaker': 'spk0'}),
#  Document(page_content="calls. Ça peut mettre deux, trois minutes. Par exemple, moi, j'ai une démo qui remonte. C'était une heure de démo.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Le temps que la plateforme identifique, c'est une démo. Ça peut mettre deux, trois minutes à être taggé comme une", metadata={'speaker': 'spk0'}),
#  Document(page_content="démo. Mais effectivement, c'est l'outil qui vient le tagger. Là, par exemple, vous pourriez avoir accès à toutes les démos", metadata={'speaker': 'spk0'}),
#  Document(page_content="aujourd'hui qui ont eu lieu chez Modjo sur le mot. OK ? Est-ce que c'est plus clair pour vous déjà,", metadata={'speaker': 'spk0'}),
#  Document(page_content="ça ? Oui, oui, oui. OK, génial. Par exemple, ce qu'on voudrait faire, c'est regarder tous les échanges qui ont", metadata={'speaker': 'spk0'}),
#  Document(page_content='eu lieu sur ce quarter, par exemple, des discoveries. Parce que notamment, généralement, dans les discoveries…. Parce que je vous', metadata={'speaker': 'spk0'}),
#  Document(page_content="demande un exemple où on pitche Modjo. Dans les discoveries, c'est souvent des échanges où effectivement, il y a un", metadata={'speaker': 'spk0'}),
#  Document(page_content="pitch ou des objections qui reviennent régulièrement. Ce qui va se passer, c'est que du coup, là, déjà, vous avez", metadata={'speaker': 'spk0'}),
#  Document(page_content="accès à l'ensemble des discoveries qui ont eu lieu sur le quarter. Vous allez aussi pouvoir filtrer par équipe ou", metadata={'speaker': 'spk0'}),
#  Document(page_content='par user si par exemple, vous voulez coacher en particulier telle ou telle personne. Vous pouvez aussi vous dire, bon,', metadata={'speaker': 'spk0'}),
#  Document(page_content='bah moi, je voudrais regarder les meilleurs pitchs qui ont eu lieu ou les meilleures qualifications, les meilleures démos qui', metadata={'speaker': 'spk0'}),
#  Document(page_content="ont eu lieu aujourd'hui sur le quarter et qui ont abouti à une vente. Vu que c'est lié à un", metadata={'speaker': 'spk0'}),
#  Document(page_content="Hubspot aujourd'hui, vous allez pouvoir filtrer sur, par exemple, toutes les discoveries qui ont abouti à une vente aujourd'hui", metadata={'speaker': 'spk0'}),
#  Document(page_content="chez Modjo Donc, vu que c'est effectivement plugé à votre Hubspot, on vient récupérer des informations. Et là, typiquement,", metadata={'speaker': 'spk0'}),
#  Document(page_content="on a aujourd'hui neuf masterclass qui sont officiellement des très bonnes discoveries puisqu'en fait, aujourd'hui, ça aboutit à une vente.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Est-ce que déjà vous voyez un peu l'idée d'aller chercher de l'information et cette idée d'entonnoir ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Super. Alors maintenant, je vais reprendre aussi un call de discovery.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Et là, l'idée, du coup, vous voulez suivre finalement la manière dont est pitché aujourd'hui, dont est pitché Modjo en", metadata={'speaker': 'spk0'}),
#  Document(page_content="fonction, par exemple, selon vos interlocuteurs, selon les personnes qui aujourd'hui travaillent chez vous. Ce qui va se passer, c'est", metadata={'speaker': 'spk0'}),
#  Document(page_content="que du coup, vous allez pouvoir arriver dans un échange. Donc, qu'est-ce que je vais pouvoir prendre comme échange ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Par exemple, je vais prendre groupe Endless, donc une introduction que j'ai eue récemment avec un de mes prospects. Donc", metadata={'speaker': 'spk0'}),
#  Document(page_content="là, vous arrivez sur une fenêtre de réécoute d'appels. Vous avez énormément d'informations. Il y a les crescendo. Déjà, vous", metadata={'speaker': 'spk0'}),
#  Document(page_content="pouvez voir que directement, c'est lié à votre CRM. Nous, c'est Salesforce, mais vous aurez la même chose avec", metadata={'speaker': 'spk0'}),
#  Document(page_content="Hubspot. Vous avez la durée de l'échange. Vous avez la possibilité d'accélérer le moment de réécoute. Sélectionnez du coup que", metadata={'speaker': 'spk0'}),
#  Document(page_content="le speaker, si vous voulez réécouter qu'un speaker. Et même traduire et avoir les sous-titres pour être plus efficace dans", metadata={'speaker': 'spk0'}),
#  Document(page_content="le moment où vous réécoutez un moment d'appel.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Une fois que je vous ai présenté cette fenêtre de réécoute d'appels, il y a un vrai sujet qui est", metadata={'speaker': 'spk0'}),
#  Document(page_content="aujourd'hui comprendre comment est pitché, comment est présenté aujourd'hui Modjo. Il y a une fonction, enfin Modjo pardon, excusez-moi, assez", metadata={'speaker': 'spk0'}),
#  Document(page_content="haut. Ce qui va se passer, c'est que du coup, avec les chapters, ça va vous permettre de découper déjà votre", metadata={'speaker': 'spk0'}),
#  Document(page_content='échange en plusieurs phases. Et déjà, ça va vous permettre de se focusser exactement au bon moment que vous voulez', metadata={'speaker': 'spk0'}),
#  Document(page_content="réécouter et challenger. Parce que toute l'idée, c'est de challenger vos sales sur justement leur manière de pitcher ou de", metadata={'speaker': 'spk0'}),
#  Document(page_content="répondre à des objections. Ce qui va se passer, c'est que du coup, là, on peut voir qu'à la minute,", metadata={'speaker': 'spk0'}),
#  Document(page_content='donc à une minute 15, je vais faire une présentation, du coup ma prospect coralie de Modjo Et ce qui', metadata={'speaker': 'spk0'}),
# ...
#  Document(page_content='OK. Et du coup, là, je te partageais juste.', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est normal de négocier Hubspot, vu ce qui nous prenne 200 euros, c'est de survoir un point. Aujourd'hui, on n'a", metadata={'speaker': 'spk1'}),
#  Document(page_content="pas de. Ce n'était pas prévu.", metadata={'speaker': 'spk1'}),
#  Document(page_content="On a obligatoirement le besoin d'un e-media. Faut voir le ROI. C'est ce que tu as expliqué. Tu as répondu", metadata={'speaker': 'spk1'}),
#  Document(page_content='à deux, trois de me pain. Ça donne. Non, ça donne une bonne vision. Fais nous une offre du coup', metadata={'speaker': 'spk1'}),
#  Document(page_content="avec. Avec la meilleure offre que tu peux faire. Et puis, on regardera ça. Là, il faut vraiment qu'on coupe", metadata={'speaker': 'spk1'}),
#  Document(page_content="parce qu'il faut que l'on enchaine. C'était intéressant. C'était intéressant. Donc, je te remercie pour ton temps.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Juste sur quoi tu as un doute du coup? Ce que tu m'as dit deux, trois pain, ça veut dire", metadata={'speaker': 'spk0'}),
#  Document(page_content="qu'il y en a au moins une auxquelles on n'a pas répondu.", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est pas que vous n'y répondez pas. C'est que, en gros, je ne sais pas si votre... Déjà, j'ai identifié", metadata={'speaker': 'spk1'}),
#  Document(page_content='des bonnes pratiques. Donc, merci. Du coup, je vais dire à mes six de faire certaines choses avec maintenant pour', metadata={'speaker': 'spk1'}),
#  Document(page_content="à être Hubspotté qui est un peu du Modjo Ça, c'est métier pour rien dans le sens où c'est. C'est", metadata={'speaker': 'spk1'}),
#  Document(page_content="j'allais dire, ça fait partie des choses. Vous faites mieux quelque chose que ce qu'est capable de faire en fait", metadata={'speaker': 'spk1'}),
#  Document(page_content="concrètement. Mais vous faites beaucoup mieux. Encore une fois, lui, c'est très sympa. C'est vrai que, par contre, à l'instant", metadata={'speaker': 'spk1'}),
#  Document(page_content="T, il y a. Je pense des choses qui sont permises par votre outil qu'on peut faire de manière un", metadata={'speaker': 'spk1'}),
#  Document(page_content="peu différente avec des outils un peu. On peut bricoler quoi. Après, le bricolage, ça reste du bricolage. Soyons, j'en", metadata={'speaker': 'spk1'}),
#  Document(page_content='ai conscience. Mais bon, à voir après, faites nous une bonne offre et puis on rediscute. La notion des CR,', metadata={'speaker': 'spk1'}),
#  Document(page_content="c'est un sujet. Vous avez l'air de le faire. La notion de la synthèse d'analytics à la fin, j'aime bien.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Donc, live note aussi.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Tu as bien aimé la live note.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Voilà, deux, trois pains. En règle générale, je perds pas le temps. Mais, mais, mais, on va voir ton offre.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Et derrière, nous, on va rediscuter en interne. Mais évidemment, effectivement, du budget, il n'y en avait pas de base.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Faut voir le ROI. Par contre, clairement, à 1000 euros et 1000 euros ou 500, je suis d'accord avec Antoine.", metadata={'speaker': 'spk1'}),
#  Document(page_content="On n'ira pas.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Par mois. Oui, on y va. Là, de toute façon, là, du coup, ce que je vous disais, c'était cinq", metadata={'speaker': 'spk0'}),
#  Document(page_content="users à 99 euros. Le prix de base, c'est du coup, ça ferait un 495 de mémoire sans levier d'action.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Voilà, je pense que comme t'as beaucoup de levier d'action, je pense que tu vas actionner plein de leviers pour", metadata={'speaker': 'spk1'}),
#  Document(page_content='que ce soit potentiellement.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Bah, écoutez, dans ce cas là, prenons nous un créneau parce que je sais que votre temps est compté. Et', metadata={'speaker': 'spk0'}),
#  Document(page_content="du coup, ce que je vous propose, c'est qu'on se prenne un créneau pour vous présenter l'offre.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Au pire, tu nous refais un mail et tu nous redis ou tu nous envoies ton calendrier. On prend le', metadata={'speaker': 'spk1'}),
#  Document(page_content='calendrier.', metadata={'speaker': 'spk1'}),
#  Document(page_content="C'est pas plus simple de croiser nos agendas maintenant.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, mais je vais gérer le troisième rendez-vous.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Voilà, parfait. OK, super.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Allez, ça marche. Merci à tous les trois. Je reste le Celeste juste pour finir. Oui, ça marche.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Merci. Merci Antoine.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Donc, Celeste, oui, encore une fois, outil très intéressant. J'avais une autre question au niveau du on boarding. Comment ça", metadata={'speaker': 'spk2'}),
#  Document(page_content='se passe chez vous?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui, alors du coup, en termes d'onboarding, du coup, effectivement, Modjo c'est 70 80% la plateforme. Mais c'est", metadata={'speaker': 'spk0'}),
#  Document(page_content='surtout que vous avez un accompte manager, donc un consultant qui est là pour vous accompagner de la paramétrage.', metadata={'speaker': 'spk0'}),
#  Document(page_content="L'onboarding jusqu'à la fin d'utilisation de Modjo Donc ce que je veux dire, c'est qu'en termes d'onboarding, il y", metadata={'speaker': 'spk0'}),
#  Document(page_content='a effectivement un onboarding manager, un onboarding équipe qui est qui est prévu en plus du paramétrage. Et', metadata={'speaker': 'spk0'}),
#  Document(page_content="ensuite, tout au long de l'utilisation, vous avez un consultant qui est là pour vous partager des tips marché, comment", metadata={'speaker': 'spk0'}),
#  Document(page_content="améliorer votre productivité, comment mieux coacher vos équipes, comment les sales peuvent être plus utilisé Modjo Et donc, ça, c'est", metadata={'speaker': 'spk0'}),
#  Document(page_content="tout ça, c'est pris en compte dans le prix de la licence du coup enregistreuse. Donc, en fait, il n'y", metadata={'speaker': 'spk0'}),
#  Document(page_content='a aucun coût additionnel par rapport à ce que je vous présenterai. Est ce que je vous ai présenté ne', metadata={'speaker': 'spk0'}),
#  Document(page_content='serait ce que les 495 euros. Vous avez vraiment un compte manager qui est dédié. Et on a notamment des', metadata={'speaker': 'spk0'}),
#  Document(page_content='gens qui sont qui sont qui sont experts sur des secteurs. On accompagne pas mal de saas dans justement le', metadata={'speaker': 'spk0'}),
#  Document(page_content="domaine de la chevalerie comme Gymlib, qui est notre premier premier client aujourd'hui. Ils étaient que trois à l'époque", metadata={'speaker': 'spk0'}),
#  Document(page_content='et tu vois maintenant à la taille de Gymlib Gymlib.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Ah c'est Gymlib.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Voilà, donc tu vas très bien connaître. Donc tu vois, ça, c'était un de nos premiers clients. Et vraiment, encore", metadata={'speaker': 'spk0'}),
#  Document(page_content="une fois, ils n'ont pas du tout mis en place Modjo quand ils étaient Gymlib de maintenant. Ils sont", metadata={'speaker': 'spk0'}),
#  Document(page_content="une armée de ça. Ils l'ont mis en place au démarrage où justement ils avaient besoin de gagner en temps", metadata={'speaker': 'spk0'}),
#  Document(page_content="à comprendre exactement les besoins du marché, comment pitcher leurs équipes, comment ils répondaient aux objections et justement passer d'un", metadata={'speaker': 'spk0'}),
#  Document(page_content='mode un peu bricolage artisanal à un mode crescendo beaucoup plus processé pour aller chercher des parts de marché, pour', metadata={'speaker': 'spk0'}),
#  Document(page_content="aller chercher de la productivité, pour faire en sorte que leur leur junior arrive très rapidement au niveau d'un justement", metadata={'speaker': 'spk0'}),
#  Document(page_content="Antonique cofondeur qui, évidemment, est le meilleur sales aujourd'hui, mais que lui se détache progressivement du coup de la vente", metadata={'speaker': 'spk0'}),
#  Document(page_content="pour avoir des sales qui prennent le relais. Donc c'est tout l'idée d'un Modjo aujourd'hui.", metadata={'speaker': 'spk0'}),
#  Document(page_content='OK, OK, OK.', metadata={'speaker': 'spk2'}),
#  Document(page_content="J'ai bien répondu à ta question.", metadata={'speaker': 'spk0'}),
#  Document(page_content="J'avais saisi effectivement ça.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Et sur les évolutions du produit, est-ce qu'on reste sur le même prix ou est-ce qu'on va être bloqué? Si", metadata={'speaker': 'spk2'}),
#  Document(page_content="on veut passer à des évolutions là dans tu dis dans un mois là, est-ce que c'est un complémentaire?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Non, effectivement, il y a absolument ce qui est signé restera signé. Ce que je veux dire, c'est que c'est", metadata={'speaker': 'spk0'}),
#  Document(page_content="notamment la fonctionnalité dont je t'ai parlé. Tu vas en bénéficier. On n'a pas de coût supplémentaire en fonction des", metadata={'speaker': 'spk0'}),
#  Document(page_content='features que tu choisis. Tu auras accès à toutes les nouveautés. Bref, à tout.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Parce que je te dis ça parce que Intercom, par exemple, qui est un excellent outil, il sort des fonctionnalités', metadata={'speaker': 'spk2'}),
#  Document(page_content="régulièrement et il y en a qui ne font pas partie du scope. C'est des modules en fait additionnels. C'est", metadata={'speaker': 'spk2'}),
#  Document(page_content="pareil avec des ardoises qui sont colossales pour des boîtes comme nous. Même si c'est des outils qui sont très", metadata={'speaker': 'spk2'}),
#  Document(page_content="pertinents. Donc voilà, nous, ce que je peux juste te dire, en tout cas, c'est que on est prêt à", metadata={'speaker': 'spk2'}),
#  Document(page_content="s'engager. En tout cas, sur les 18 prochains mois avec un tarif très très préférentiel. Très sincèrement et après, continue", metadata={'speaker': 'spk2'}),
#  Document(page_content="avec vous. Il n'y a pas de raison à ce que, en tout cas, moi, je crois en cet outil", metadata={'speaker': 'spk2'}),
#  Document(page_content="là. Ce n'est pas le problème. Aujourd'hui, nous, le frein, c'est à la fois le tarif et un frein mineur.", metadata={'speaker': 'spk2'}),
#  Document(page_content="C'est ça, il faut qu'on en discute en interne. C'est le temps à accorder après sur cet outil là. Si", metadata={'speaker': 'spk2'}),
#  Document(page_content="c'est pour avoir un outil pour dire qu'on a Modjo mais derrière qu'on ne l'exploite pas. Parce que aujourd'hui, on", metadata={'speaker': 'spk2'}),
#  Document(page_content="a des outils qu'on n'exploite pas comme il se devrait, comme il devrait. Ça ne nous servira à rien. Mais", metadata={'speaker': 'spk2'}),
#  Document(page_content="ça, c'est plus surprenant à se mettre d'avis.", metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, effectivement, après, tu vois, sur la partie productivité, notes. Aujourd'hui, du coup, c'est l'IA qui fait tout. Et donc,", metadata={'speaker': 'spk0'}),
#  Document(page_content='pour le coup, ça remonte directement dans ton Hubspot. Donc, en fait, de toute façon, les calls, ils sont enregistrés.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Donc ça, de toute façon, on va dire que vous avez entre guillemets plus la main mise sur est-ce que', metadata={'speaker': 'spk0'}),
#  Document(page_content='mon IA prend des notes. De toute façon, elle prendra les notes. Et sur la partie du coup réécoute. Pour', metadata={'speaker': 'spk0'}),
#  Document(page_content="moi, c'est on vient pas modifier vos routines, ce qui est mis en place par Merlin, ce qui est mis", metadata={'speaker': 'spk0'}),
#  Document(page_content='en place par Arthur, peut être sur toi, sur la partie management des équipes CSM. On vient juste vous faire', metadata={'speaker': 'spk0'}),
#  Document(page_content="gagner du temps d'écoupler votre force de coaching et surtout donner les moyens à des sales aujourd'hui ou des CSM", metadata={'speaker': 'spk0'}),
#  Document(page_content="de s'améliorer. Et du coup, aujourd'hui, honnêtement, en termes de connexion, c'est évidemment qu'il y a des managers. Mais en", metadata={'speaker': 'spk0'}),
#  Document(page_content="fait, aujourd'hui, c'est un outil. Il y a des équipes aujourd'hui qui font des sales aujourd'hui qui demandent de leur", metadata={'speaker': 'spk0'}),
#  Document(page_content="de leurs entretiens. Est ce que vous avez Modjo ? Parce qu'en fait, ça leur simplifie à mort la vie. La", metadata={'speaker': 'spk0'}),
#  Document(page_content='dernière fois, on avait parlé du fait que vous ayez des grands comptes et six mois de cycles de ventes.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Si je ne m'abuse, justement, un outil comme ça, ça te permet de revenir sur tes échanges, de te remettre", metadata={'speaker': 'spk0'}),
#  Document(page_content="dedans, de préparer des rendez-vous, être beaucoup plus pertinent. Et en fait, c'est vraiment comment dire? C'est en fait, ça", metadata={'speaker': 'spk0'}),
#  Document(page_content="devient indispensable pour les équipes. Du coup, en termes d'usage, je comprends effectivement le côté. On n'a pas envie de", metadata={'speaker': 'spk0'}),
#  Document(page_content='mettre en place un outil pour un outil. Mais alors là, pour le coup, moi, je sais que tu vois', metadata={'speaker': 'spk0'}),
#  Document(page_content='le jour où je bosse de Modjo je sais que je veux une équipe, une boîte où il y a', metadata={'speaker': 'spk0'}),
#  Document(page_content="un Modjo aujourd'hui. Parce que moi, je m'y imagine pas repasser à des tâches manuelles, revenir sur des enregistrements pour", metadata={'speaker': 'spk0'}),
#  Document(page_content="me préparer. Ça me paraît aberrant de faire ça. Voilà, voilà. Écoute, ce que je te propose, c'est qu'on se", metadata={'speaker': 'spk0'}),
#  Document(page_content='prenne un petit créneau du coup, effectivement, pour la partie tarifaire.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Qu'est ce que tu penses? Moi, j'ai un créneau demain si tu veux ou autrement lundi.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Lundi, ce sera mieux.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Lundi, lundi, lundi.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Qu'est ce que c'est?", metadata={'speaker': 'spk1'}),
#  Document(page_content='Lundi 16h30.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Eh ben parfait. Lundi 16h30. On fait ça. Je t'envoie un peu. Je t'envoie l'invit du coup. Que on", metadata={'speaker': 'spk0'}),
#  Document(page_content="sera tous les deux, c'est ça? Oui. OK, très bien. Eh ben écoute, je t'envoie l'invitation et on en discute", metadata={'speaker': 'spk0'}),
#  Document(page_content="à 16h30 lundi. Et écoute, je prépare une offre tarifaire la plus ajustée que je peux faire aujourd'hui. Et puis", metadata={'speaker': 'spk0'}),
#  Document(page_content='on la finira en fonction. OK, super. Merci Merlin. Bonne après-midi. Oui, toi aussi. Au revoir.', metadata={'speaker': 'spk0'})]

# %%
from langchain.chains.llm import LLMChain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain_core.prompts import PromptTemplate

# document_prompt = PromptTemplate(
#     input_variables=["page_content", "metadata"], template="""{metadata["speaker"]}: {page_content}"""
# )
document_prompt = PromptTemplate(
    input_variables=["page_content", "metadata"],
    template="""- {speaker}: {page_content}""",
)
document_variable_name = "context"

query = f"""
Write a concise summary of the following text, in fewer than 60 words using the same language as the original text:french
"""

stuff_prompt_override = """Given this text extracts:
-----
{context}
-----
Please answer the following question:
{query}"""

prompt = PromptTemplate(
    template=stuff_prompt_override, input_variables=["context", "query"]
)

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")

# Instantiate the chain
llm_chain = LLMChain(llm=llm, prompt=prompt)

chain = StuffDocumentsChain(
    llm_chain=llm_chain,
    document_prompt=document_prompt,
    document_variable_name=document_variable_name,
)

chain.run(input_documents=docs, query=query)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[35], line 39
#      31 llm_chain = LLMChain(llm=llm, prompt=prompt)
#      33 chain = StuffDocumentsChain(
#      34     llm_chain=llm_chain,
#      35     document_prompt=document_prompt,
#      36     document_variable_name=document_variable_name,
#      37 )
# ---> 39 chain.run(input_documents=docs, query=query)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:574, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     569     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     570         _output_key
#     571     ]
#     573 if kwargs and not args:
# --> 574     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     575         _output_key
#     576     ]
#     578 if not kwargs and not args:
#     579     raise ValueError(
#     580         "`run` supported with either positional arguments or keyword arguments,"
#     581         " but none were provided."
#     582     )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:378, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     346 """Execute the chain.
#     347
#     348 Args:
#    (...)
#     369         `Chain.output_keys`.
#     370 """
#     371 config = {
#     372     "callbacks": callbacks,
#     373     "tags": tags,
#     374     "metadata": metadata,
#     375     "run_name": run_name,
#     376 }
# --> 378 return self.invoke(
#     379     inputs,
#     380     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     381     return_only_outputs=return_only_outputs,
#     382     include_run_info=include_run_info,
#     383 )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\combine_documents\base.py:137, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     135 # Other keys are assumed to be needed for LLM prediction
#     136 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 137 output, extra_return_dict = self.combine_docs(
#     138     docs, callbacks=_run_manager.get_child(), **other_keys
#     139 )
#     140 extra_return_dict[self.output_key] = output
#     141 return extra_return_dict
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\combine_documents\stuff.py:244, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     242 inputs = self._get_inputs(docs, **kwargs)
#     243 # Call predict on the LLM.
# --> 244 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\llm.py:293, in LLMChain.predict(self, callbacks, **kwargs)
#     278 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     279     """Format prompt with kwargs and pass to LLM.
#     280
#     281     Args:
#    (...)
#     291             completion = llm.predict(adjective="funny")
#     292     """
# --> 293     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\_api\deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:378, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     346 """Execute the chain.
#     347
#     348 Args:
#    (...)
#     369         `Chain.output_keys`.
#     370 """
#     371 config = {
#     372     "callbacks": callbacks,
#     373     "tags": tags,
#     374     "metadata": metadata,
#     375     "run_name": run_name,
#     376 }
# --> 378 return self.invoke(
#     379     inputs,
#     380     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     381     return_only_outputs=return_only_outputs,
#     382     include_run_info=include_run_info,
#     383 )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\llm.py:103, in LLMChain._call(self, inputs, run_manager)
#      98 def _call(
#      99     self,
#     100     inputs: Dict[str, Any],
#     101     run_manager: Optional[CallbackManagerForChainRun] = None,
#     102 ) -> Dict[str, str]:
# --> 103     response = self.generate([inputs], run_manager=run_manager)
#     104     return self.create_outputs(response)[0]
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain\chains\llm.py:115, in LLMChain.generate(self, input_list, run_manager)
#     113 callbacks = run_manager.get_child() if run_manager else None
#     114 if isinstance(self.llm, BaseLanguageModel):
# --> 115     return self.llm.generate_prompt(
#     116         prompts,
#     117         stop,
#     118         callbacks=callbacks,
#     119         **self.llm_kwargs,
#     120     )
#     121 else:
#     122     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     123         cast(List, prompts), {"callbacks": callbacks}
#     124     )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\language_models\chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\language_models\chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\language_models\chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_core\language_models\chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_community\chat_models\openai.py:441, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     435 message_dicts, params = self._create_message_dicts(messages, stop)
#     436 params = {
#     437     **params,
#     438     **({"stream": stream} if stream is not None else {}),
#     439     **kwargs,
#     440 }
# --> 441 response = self.completion_with_retry(
#     442     messages=message_dicts, run_manager=run_manager, **params
#     443 )
#     444 return self._create_chat_result(response)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\langchain_community\chat_models\openai.py:356, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     354 """Use tenacity to retry the completion call."""
#     355 if is_openai_v1():
# --> 356     return self.client.create(**kwargs)
#     358 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     360 @retry_decorator
#     361 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\openai\resources\chat\completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\openai\_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File c:\Users\benja\miniforge3\envs\basic_code\lib\site-packages\openai\_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# BadRequestError: Error code: 400 - {'error': {'message': "This model's maximum context length is 16385 tokens. However, your messages resulted in 24790 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}

# %%
# As the context is too long for this model (but not to much, we used up to 16/21 = 1.3 times the maximum amount of token, so it's only a 30% overflow)
# Let us try reordering documents and loading from a chroma DB with
from langchain_community.document_transformers import (
    LongContextReorder,
)
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

retriever = Chroma.from_documents(
    docs, embedding=OpenAIEmbeddings(api_key=OPENAI_API_KEY)
).as_retriever(
    search_kwargs={"k": int(794 / 1.4)}  # taking into account the previous remark
)
query = "Write a concise summary of the following text, in fewer than 60 words using the same language as the original text: french"

# Get relevant documents ordered by relevance score
docs2 = retriever.invoke(query)

reordering = LongContextReorder()
reordered_docs = reordering.transform_documents(docs2)

chain.run(input_documents=reordered_docs, query=query)
# Out:
# "La conversation concerne la prise de notes et la synthèse des appels téléphoniques afin d'améliorer la productivité et les performances des commerciaux. L'objectif est de créer un outil d'intelligence conversationnelle qui analyse les appels et génère des résumés automatiques pour faciliter la formation et le coaching des équipes de vente."

# %%
# Problem using jq library on windows... Hence using own definition of the JSOLoader following https://github.com/langchain-ai/langchain/issues/4396
import json
from pathlib import Path
from typing import Callable, Dict, List, Optional, Union

from langchain.docstore.document import Document
from langchain.document_loaders.base import BaseLoader


class JSONLoader(BaseLoader):
    def __init__(
        self,
        file_path: Union[str, Path],
        metadata_func: Optional[Callable[[dict, dict], dict]] = None,
    ):
        """
        Initializes the JSONLoader with a file path, an optional content key to extract specific content,
        and an optional metadata function to extract metadata from each record.
        """
        self.file_path = Path(file_path).resolve()
        self.metadata_func = metadata_func

    def create_documents(self, processed_data):
        """
        Creates Document objects from processed data.
        """
        documents = []
        for item in processed_data:
            content = item.get("content", "")
            metadata = item.get("metadata", {})
            document = Document(page_content=content, metadata=metadata)
            documents.append(document)
        return documents

    def process_json(self, data):
        """
        Processes JSON data to prepare for document creation, extracting content based on the content_key
        and applying the metadata function if provided.
        """
        processed_data = []
        tmp = ""
        previous_speaker = ""
        for item in data["segments"]:
            content = item["content"]
            speaker = item["speaker"]
            if speaker == previous_speaker:
                tmp += " " + content
            else:
                processed_data.append(
                    {"content": tmp, "metadata": {"speaker": previous_speaker}}
                )
                tmp = content
                previous_speaker = speaker
        return processed_data

    def load(self) -> List[Document]:
        """
        Load and return documents from the JSON file.
        """
        docs = []
        with open(self.file_path, mode="r", encoding="utf-8") as json_file:
            try:
                data = json.load(json_file)
                processed_json = self.process_json(data)
                docs = self.create_documents(processed_json)
            except json.JSONDecodeError:
                print("Error: Invalid JSON format in the file.")
        return docs

# %%
loader = JSONLoader(file_path="demo-segments.json")
docs = loader.load()
docs
# Out:
# [Document(page_content='', metadata={'speaker': ''}),
#  Document(page_content='Oui bonjour Celeste.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Bonjour Merlin. Comment vas-tu ?', metadata={'speaker': 'spk0'}),
#  Document(page_content='Très bien et toi ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Super. Écoute, ça va super. Je suis ravie de commencer mon après-midi avec toi. Je vois que la caméra n'a pas été réparée. Je sais pas si t'es tout seul ou t'es avec...", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, là je t'avoue que avec le gros brume que j'ai...", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ah oui ! Ok, pas de problème. Non, mais je ne savais pas si du coup, Arthur et l'autre Merlin se connectaient derrière toi ou s'il y avait d'autres personnes qui arrivaient.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, alors Merlin, je ne sais pas, mais Arthur, ben voilà, il est là, parfait.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Ben voilà. Bonjour Arthur, enchanté. Salut Arthur.', metadata={'speaker': 'spk0'}),
#  Document(page_content='Je suis là, bonjour Celeste.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Ah c'est Merlin, parfait. Donc, je suis juste contente de reposer le contexte par rapport à notre échange de la dernière fois et puis l'objectif de cette petite call tous ensemble.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui, effectivement, l'idée c'était, si ça vous va, l'agenda du coup juste que je vous propose effectivement, c'est peut-être juste de faire un petit tour de table avant pour connaître un peu du coup le niveau de connaissance de Merlin et de Arthur sur Modjo et connaître un peu exactement vos scopes et vos enjeux un peu personnels justement sur vos scopes de collectif chez RoundTable. Ensuite, évidemment, je vais faire un récap' des enjeux discutés avec Merlin lors de notre précédent call et pour être sûr qu'on est tous les quatre alignés. Et évidemment, on va très vite s'immerger dans Modjo pour que vous puissiez justement vous projeter et voir en quoi ça pourrait évidemment vous aider sur vos enjeux à la fois côté sales et CSM et la fin de l'échange, ça serait du coup de planifier la suite. Pour vous, l'idée, c'est d'avoir un peu de la visibilité du coup sur notre business model et pour moi, c'est pouvoir vous préparer une proposition tarifaire sur mesure et du coup la plus adaptée que ça soit en termes de nombre de licences. Est-ce que ça vous va comme comme comme Ouais, pas mal. L'échange. Ouais, OK, juste je peux me permettre. Merlin et Arthur, est-ce que vous votre caméra fonctionne ou pas?", metadata={'speaker': 'spk0'}),
#  Document(page_content='La caméra, je vais voir si elle fonctionne.', metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, génial, trop cool. OK, ça va super. C'est sympa. Merci. Comme ça, plus qu'en plus, on est trois. Comme ça, je suis sûre. Si vous avez des questions, peut être aussi d'avoir le visuel. Juste avant du coup de commencer, je suis juste curieuse de savoir Arthur et du coup Merlin, quel est juste votre niveau de connaissance de Modjo et qu'est ce que vous faites exactement chez RoundTable pour être sûr de présenter?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Et bien, on a radé un petit peu, donc c'était pour améliorer les performances commerciales, notamment grâce à l'IA. En gros, c'est par rapport à un script, voir à quel degré de similitude on est par rapport au script. Et donc, du coup, pour améliorer tout ce qui est nous, les relations clients après l'espèce commerciale et aussi l'espèce commerciale pour avoir de nouveaux clients. Et du coup, quand je suis à RoundTable, l'équipe d'équipe customer success et on est sur la partie commerciale opérationnelle.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ouais, moi, je m'occupe de toute la partie opérationnelle. Je suis associé à Merlin qui est ici dans la call et connaissance de Modjo au même moment avec Merlin, puisque c'est on était dans la même réunion le jour où on nous en a parlé. OK, donc voilà en synthèse.", metadata={'speaker': 'spk1'}),
#  Document(page_content="OK, génial. Et du coup, justement, je crois que vous avez passé pas mal de temps ces dernières semaines ou ces derniers jours chez Furnitures. Est ce que vous avez pu échanger avec SquareChair? Enfin, du coup, je crois que c'est Lancelot et Lancelot. Oui, c'est ça. Lancelot, le CEO de SquareChair qui est dans le même incubateur que vous.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, on n'a pas parlé avec Lancelot spécialement sur ça, je t'avoue.", metadata={'speaker': 'spk1'}),
#  Document(page_content="OK, non, mais pas de problème. C'était par curiosité. OK, super clair.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Pour le savoir, on se gardera avec lui la semaine prochaine.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Écoutez, bah écoutez, avec plaisir, effectivement, ces équipes l'utilisent. Depuis, c'était mon premier client parce que moi, je suis à eux depuis trois mois maintenant et du coup, qui de mieux qu'un utilisateur Modjo pourra vous partager des insights. Donc, trop bien si vous le rencontrez. Du coup, pour récapituler ce qu'on s'est dit la dernière fois du coup avec Merlin et être sûr qu'on est sur le même niveau d'information. Moi, ce que j'ai compris, c'est que vous avez des grosses ambitions de croissance. Aujourd'hui, vous avez des équipes principalement à Lyon, mais aussi un peu à Barcelone. Du coup, il y a un enjeu de manager à distance pour être plus efficient. Vous avez des process aujourd'hui qui est du coup, je reprends tes termes à Merlin. Je ne sais pas du tout de ma bouche, mais qui sont encore un peu brouillon. Et du coup, vous avez un enjeu de scalaire un peu sur cet aspect. Du coup, formaliser plus les process pour aller chercher plus de méthodologie dans votre approche, que ça soit côté CSM et SAIS. Et du coup, quand vous parlez justement, quand on parle du coup de performance de croissance aujourd'hui, tu parlais aujourd'hui de vos deux enjeux qui étaient augmentés drastiquement. Le MRR généré aujourd'hui, c'est un peu possible que ça soit sur la partie tunnel d'acquisition en termes de volume ou de panier moyen. Et c'était aussi de fidéliser du coup les clients côté CSM. Et pour ça, du coup, vous avez besoin d'un ou vous voudriez vous projeter sur un outil d'intelligence conversationnelle. Du coup, côté sales, c'était vraiment pour l'aspect amélioration du discours, peut être test aussi de discours en fonction de vos nouvelles offres pour aller peut être chercher justement un panier moyen plus important. Aussi, réponse aux objections et faire monter tout simplement vos recrues en compétences, parce que notamment, c'est des profils assez juniors et alternants. Si je ne m'abuse. Et côté CSM, c'est aussi de challenger sur la partie plutôt démo avec démo et avoir une expertise CSM vraiment encore plus poussée sur votre plateforme. Et on avait parlé d'un dernier sujet qui était moins lié à la performance, mais qui serait amené certainement à être challenge. C'était la partie productivité sur Hubspot. Merlin, tu disais que que vous l'utilisiez peut être aujourd'hui à 30% et que 99% vous n'étais pas sûr à 99% que les notes dans les opportunités soient bien prises et qu'il y aurait potentiellement des sujets de passations d'information entre CSM. Et du coup, c'est tout l'idée de Modjo d'un outil global, c'est de vous aider sur ses parties performance et productivité. Est ce qu'on est toujours aligné? Est ce qu'il y a d'autres points que vous vouliez voir et qui sera important pour vous pour la démo?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, tu as très bien résumé.', metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, génial. Et qu'est ce que je veux dire? Oui, non, dernier dernier aspect. Du coup, on avait à parler un tout petit peu moins de ça la dernière fois, Merlin, j'étais curieuse de savoir aujourd'hui concrètement qu'est ce que vous mettez en place comme routine de coaching à proprement parler, puisque du coup, vous aimeriez bien challenger sur le discours, sur les objections. Mais du coup, à date, sans un Modjo sans un outil pour vous y aider, qu'est ce qui est mis en place par les managers?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Pas grand chose. Ce n'est pas le problème. Donc, sur la partie CSM, on met en place depuis un mois, un mois et demi des tests de pitch juste sur la partie pitch démo fonctionnel. Donc, on faut qu'on garde justement cette vélocité sur ces tests. Et c'est tout ce que l'on fait, en tout cas sur la partie CSM aujourd'hui. Je pense qu'il y a d'autres éléments à prendre en compte aussi sur la qualité des process qui sont traités. Et sur la partie sales, tu peux dire deux mots, mais voilà, je sais qu'il y a des écoutes pendant un moment qui étaient faites sur Ringover, du double écoute ou même après coup, mais par quelque chose de régulièrement.", metadata={'speaker': 'spk2'}),
#  Document(page_content="On fait principalement des workshops. OK. Des workshops en règle générale, c'est une fois par mois.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ça se matérialise comment? Concrètement, ces workshops, c'est quoi l'objectif?", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est en gros, moi, je demande, donc il y a des ateliers à Ringover qui nous permettent de les écouter. Clairement, il n'y a pas de double écoute dans le sens où on n'est à personne qui a le temps de faire de la double écoute. En tout cas, moi, je n'ai pas le temps de faire la double écoute. Donc, on demande celle de venir avec d'enregistrer des bad calls et des good calls en gros, au nombre de cinq par mois. Et ils viennent avec en atelier.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Ouais.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Workshop. On travaille comme ça, notamment beaucoup. Le traitement des objections. Voilà, c'est aujourd'hui, c'est la méthode où qui est qui est qui est faite côté sales. Donc, c'est une fois par mois. Sachant que ça, effectivement, ça c'est là depuis septembre. Ça s'est arrêté puisqu'on a eu pas mal de nouvelles recrues qui sont rentrées, etc. Donc, en gros, il y a une petite pause sur septembre, octobre. Le temps de remettre l'équipe à flot. Donc là, ça va reprendre. On a arrêté, je crois, le dernier, c'était en juillet, début juillet, en été. Donc voilà, septembre, octobre, il n'y en a pas. Là, on va reprendre en novembre. Sachant que nous, les nouveaux sales, quand ils rentrent, on les fait d'abord travailler sur du pur call à froid. Donc, du pur call à froid, on ne les fait pas travailler sur des pros spéciaux de notre CRM. On travaille sur le script, le discours, on va dire en condition dure pour être potentiellement plus efficace en conditions plus clémentes. Et au niveau du script, tout est scripté, j'allais dire, en fonction des différents cas, que ce soit du prospect froid au prospect. Il y a deux doigts de signer et qui a déjà fait une période d'essai. Donc, on a à peu près tout scripté. Néanmoins, on n'est pas dans une logique de... Moi, j'ai tendance à dire aux sales que l'important, c'est qu'ils sont en capacité d'avoir la profondeur de traiter les objections et la résilience de s'accrocher. Après, effectivement, ça reste de l'impro en fonction de qui tu es en face de toi. Donc, tu ne peux pas avoir un discours de robot, même si au début, tu l'as un petit peu sur les trois et six premiers mois. Ils sont un peu en mode robot et c'est normal. Et j'allais dire, c'est même les robots qui sont en mode robot, parce que ça veut dire qu'ils suivent le script. Néanmoins, par la suite, ce n'est pas le robot qui signe. C'est lui.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Et du coup, juste petite question. Que ça soit sur les sales qui ont déjà eu leur phase de ramp-up ou les junior aujourd'hui, donc, effectivement, ils testent le pitch, ils répondent à des objections. Concrètement, là, tu fais comment juste pour t'assurer qu'ils répondent bien? Parce qu'il y a les workshops que vous mettiez en place. Mais aujourd'hui, à date, tu fais comment? Tu es sur le flot, tu les écoutes comme ça, tu fais de la réécoute via ring-over. Comment tu les accompagnes dans leur montée en compétence?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Nous, en gros, on a un suivi hebdo. Le lundi, on a une réunion d'équipe. Le vendredi, on a une réunion individuelle. En réunion individuelle, ils ont pris l'habitude de venir avec leur, entre guillemets, avec leurs problématiques, leurs objections. Ils viennent souvent me demander des arguments. Effectivement, à l'instant T maintenant, alors avant, ce n'était pas obligatoirement le cas avant l'été, mais maintenant, on a la chance d'avoir une sorte d'open space sur lequel moi, je peux entendre les appels. Donc, ça me permet d'intervenir quand je suis là pour éventuellement donner des petits des petits feedbacks. Voilà des tips. Mais jusqu'alors, on va dire que jusqu'alors, on était sur un modèle où, comme je te dis, il n'y a pas de réécoute à part le workshop. Il n'y a pas de réécoute. Après, les celles chez nous ont participé pour la plupart, ou en tout cas, ont au moins participé une fois un salon. Salon, ça veut dire que, voilà, j'allais dire, il n'y a pas derrière un téléphone, tu ne peux pas te cacher, tu es face à la personne et tu dois tu dois débiter. Et aujourd'hui, tous les sales, on va dire, ont participé au moins à un salon et ils ont déjà conclu des ventes. Donc, on a quand même un niveau de performance minimum qu'on sait être capable de tenir. Le problème, c'est la recherche de la... Le problème, c'est de travailler sur l'amélioration de la performance. C'est vraiment ça. C'est augmenter le nombre de conversions par mois, le nombre de closures, c'est le sujet.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Tu vas aller chercher combien en taux de conversion aujourd'hui ? Pardon ? Tu vas aller chercher combien en taux de conversion aujourd'hui ? Enfin, vous êtes à combien en taux de conversion et tu vas aller chercher combien dans l'idéal ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="En gros, aujourd'hui, on veut aller... On a nous un gros top service qui est la customize, la marque blanche chez nous. Si tu regardes un petit peu...", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ici, j'ai regardé votre site à 139 euros.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Voilà, notre objectif, c'est d'être tous les mois au moins 10. Donc, ça, c'est vraiment notre objectif d'être à 10.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Et aujourd'hui, vous êtes à combien ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Aujourd'hui, on tourne entre 6 et 8 en gros. Donc, on est un cran en dessous. Ce mois-ci, on va aller faire les 10 parce qu'on sort d'un salon. On va dire que le taf a été bien fait, mais dans la récurrence... Et d'ailleurs, on a une performance assez ératique dans le sens où il y a des mois, je ne sais plus, en juin, on en fait 5 et en juillet, par exemple, on en fait 10. Donc, en fait, on est vraiment comptable au niveau de la perfo. C'est ça qui est le plus frustrant. C'est là qu'on aimerait avoir un outil qui potentiellement nous permette d'améliorer de manière continue la performance des sales.", metadata={'speaker': 'spk1'}),
#  Document(page_content="En termes de chiffre d'affaires ou de MRR ou ARR à aller chercher sur l'année, tu as une idée de ce que ça représenterait d'augmenter justement cette performance qui est aujourd'hui pas forcément stable de moins en moins.", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est-à-dire le fait d'atteindre l'objectif, qu'est-ce que ça apporte ton MRR en plus ?", metadata={'speaker': 'spk1'}),
#  Document(page_content="Aujourd'hui, c'est quoi ton objectif ? C'est quoi le manque à gagner en termes d'ARR que tu as en visibilité le fait de ne pas être à 10 aujourd'hui ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Tu peux parler de son MRR.', metadata={'speaker': 'spk1'}),
#  Document(page_content='MRR, oui.', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est un jeu galère quand il met son niveau. Là, c'est simple. On a fait 7 marques blanches en septembre. L'objectif, c'est 10. C'est à peu près 500 euros par mois la marque blanche. C'est 1500 euros mensuels qui tournent par an.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Et du coup, ça c'est par sales ? Pour l'équipe ? Au global ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Le sales doit faire 3 marques blanches par mois. Si on voudrait qu'ils soient au niveau, il faut qu'ils fassent 3 marques blanches par mois. Normalement, s'ils en font 3 par mois, sachant que moi également j'en fais aussi, ça en fait 12 tout de moins.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Attention, ça c'est nos chiffres aujourd'hui. Les chiffres de TAM4, c'est pas ce que ça donne. On leur fait le calcul avec Samuel pas plus tard que ce matin.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Ça serait plutôt combien du coup ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Là, on serait plutôt à nombre de marques blanches par personne par mois, 5. Après, on s'est fixé des objectifs.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Par mois, c'est pas possible. T'es à 15 marques blanches.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Si on veut suivre ce qu'on est censé progresser, comment on est censé progresser, en tout cas sur 2024, on devrait être à terme à ce nombre-là. Dans tous les cas, on a un gros gap entre haut et bas.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Il y a un gros gap. On parle juste de marques blanches. Les autres sont complètement dépriorisés ? Est-ce que vos sales performent plus sur les autres ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Là-dessus, Celeste, c'est compliqué parce que tu poses des questions auxquelles on n'a pas de réponse.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Ok, pas de problème.', metadata={'speaker': 'spk0'}),
#  Document(page_content="La question est pertinente, mais tu poses des questions auxquelles on n'a pas de réponse.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, c'est pas grave.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Le problème, c'est que le sales contribue à la vente de licence les deux autres, sauf qu'on ne sait pas le traquer. On ne sait pas pourquoi nos clients, quand le sales leur donne un code, ils ne l'utilisent pas spécialement. On se trouve des sales qui aident à vendre la licence à 49 ou 69 euros, mais on ne sait pas si la vente a été faite par X ou Y. On sait que l'équipe contribue, donc on a une sorte de prime d'équipe là-dessus. Mais on n'arrive pas à l'individualiser. Aujourd'hui, alors que pour la marque blanche, on sait parce que le devis est fait par le sales, par le propriétaire de la transaction, donc là, c'est beaucoup plus facile. Moi, alors, dans le suivi mensuel, comme je les ai deux fois par semaine, je sais quel deal X ou Y a signé, donc je suis capable d'identifier qui a fait son taff, si c'est bon, si ou non.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Traquer dans un call, tel ou tel offre, ça vous permettrait d'avoir plus de visibilité sur ce qui pourrait être poussé par vos sales ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Oui, identifier ce qui a été vendu dans le call et être capable de dire que c'était Jacky qui a vendu ça. Oui, ça peut être intéressant.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, clairement, c'est un truc que je n'avais pas en tête, donc je vous montrerai. J'ai une dernière question et après, je vous promets, on switch sur la démo, mais on n'a pas trop parlé du coup de la partie CSM. J'ai compris qu'il y avait un enjeu sur la partie plutôt démo de votre côté. Juste pour comprendre aujourd'hui, c'est quoi les axes d'amélioration d'une démo. Concrètement, qu'est-ce que vous cherchez exactement à faire ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Je pense qu'on peut rester sur le périmètre size.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Size, ok.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Très clair. Le démo, effectivement, peut l'améliorer, mais la personne est déjà sur le produit et c'est des informations qu'on vient lui donner. Donc oui, il y a de l'amélioration à faire, mais là pour la démo, je pense qu'on peut focusser sur les sales.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ok, donc, focussons dans ce cas-là sur les sales. On n'avait pas sur la partie compte rendu, prise de notes. Tu me disais, Merlin, pendant le dernier échange que du coup, à ta connaissance en tout cas, aujourd'hui, c'est qu'il y avait peu de prise de notes de fait. Du coup, l'autre, Merlin, je crois que c'est toi qui manage les sales. À ton niveau, c'est quoi ta connaissance ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est dans les deux sens. Aujourd'hui, on n'est pas bon dans les deux sens, dans le sens où le sales n'a pas tout le temps pris les notes et souvent le CS ne prend pas les notes du tout en post démo, ce qui fait qu'on a eu sur mai-juin des signatures qu'on a perdu par mauvaise communication CS Sales et Sales CS. Ce qui est sûr, c'est que je suis sûr à 99% qu'il n'y a pas toutes les informations entre les Arthur-Panthéonier vu que deux ou trois fois...", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, je mets les pieds là où il ne faut pas, mais l'idée, c'est de faire en sorte que ça ne se passe plus.", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est clair que les notes, c'est quelque chose qui est très important. Tout le monde a une fois commis l'erreur, voire même la commet de temps à autre, ça, c'est certain. Et si on peut avoir un système de prise de notes automatisée grâce à une IA, oui, c'est intéressant.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok. Du coup, aujourd'hui, vous savez pourquoi ce n'est pas fait ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Pourquoi ce n'est pas fait ? Parce qu'en fait, le CS, il a du mal à le faire parce qu'il fait sa démo en live avec son ordinateur. Et du coup, pour faire son CR, il faut qu'il s'arrête 5 minutes après et qu'il se dise, je fais ma synthèse. Donc là, il faut enlever la synthèse, il faut y penser. Et des fois, le pauvre CS, il enchaîne une réunion avec un autre CS.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Et côté sales sur la partie call ?', metadata={'speaker': 'spk0'}),
#  Document(page_content="Alors côté sales, j'allais dire chez les sales, c'est peut-être l'endroit où c'est peut-être le plus fait parce que déjà, il est libre même. Donc en fait, un sales pour lui-même, il va prendre des notes. Mais les fois où il ne va pas le faire, ça peut être parce qu'il n'est pas à l'aise dans son call et qu'il se fait malmener et que du coup, on va dire que voilà, il a subi le rendez-vous et du coup, il a potentiellement besoin de souffler derrière. Et voilà, soit il enchaîne aussi des réunions, ça peut arriver puisqu'il peut avoir plusieurs réunions prévues avec des prospects. Et après, il y a aussi au-delà de l'aspect faire, il y a la qualité de la synthèse, il y a la qualité du CR, c'est deux choses différentes. Il y a faire et faire et effectivement, certains ont moins l'esprit synthétique que d'autres.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, écoutez, très clair, dans ce cas-là, on regardera bien cet aspect aide à la prise de notes qui aidera du coup les deux équipes. Est-ce que vous avez des choses à rajouter ou est-ce qu'on peut passer du coup au partage d'écran et à la démo ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Non, c'est complet.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Ok, génial. Merci en tout cas pour ce complément d'information qui va très certainement enrichir cette démo. Je vous partage dès maintenant mon écran, est-ce que vous le voyez bien ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Génial. Du coup, je compte sur vous pour vraiment m'arrêter si vous avez des questions et de me dire si jamais vous voulez passer parce que ça ne vous intéresse pas particulièrement. Normalement, j'ai bien préparé, donc ça ne devrait pas être le cas, mais n'hésitez pas vraiment à m'interrompre pour que ça soit le plus interactif possible. Du coup, bienvenue sur Modjo Comme vous pouvez le voir, c'est mon Modjo à moi. Je vous partage vraiment en toute transparence tous les échanges que j'ai au quotidien avec mes prospects et mes clients. Techniquement, comment ça va se passer ? Modjo ça va venir se plugger à votre outil de VOIP, donc Ringover, à vos outils de Visio et à votre CRM Hubspot. L'idée du coup, c'est qu'on va venir récupérer les enregistrements de ces échanges à des fins de performance, de productivité. Ce qu'on va faire concrètement, c'est qu'on va retranscrire en texte tout ce qui va être abordé, on va dire toute la dialectique, que ça soit côté commercial, CS ou client prospect. Concrètement, juste pour que vous ayez une idée, rien ne va changer pour côté Sales ou CS. Ce que je veux dire, c'est qu'il n'y a pas de manip manuel à faire pour qu'un call, une Visio remonte, tout est fait automatiquement.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Excusez-moi, Celeste, les CS font beaucoup de Google Meet ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui. C'est géré ?", metadata={'speaker': 'spk1'}),
#  Document(page_content="Du coup, Google Meet, exactement, c'est bien pris en compte. Toutes les vidéos Google Meet vont remonter automatiquement aujourd'hui dans Modjo. On off ? On off, non. On off aujourd'hui, on n'est pas intégré à on off. En revanche, on est intégré à Ringover et à d'autres outils de VOIP, mais pas à on off aujourd'hui.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ce n'est pas grave, on off, normalement, c'est fait que pour beaucoup, pour des réceptions de SMS, pour débloquer des comptes, etc. Donc, ce n'est pas problématique.", metadata={'speaker': 'spk2'}),
#  Document(page_content="C'est plus de l'écrit du coup plutôt que de l'audio finalement ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est plus pour l'opérationnel que de l'échange pur avec du client.", metadata={'speaker': 'spk2'}),
#  Document(page_content="En tout cas, effectivement, à date, on n'a pas encore d'intégration avec on off. Du coup, à date, on ne récupérerait pas ces échanges. OK. Du coup, l'ADN de Modjo c'est d'être le plus collaboratif possible. Et du coup, que ça soit au sein des équipes sales, customer success, entre managers, managers. Et du coup, comme vous pouvez le voir, on peut avoir accès à mes échanges, aux échanges du coup de mon équipe et aux échanges de toute l'entreprise. Une fois que j'ai dit ça, Modjo c'est également aussi la mémoire de l'entreprise, la mémoire client. Donc, par exemple, si je veux prendre par exemple un de mes, je vais faire encore mieux, je vais prendre SquareChair. SquareChair, comme je vous le disais, c'est une des start-up incubées chez Furnitures. Et du coup, ce qu'on peut faire, c'est qu'on va pouvoir filtrer finalement sur ce compte client. Là, vous pouvez voir qu'il y a effectivement aujourd'hui 10 échanges qui sont remontés. Ça passe de mon appel de prospection, ma discovery, bref, ma démo, l'offre tarifaire, comme aussi tous les échanges que l'équipe aujourd'hui de Modjo Customer Success a avec les équipes. Donc vous voyez vraiment, on part vraiment d'une base énorme d'échanges et on peut filtrer en fonction évidemment des clients pour avoir vraiment une historisation maximum des échanges. Déjà, est-ce que pour vous, ça c'est clair ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui, oui, oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Ok, j'ai une idée. Alors, du coup, ce que je vous propose, c'est qu'on va partir sur le premier pilier qui est vraiment le pilier performance. Donc on va prendre du coup la performance commerciale. Aujourd'hui, vous avez des vrais enjeux d'amélioration du discours, de comprendre aujourd'hui ce qui est dit dans les échanges, d'amélioration aussi des réponses à des objections. Vous avez vraiment besoin d'avoir de la visibilité sur ce qui se passe dans les calls. Je ne me trompe pas, je suis fidèle. On est d'accord ? Ok, génial.", metadata={'speaker': 'spk0'}),
#  Document(page_content="On va avoir surtout de l'information de ce qui se passe dans les calls.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, et ce qui va se passer, c'est que par exemple, je vais prendre du coup des échanges qui ont eu lieu, par exemple, sur le quarter. Donc ce que vous pouvez voir déjà, c'est qu'il y a des tags en fonction de la typologie des échanges. Il y a effectivement des calls de qualification, de démos. Vous aurez des typologies d'échanges évidemment en fonction de votre cycle de ventre.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Comment ces tags sont mis en fait ?', metadata={'speaker': 'spk2'}),
#  Document(page_content="Alors typiquement, là, c'est des appels, donc c'est des appels de prospection. Donc là, vous pouvez voir que c'est du cold call. Autrement, c'est l'intelligence artificielle.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Comment Modjo sait que c'est du cold call ?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Parce que c'est lié du coup à votre ringover ou à votre aircall ou à votre outil de VOIP. Ça remonte automatiquement ce tag.", metadata={'speaker': 'spk0'}),
#  Document(page_content="D'accord, donc c'est sur ringover et il faut mettre la bonne information.", metadata={'speaker': 'spk2'}),
#  Document(page_content='Quand tu raccroches… Ce qui a été dit.', metadata={'speaker': 'spk1'}),
#  Document(page_content="Il y a deux choses en fait. Par exemple, il y a le nom du meeting. Vous faites une intro, l'intelligence artificielle va venir identifier la typologie de rendez-vous.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Donc là, par exemple, on a accès… Par rapport à l'intro qui a été faite, si tu présentes le produit, c'est que c'est un cold call froid. Si tu attaques directement sur une… Comme on s'est dit la dernière fois… C'est la même chose pour le démo.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Modjo sait à tous les coups classifier ses échanges.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Il sait classifier ses échanges. Alors là, qu'est-ce qui se passe ? Parce que j'ai mis tous les appels. Ça va pas aller. Attendez. Il sait classifier ses échanges. Ces échanges, pardon. Ça m'épette en fonction de la typologie des calls. Ça peut mettre deux, trois minutes. Par exemple, moi, j'ai une démo qui remonte. C'était une heure de démo. Le temps que la plateforme identifique, c'est une démo. Ça peut mettre deux, trois minutes à être taggé comme une démo. Mais effectivement, c'est l'outil qui vient le tagger. Là, par exemple, vous pourriez avoir accès à toutes les démos aujourd'hui qui ont eu lieu chez Modjo sur le mot. OK ? Est-ce que c'est plus clair pour vous déjà, ça ? Oui, oui, oui. OK, génial. Par exemple, ce qu'on voudrait faire, c'est regarder tous les échanges qui ont eu lieu sur ce quarter, par exemple, des discoveries. Parce que notamment, généralement, dans les discoveries…. Parce que je vous demande un exemple où on pitche Modjo. Dans les discoveries, c'est souvent des échanges où effectivement, il y a un pitch ou des objections qui reviennent régulièrement. Ce qui va se passer, c'est que du coup, là, déjà, vous avez accès à l'ensemble des discoveries qui ont eu lieu sur le quarter. Vous allez aussi pouvoir filtrer par équipe ou par user si par exemple, vous voulez coacher en particulier telle ou telle personne. Vous pouvez aussi vous dire, bon, bah moi, je voudrais regarder les meilleurs pitchs qui ont eu lieu ou les meilleures qualifications, les meilleures démos qui ont eu lieu aujourd'hui sur le quarter et qui ont abouti à une vente. Vu que c'est lié à un Hubspot aujourd'hui, vous allez pouvoir filtrer sur, par exemple, toutes les discoveries qui ont abouti à une vente aujourd'hui chez Modjo Donc, vu que c'est effectivement plugé à votre Hubspot, on vient récupérer des informations. Et là, typiquement, on a aujourd'hui neuf masterclass qui sont officiellement des très bonnes discoveries puisqu'en fait, aujourd'hui, ça aboutit à une vente. Est-ce que déjà vous voyez un peu l'idée d'aller chercher de l'information et cette idée d'entonnoir ?", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Super. Alors maintenant, je vais reprendre aussi un call de discovery. Et là, l'idée, du coup, vous voulez suivre finalement la manière dont est pitché aujourd'hui, dont est pitché Modjo en fonction, par exemple, selon vos interlocuteurs, selon les personnes qui aujourd'hui travaillent chez vous. Ce qui va se passer, c'est que du coup, vous allez pouvoir arriver dans un échange. Donc, qu'est-ce que je vais pouvoir prendre comme échange ? Par exemple, je vais prendre groupe Endless, donc une introduction que j'ai eue récemment avec un de mes prospects. Donc là, vous arrivez sur une fenêtre de réécoute d'appels. Vous avez énormément d'informations. Il y a les crescendo. Déjà, vous pouvez voir que directement, c'est lié à votre CRM. Nous, c'est Salesforce, mais vous aurez la même chose avec Hubspot. Vous avez la durée de l'échange. Vous avez la possibilité d'accélérer le moment de réécoute. Sélectionnez du coup que le speaker, si vous voulez réécouter qu'un speaker. Et même traduire et avoir les sous-titres pour être plus efficace dans le moment où vous réécoutez un moment d'appel. Une fois que je vous ai présenté cette fenêtre de réécoute d'appels, il y a un vrai sujet qui est aujourd'hui comprendre comment est pitché, comment est présenté aujourd'hui Modjo. Il y a une fonction, enfin Modjo pardon, excusez-moi, assez haut. Ce qui va se passer, c'est que du coup, avec les chapters, ça va vous permettre de découper déjà votre échange en plusieurs phases. Et déjà, ça va vous permettre de se focusser exactement au bon moment que vous voulez réécouter et challenger. Parce que toute l'idée, c'est de challenger vos sales sur justement leur manière de pitcher ou de répondre à des objections. Ce qui va se passer, c'est que du coup, là, on peut voir qu'à la minute, donc à une minute 15, je vais faire une présentation, du coup ma prospect coralie de Modjo Et ce qui va se passer, c'est qu'un manager aujourd'hui va pouvoir, attendez, hop. Un manager va pouvoir venir cliquer sur justement ce passage du call et pouvoir le réécouter. Est-ce que vous avez entendu le son ou pas ? Non. Non, OK. Écoutez, j'ai pas du… Mais ce qui va se passer, c'est que du coup, vous allez pouvoir réécouter juste le passage où effectivement, « tile size pitch Modjo », pitch à zéro. Donc l'idée, c'est qu'en fait, comprendre comment est pitché, comment est présenté aujourd'hui à zéro et du coup pouvoir challenger sur cet aspect-là du cycle de vente. Je ne comprends pas.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Qu'est-ce que vous apportez de plus que Ringover ?", metadata={'speaker': 'spk1'}),
#  Document(page_content="Alors Ringover, déjà, il faut que tu sélectionnes tes appels un peu à l'aveugle, déjà. Deuxièmement, et tu ne peux pas venir focusser sur un aspect particulier de l'échange, enfin que ça soit une démo, du coup Ringover, ce n'est pas une démo, mais que ça soit… Tu ne peux pas focusser à un moment particulier de l'échange. Là, avec Modjo du coup, on va t'aider à justement pas avoir réécouter 10 minutes d'appels ou 29 minutes d'appels, mais réécouter finalement pile le moment qui paraît essentiel à coacher.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ouais, OK. Sauf que…, juste le moment de l'objection ou le moment OK dans le sens où… J'ai envie de dire tout le moment de l'appel.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Tout le moment de l'appel est important ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="On a eu le chien de nos colocs qui est venu s'exploser contre la porte.", metadata={'speaker': 'spk1'}),
#  Document(page_content="D'accord, pas de problème.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Pour montrer le pauvre Padi. J'allais dire, ouais, tout le moment de l'appel amène en partie à cette situation. L'appel en lui-même en complet est important. Par contre, effectivement, dans le cadre d'une objection auquel le sales n'arrive pas à répondre ou un manque de résilience, ça peut être intéressant, mais souvent ça se passe ça à la fin du call. Il y a rarement un truc qui se passe au milieu du call. Moi, clairement, aujourd'hui, quand on fait les appels et les écoutes ring-over, je réécoute rarement tous les appels. Je vais écouter les 30 dernières secondes. En fait, les 30 dernières secondes, tu vois là où ça décroche, tu vois là où le sales a manqué de résilience ou alors il a manqué d'argument. Il n'y a pas besoin. Et s'il n'y a même pas eu 30 secondes, là tu sais que c'est sur la manière de faire le discovery que le sales n'a pas été bon, il n'a pas suffisamment rentré. J'avoue que comme ça, je comprends l'idée. L'idée, même si du coup, je me dis que pour moi, soit ça se passe tout au début, soit ça se passe à la fin. Je vois rarement un élément qui se passe au milieu. À part une information importante, et là, le seul endroit où ça me paraît intéressant d'avoir ça, c'est que si vous avez une fonction compte rendu qui reprend tout et toutes les informations importantes du milieu comme de la fin, ça, ça peut être intéressant parce qu'on sait que les sales, ils font des CR où ils oublient des informations.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Oui, effectivement. Du coup, sur cette partie compte rendu, je vais te le montrer. Mais du coup, je vais peut-être prendre un exemple plus parlant sur un cold call. Là, ce que je voulais te montrer, c'était aujourd'hui, comment font les managers ? Ils vont réécouter des moments de présentation de pitch pour pouvoir savoir comment Celeste, comment Charles, comment X ou Y personne, pitch Modjo RoundTable, et savoir justement où est-ce qu'il faut l'améliorer. Il y a cette première aspect, mais du coup, par exemple, si on part justement sur la partie objections, on va prendre par exemple des exemples de cold call. Aujourd'hui, tu vas pouvoir filtrer sur tous les appels où il y a eu des objections. Soit tu veux traquer un sujet en particulier, tous les appels où on a abordé telle ou telle offre, ou les appels où il y a eu des objections, ou des appels où on a partie de concurrence. Ça dépend de quels sont les sujets que tu veux traquer. Par exemple, je prends les appels où il y a eu des objections. Et par exemple, je prends les appels de Caradoc, qui est un de nos nouveaux arrivants et qui a souvent des objections dans ses appels. Ce que je vais faire, c'est que ça te permet déjà d'identifier concrètement où est-ce que des objections ont été abordées. Si je prends un exemple, du coup, de… Ça, c'est quoi le pourcentage de précision ? C'est-à-dire ?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Les objections, comment on va parler d'algorithme, est-ce qu'à 98%, toutes les objections sont bien remontées, sont bien détectées ?", metadata={'speaker': 'spk2'}),
#  Document(page_content="En fait, c'est paramétré lors de la mise en place de Modjo. Par exemple, si tu veux traquer tous les sujets où ont été apportés par exemple des concurrents, grâce au paramétrage, on va pouvoir créer un… On appelle ça un Topix, mais en gros un champ l'écritacle autour de ce sujet-là. Et du coup, on va flagger des mots qui ont été abordés dans le call. Et du coup, ça, c'est l'IA qui identifie que, OK, on a parlé de tel concurrent, on a parlé du mot concurrence. Et ça, pour le coup, c'est 100% fiable, vu que tout dépend du transcript. Mais pour le coup, on a une équipe de data scientists qui travail sur le transcript. Et du coup, aujourd'hui, en termes de qualité, c'est exactement pour ça que des équipes sales font appel à nous. Et autrement, c'est juste l'intelligence artificielle qui le reconnaît dans le discours. Donc ce que je voulais vous partager, par exemple, je prends un appel de prospection qui a été perdu aujourd'hui. L'IA, ce qui permet d'identifier, comme je vous disais, c'était l'objection. Donc tu peux identifier différents sujets. Donc là, par exemple, c'est objection. Là, le manager, ce qu'il va faire, c'est du coup, il va juste venir réécouter ou d'ailleurs juste lire, réécouter ce passage, ce passage et réécouter aussi son size pour voir comment il y a répondu. Là, tu vois, l'objection, elle n'est pas du coup, il y en avait aussi une à la fin, mais l'objection, elle est, on peut l'identifier, la flaguer directement. Du coup, l'idée, c'est pas que tu réécoutes 7 minutes d'appel, mais c'est bien que tu réécoutes potentiellement que cette partie là de l'appel. OK. OK. Donc ça, il y a sa première aspect là. Donc déjà, c'est l'IA identifie des sujets abordés. Le deuxième point, c'est qu'en fait, c'est aussi, c'est évidemment un noté de coaching. Donc là, tu vois, en fait, Catalin, il est venu taguer son manager parce qu'il a besoin d'être sur ce call là. Il va venir taguer son manager et son manager va pouvoir faire une review, donc des feedbacks formalisés, concrets pour justement coacher son sales, son BDR. Pour ça, on a une fonctionnalité qui s'appelle du coup la review, pardon, qui permet en fonction effectivement de la typologie de call de finalement noter, apporter une grille lecture à ton à ton size pour qu'il puisse comprendre ses axes d'amélioration et pouvoir revenir aussi sur ce qui est les feedbacks de son manager. Au lieu que ce soit des feedbacks qui soient faits à la volée et que ça soit entre guillemets un peu oublié et du coup qu'il puisse finalement revenir sur son call. Comment ça se matérialise? Je vous montre. Ça se matérialise de cette manière là. Donc là, typiquement, à la fin, tu as une petite note et du coup le manager là aujourd'hui, Gabriel, il a pu venir réécouter ce call où son manager l'a identifié à telle minute et pouvoir prendre des notes et du coup l'accompagner justement dans sa réponse à des objections. Qu'est ce que tu en penses de ça?", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ça apporte de la précision sur ton appel et pour le retravailler derrière. Ça, c'est sûr. La question que je te poserai à la fin de la réunion, c'est aujourd'hui, comme tu connais notre contexte, est ce que c'est un outil qu'il faudrait mettre en place ou est ce qu'il faut attendre que nous, on soit plus carrés pour après améliorer quelque chose sur un socle propre?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Aujourd'hui, ce que vous me disiez, c'est que vous aviez besoin justement de comprendre un peu les pitches, les réponses à des objections, tester, challenger. La l'idée de cet outil, c'est justement vous donner les moyens de réécouter, challenger, avoir du feedback, comprendre comment réagissent votre prospect aux fonctions de par exemple, quand on pousse telle ou telle offre, par exemple, pourquoi vous avez aujourd'hui un sales qui pousse, enfin, pourquoi vous avez un sales par exemple qui pousse quatre offres de marque blanche et pourquoi il y en a un qui arrive à en pousser qu'une? En gros, c'est comprendre la différence de discours, comment y répondre aux objections. Sans un outil comme ça, c'est beaucoup plus compliqué à suivre, analyser, challenger, faire du feedback en tant que manager.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Après, je pense que aujourd'hui, moi, ce qui m'interpelle avec Modjo c'est le temps que ça doit prendre un manager de faire ce travail là. Ça, c'est le premier point. Je t'avoue que là, comme ça, à chaud, je n'identifie pas trop la différence de temps entre les écoutes Ringover et Modjo. Je n'ai pas le sentiment, moi, je me connecte à Ringover. J'écoute les appels, Merlin peut le faire. On a les appels qui sont dans Hubspot. J'ai du mal à voir à quel endroit vous faites gagner du temps à ce niveau là. Ce qui est sûr, c'est que pour écouter l'appel, il faut prendre du temps. Moi ou Merlin, si on veut écouter les appels, il faut qu'on se mette et qu'on s'assoit et qu'on se dise pendant 30 minutes, on fait des coups de l'appel et qu'on soit sur Ringover ou que ce soit sur Modjo Dans tous les cas, il faut prendre les 30 minutes. Donc après, tu as le fameux sujet où tu dis que vous vous isolez, etc. Mais comme je t'ai dit, pour moi aujourd'hui, j'ai une manière d'isoler parce que quand tu connais un peu la structuration des appels, tu sais que tout se passe au début, voire à la fin. La notion de commentaire, je trouve ça intéressant, mais je vais du mal à comprendre en quoi ce n'est pas un doublon par rapport à Hubspot où tu as ta ligne avec ton call écouté. En fait, tu peux faire un commentaire dessus si tu as écouté en disant ton Sales il dit, il tag Merlin, il dit Merlin, ce call là, j'ai eu des problèmes. Moi, je le réécoute et je lui dis, en gros, je trouve l'UX et la manière dont c'est disposé plus sympa que sur Hubspot dans les faits, ce que je vous accorde. Pour moi, vous venez faire mieux que Hubspot quelque chose qu'ils essaient de faire aussi. Mais il va falloir qu'on rationnalise notre décision car ça a un coût supplémentaire.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Ok, alors du coup, je fais mon mea culpa parce que je pense que je n'ai pas été assez pertinente dans ma présentation. Première chose, c'est que déjà, c'est pas que pour challenger les calls, mais du coup, vous avez un sujet aussi sur la partie démo et du coup, c'est vraiment un outil global. Le deuxième point que je peux partager, c'est qu'aujourd'hui, toutes les équipes qu'on accompagne sont sur du Hubspot téléphonie et par exemple, ou sur du aircall et par exemple, toutes les équipes d'aircall aujourd'hui n'utilisent absolument pas les enregistrements aircall pour réécouter leurs équipes. Pourquoi ? Parce que justement, ils ont besoin absolument de gagner du temps et du coup, tu me disais, ben en fait, je vois pas en quoi ça me fait gagner du temps. Là, l'idée, c'est qu'effectivement, tu puisses vraiment te focuser sur les, enfin sur tous les appels où il y a tel ou tel sujet qui ont été abordés et en fait, pas par un, c'est vraiment industrier. T'as ton process de réécoute aujourd'hui au lieu de...", metadata={'speaker': 'spk0'}),
# ...
#  Document(page_content="Bah écoute, tu vois, on l'a vu hier, les pauvres, ils étaient frustrés. Du coup, ils ont perdu le challenge.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Mais c'est pas sympa. Ça, c'est toi qui a gagné le resto. OK. Oui, bon, du coup, pour revenir. Pour revenir au sujet, du coup, ça sera entre 4 et 5 licences, enfin, ou 4 licences.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Si le manager est compris dedans, ça serait 5.', metadata={'speaker': 'spk2'}),
#  Document(page_content='OK. Mais du coup, toute la partie, donc ça serait que sur la partie call, pas du tout sur la partie vidéo.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Alors la partie vidéo, elle est faite plus par les CSM. Donc dans un deuxième temps, parce que ça, c'est pas aujourd'hui, c'est pas le gros du sujet.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Bah du coup, sur la partie aujourd'hui, du coup, notre business model. Du coup, notre business model, c'est à la licence enregistreuse. Donc, c'est toutes les personnes qui importent de la matière des enregistrements dans Modjo Donc là, ça serait les 4, 5 personnes côté sales. On a un business model où aujourd'hui, du coup, c'est un engagement annuel. Et du coup, le prix à la licence, le prix d'entrée, c'est de 99 euros par licence enregistreuse. Il y a des leviers de négociation, évidemment, possibles en fonction des marges de manoeuvre que vous pouvez avoir. Mais aujourd'hui, du coup, c'est 99 euros par licence par mois.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Nous, on n'a pas de marge de manoeuvre. C'est toi, éventuellement, tu en as. Mais nous, on n'en a pas.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Mais tu imagines bien que si on fait des discounts, il y a forcément des contreparties. Tu dois être meilleur sales que moi. Et du coup, j'imagine que tu as l'habitude de négocier. Du coup, les contreparties, c'est la vélocité en termes de la vélocité en termes de signature, la durée d'engagement et la possibilité aussi de nous faire des introductions auprès de CEO, VP sales, manager sales qui auraient justement les mêmes problématiques, les mêmes enjeux aujourd'hui que vous ou que en tout cas, qui répondraient dont Modjo répondrait en termes de valeur.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Et du coup, pour les trois introductions, combien je gagne ?', metadata={'speaker': 'spk1'}),
#  Document(page_content="5 %. Mais alors aujourd'hui, non, mais écoutez, aujourd'hui, là, le tout, enfin, le sujet de cet échange, c'est du coup de faire une démo et de valider aujourd'hui la valeur et de vous présenter le business model. Moi, ce que je voudrais faire, c'est vous, du coup, vous partage, enfin, vous faire une offre tarifaire personnalisée. Justement, qu'on voit aujourd'hui les leviers de négociation que vous seriez, enfin, qu'on pourrait activer, actionner, pardon, pour effectivement réduire ce prix à la licence. Du coup, moi, ce que je voudrais vous proposer, c'est plutôt un call d'offre tarifaire parce qu'aujourd'hui, c'est comme ça qu'on fonctionne et comme ça, ça nous permettrait d'avoir plus de temps justement sur l'aspect ROI et budget. Je sais pas ce que vous en pensez.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ouais, alors moi, je veux juste te donner une autre information. On a 18 mois pour performer. Voilà. Donc, tout budget supplémentaire qui arrive dans ces 18 mois, il faut qu'il soit justifié ou alors avoir un discount comme Hubspot va nous faire là, même si c'est un discount, il y aura des bananes qui nous font.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Aujourd'hui, de toute façon, Modjo c'est pas un outil qui est mis en place parce qu'il n'y a pas de ROI. Et le ROI ne serait-ce qu'en termes de taux de conversion, si je reste juste sur le taux de conversion et pas le temps économisé et bref et pas mal d'autres aspects. Aujourd'hui, le ROI, c'est plus 20% sur le taux de conversion dans les équipes aujourd'hui qui sont équipées d'un Modjo versus avant avant mise en place d'un Modjo Donc, c'est pour ça que quand tu parlais de coûts tout à l'heure, il faut vraiment voir ça. En fait, aujourd'hui, combien ça peut vous rapporter versus combien ça va vous coûter. Et du coup, c'est tout l'idée d'un prochain échange, c'est de justement voir combien ça pourrait vous rapporter aujourd'hui. Mais du coup, aujourd'hui, quand tu me parlais d'enveloppes budgétaires, tu en as une ou dans tous les cas, vous n'en avez pas?", metadata={'speaker': 'spk0'}),
#  Document(page_content="On en a une. Oui, on en a une après de donner un montant exact. J'en serais incapable. En tout cas, c'est sûr que c'est un montant qui est vraiment minime. Je te dis avec Hubspot, on est en train de négocier à 200 euros près. Donc, tu vois, on en est rendu.", metadata={'speaker': 'spk2'}),
#  Document(page_content='OK. Et du coup, là, je te partageais juste.', metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est normal de négocier Hubspot, vu ce qui nous prenne 200 euros, c'est de survoir un point. Aujourd'hui, on n'a pas de. Ce n'était pas prévu. On a obligatoirement le besoin d'un e-media. Faut voir le ROI. C'est ce que tu as expliqué. Tu as répondu à deux, trois de me pain. Ça donne. Non, ça donne une bonne vision. Fais nous une offre du coup avec. Avec la meilleure offre que tu peux faire. Et puis, on regardera ça. Là, il faut vraiment qu'on coupe parce qu'il faut que l'on enchaine. C'était intéressant. C'était intéressant. Donc, je te remercie pour ton temps.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Juste sur quoi tu as un doute du coup? Ce que tu m'as dit deux, trois pain, ça veut dire qu'il y en a au moins une auxquelles on n'a pas répondu.", metadata={'speaker': 'spk0'}),
#  Document(page_content="C'est pas que vous n'y répondez pas. C'est que, en gros, je ne sais pas si votre... Déjà, j'ai identifié des bonnes pratiques. Donc, merci. Du coup, je vais dire à mes six de faire certaines choses avec maintenant pour à être Hubspotté qui est un peu du Modjo Ça, c'est métier pour rien dans le sens où c'est. C'est j'allais dire, ça fait partie des choses. Vous faites mieux quelque chose que ce qu'est capable de faire en fait concrètement. Mais vous faites beaucoup mieux. Encore une fois, lui, c'est très sympa. C'est vrai que, par contre, à l'instant T, il y a. Je pense des choses qui sont permises par votre outil qu'on peut faire de manière un peu différente avec des outils un peu. On peut bricoler quoi. Après, le bricolage, ça reste du bricolage. Soyons, j'en ai conscience. Mais bon, à voir après, faites nous une bonne offre et puis on rediscute. La notion des CR, c'est un sujet. Vous avez l'air de le faire. La notion de la synthèse d'analytics à la fin, j'aime bien. Donc, live note aussi.", metadata={'speaker': 'spk1'}),
#  Document(page_content='Tu as bien aimé la live note.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Voilà, deux, trois pains. En règle générale, je perds pas le temps. Mais, mais, mais, on va voir ton offre. Et derrière, nous, on va rediscuter en interne. Mais évidemment, effectivement, du budget, il n'y en avait pas de base. Faut voir le ROI. Par contre, clairement, à 1000 euros et 1000 euros ou 500, je suis d'accord avec Antoine. On n'ira pas.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Par mois. Oui, on y va. Là, de toute façon, là, du coup, ce que je vous disais, c'était cinq users à 99 euros. Le prix de base, c'est du coup, ça ferait un 495 de mémoire sans levier d'action.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Voilà, je pense que comme t'as beaucoup de levier d'action, je pense que tu vas actionner plein de leviers pour que ce soit potentiellement.", metadata={'speaker': 'spk1'}),
#  Document(page_content="Bah, écoutez, dans ce cas là, prenons nous un créneau parce que je sais que votre temps est compté. Et du coup, ce que je vous propose, c'est qu'on se prenne un créneau pour vous présenter l'offre.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Au pire, tu nous refais un mail et tu nous redis ou tu nous envoies ton calendrier. On prend le calendrier.', metadata={'speaker': 'spk1'}),
#  Document(page_content="C'est pas plus simple de croiser nos agendas maintenant.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Non, mais je vais gérer le troisième rendez-vous.', metadata={'speaker': 'spk2'}),
#  Document(page_content='Voilà, parfait. OK, super.', metadata={'speaker': 'spk1'}),
#  Document(page_content='Allez, ça marche. Merci à tous les trois. Je reste le Celeste juste pour finir. Oui, ça marche.', metadata={'speaker': 'spk0'}),
#  Document(page_content="Merci. Merci Antoine. Donc, Celeste, oui, encore une fois, outil très intéressant. J'avais une autre question au niveau du on boarding. Comment ça se passe chez vous?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Oui, alors du coup, en termes d'onboarding, du coup, effectivement, Modjo c'est 70 80% la plateforme. Mais c'est surtout que vous avez un accompte manager, donc un consultant qui est là pour vous accompagner de la paramétrage. L'onboarding jusqu'à la fin d'utilisation de Modjo Donc ce que je veux dire, c'est qu'en termes d'onboarding, il y a effectivement un onboarding manager, un onboarding équipe qui est qui est prévu en plus du paramétrage. Et ensuite, tout au long de l'utilisation, vous avez un consultant qui est là pour vous partager des tips marché, comment améliorer votre productivité, comment mieux coacher vos équipes, comment les sales peuvent être plus utilisé Modjo Et donc, ça, c'est tout ça, c'est pris en compte dans le prix de la licence du coup enregistreuse. Donc, en fait, il n'y a aucun coût additionnel par rapport à ce que je vous présenterai. Est ce que je vous ai présenté ne serait ce que les 495 euros. Vous avez vraiment un compte manager qui est dédié. Et on a notamment des gens qui sont qui sont qui sont experts sur des secteurs. On accompagne pas mal de saas dans justement le domaine de la chevalerie comme Gymlib, qui est notre premier premier client aujourd'hui. Ils étaient que trois à l'époque et tu vois maintenant à la taille de Gymlib Gymlib.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Ah c'est Gymlib.", metadata={'speaker': 'spk2'}),
#  Document(page_content="Voilà, donc tu vas très bien connaître. Donc tu vois, ça, c'était un de nos premiers clients. Et vraiment, encore une fois, ils n'ont pas du tout mis en place Modjo quand ils étaient Gymlib de maintenant. Ils sont une armée de ça. Ils l'ont mis en place au démarrage où justement ils avaient besoin de gagner en temps à comprendre exactement les besoins du marché, comment pitcher leurs équipes, comment ils répondaient aux objections et justement passer d'un mode un peu bricolage artisanal à un mode crescendo beaucoup plus processé pour aller chercher des parts de marché, pour aller chercher de la productivité, pour faire en sorte que leur leur junior arrive très rapidement au niveau d'un justement Antonique cofondeur qui, évidemment, est le meilleur sales aujourd'hui, mais que lui se détache progressivement du coup de la vente pour avoir des sales qui prennent le relais. Donc c'est tout l'idée d'un Modjo aujourd'hui.", metadata={'speaker': 'spk0'}),
#  Document(page_content='OK, OK, OK.', metadata={'speaker': 'spk2'}),
#  Document(page_content="J'ai bien répondu à ta question.", metadata={'speaker': 'spk0'}),
#  Document(page_content="J'avais saisi effectivement ça. Et sur les évolutions du produit, est-ce qu'on reste sur le même prix ou est-ce qu'on va être bloqué? Si on veut passer à des évolutions là dans tu dis dans un mois là, est-ce que c'est un complémentaire?", metadata={'speaker': 'spk2'}),
#  Document(page_content="Non, effectivement, il y a absolument ce qui est signé restera signé. Ce que je veux dire, c'est que c'est notamment la fonctionnalité dont je t'ai parlé. Tu vas en bénéficier. On n'a pas de coût supplémentaire en fonction des features que tu choisis. Tu auras accès à toutes les nouveautés. Bref, à tout.", metadata={'speaker': 'spk0'}),
#  Document(page_content="Parce que je te dis ça parce que Intercom, par exemple, qui est un excellent outil, il sort des fonctionnalités régulièrement et il y en a qui ne font pas partie du scope. C'est des modules en fait additionnels. C'est pareil avec des ardoises qui sont colossales pour des boîtes comme nous. Même si c'est des outils qui sont très pertinents. Donc voilà, nous, ce que je peux juste te dire, en tout cas, c'est que on est prêt à s'engager. En tout cas, sur les 18 prochains mois avec un tarif très très préférentiel. Très sincèrement et après, continue avec vous. Il n'y a pas de raison à ce que, en tout cas, moi, je crois en cet outil là. Ce n'est pas le problème. Aujourd'hui, nous, le frein, c'est à la fois le tarif et un frein mineur. C'est ça, il faut qu'on en discute en interne. C'est le temps à accorder après sur cet outil là. Si c'est pour avoir un outil pour dire qu'on a Modjo mais derrière qu'on ne l'exploite pas. Parce que aujourd'hui, on a des outils qu'on n'exploite pas comme il se devrait, comme il devrait. Ça ne nous servira à rien. Mais ça, c'est plus surprenant à se mettre d'avis.", metadata={'speaker': 'spk2'}),
#  Document(page_content="OK, effectivement, après, tu vois, sur la partie productivité, notes. Aujourd'hui, du coup, c'est l'IA qui fait tout. Et donc, pour le coup, ça remonte directement dans ton Hubspot. Donc, en fait, de toute façon, les calls, ils sont enregistrés. Donc ça, de toute façon, on va dire que vous avez entre guillemets plus la main mise sur est-ce que mon IA prend des notes. De toute façon, elle prendra les notes. Et sur la partie du coup réécoute. Pour moi, c'est on vient pas modifier vos routines, ce qui est mis en place par Merlin, ce qui est mis en place par Arthur, peut être sur toi, sur la partie management des équipes CSM. On vient juste vous faire gagner du temps d'écoupler votre force de coaching et surtout donner les moyens à des sales aujourd'hui ou des CSM de s'améliorer. Et du coup, aujourd'hui, honnêtement, en termes de connexion, c'est évidemment qu'il y a des managers. Mais en fait, aujourd'hui, c'est un outil. Il y a des équipes aujourd'hui qui font des sales aujourd'hui qui demandent de leur de leurs entretiens. Est ce que vous avez Modjo ? Parce qu'en fait, ça leur simplifie à mort la vie. La dernière fois, on avait parlé du fait que vous ayez des grands comptes et six mois de cycles de ventes. Si je ne m'abuse, justement, un outil comme ça, ça te permet de revenir sur tes échanges, de te remettre dedans, de préparer des rendez-vous, être beaucoup plus pertinent. Et en fait, c'est vraiment comment dire? C'est en fait, ça devient indispensable pour les équipes. Du coup, en termes d'usage, je comprends effectivement le côté. On n'a pas envie de mettre en place un outil pour un outil. Mais alors là, pour le coup, moi, je sais que tu vois le jour où je bosse de Modjo je sais que je veux une équipe, une boîte où il y a un Modjo aujourd'hui. Parce que moi, je m'y imagine pas repasser à des tâches manuelles, revenir sur des enregistrements pour me préparer. Ça me paraît aberrant de faire ça. Voilà, voilà. Écoute, ce que je te propose, c'est qu'on se prenne un petit créneau du coup, effectivement, pour la partie tarifaire.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Oui.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Qu'est ce que tu penses? Moi, j'ai un créneau demain si tu veux ou autrement lundi.", metadata={'speaker': 'spk0'}),
#  Document(page_content='Lundi, ce sera mieux. Lundi, lundi, lundi.', metadata={'speaker': 'spk2'}),
#  Document(page_content="Qu'est ce que c'est?", metadata={'speaker': 'spk1'}),
#  Document(page_content='Lundi 16h30.', metadata={'speaker': 'spk2'})]

# %%
retriever = Chroma.from_documents(
    docs, embedding=OpenAIEmbeddings(api_key=OPENAI_API_KEY)
).as_retriever(search_kwargs={"k": 200})
query = "Write a concise summary of the following text, in fewer than 60 words (this is a hard requirement: the summary cannot exceed 60 words) using the same language as the original text: french"

# Get relevant documents ordered by relevance score
docs2 = retriever.invoke(query)

reordering = LongContextReorder()
reordered_docs = reordering.transform_documents(docs2)

result = chain.run(input_documents=reordered_docs, query=query)
print(f"""The results is {len(result.strip().split(" "))} words long""")
result
# Out:
# The results is 65 words long
# "L'IA est utilisée pour faire un résumé automatique des appels téléphoniques, en captant les informations importantes telles que les prochaines étapes, les objections et les problèmes des prospects. Cela permet de créer un compte rendu synthétique et homogène de l'échange, facilitant ainsi la prise de notes et l'accompagnement des commerciaux dans leurs réponses. L'IA permet également de repérer des mots clés et d'analyser les performances."

# %% [markdown]
# This is not a bad summary at all despite the quite unconventional use of one document per line of dialog.
#
# Looking for alternatives to summarize documents based on [this article](https://medium.com/@abonia/summarization-with-langchain-b3d83c030889#:~:text=Map%2DReduce%20Method&text=The%20map_reduce%20technique%20is%20designed,to%20create%20a%20final%20summary.)
#
# 1. The Stuffchain works best in the scenario when documents are very big. It summarizes individually each document, then combines the summaries. In our case this could be interesting to try to avoid the token limit we dealt with above. We could interpret the whole conversation as a single document, then cut it in documents just big enough for the context window to handle. The major drawback with this approach that I can see is that we can potentially cut an important dialog midway and lose the "order" of the steps in the conversation if it is really long. Also it supposedly does not scale well with large amounts of documents
# 2. The Map-Reduce Method works a similar fashion even at document level it will work out a summary per chunk. It is supposedly more scalable but requires a bigger setup. It may be more indicated here for a summarization task.
# 3. Refine: can "update" a summary based on new information. This is not exactly what we are looking for, except based on [langchain's tutorial](https://python.langchain.com/v0.1/docs/use_cases/summarization/#quickstart)
#
# Let us try the load_summarization tool from langchain using the full document as input as in [this tuto](https://dxiaochuan.medium.com/summarising-your-meeting-with-chatgpt-and-langchain-8eb646cfcdd1) which shows good results

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.chains.summarize import load_summarize_chain


def retranscription_from_json(json_dict):
    out = ""
    tmp = ""
    previous_speaker = ""
    for block in json_dict["segments"]:
        speaker = block["speaker"]
        if speaker == previous_speaker:
            tmp += " " + block["content"]
        else:
            out += tmp
            tmp = f"""\n - {speaker}: """ + block["content"]
            previous_speaker = speaker
    return out


textified_conversation = retranscription_from_json(data)

# Choosing appropriate chunk size to avoid the maximum limit size specified by OpenAI ChatGPT 3.5
target_len = 300  # for each intermediary summary
chunk_size = 3000  # <4k
chunk_overlap = 200

text_splitter = CharacterTextSplitter(
    separator="\n -",
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    length_function=len,
)

texts = text_splitter.split_text(
    textified_conversation,
)

# Create Document objects for the texts
docs = [Document(page_content=t) for t in texts[:]]

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")

prompt_template = """Act as a professional technical meeting minutes writer. 
Tone: formal
Format: Technical meeting summary
Length:  300
Tasks:
- highlight action items and owners
- highlight the agreements
- Use bullet points (maximum 20)
{text}
CONCISE SUMMARY IN FRENCH:"""
prompt = PromptTemplate(template=prompt_template, input_variables=["text"])
refine_template = (
    "Your job is to produce a final summary\n"
    "We have provided an existing summary up to a certain point: {existing_answer}\n"
    "We have the opportunity to refine the existing summary"
    "(only if needed) with some more context below.\n"
    "------------\n"
    "{text}\n"
    "------------\n"
    f"Given the new context, refine the original summary in French within {target_len} words: following the format"
    "Title: <title of the meeting>"
    "Participants: <participants>"
    "Discussed: <Discussed-items-with-bullet-points>"
    "Follow-up actions: <a-list-of-follow-up-actions-with-owner-names>"
    f"Conclusion: <a-global-summary-with-maximum-60-words-and-much-less-if-possible>"
    "------------\n"
    "If the context isn't useful, return the original summary. Highlight agreements and follow-up actions and owners in the answer."
    "if there are any participants that correpond to generic speakers such as spk0, spk1, spk2 do not include them in the list of participnts"
    f"The final summary must not exceed 60 words."
)
refine_prompt = PromptTemplate(
    input_variables=["existing_answer", "text"],
    template=refine_template,
)
chain = load_summarize_chain(
    llm,
    chain_type="refine",
    return_intermediate_steps=True,
    question_prompt=prompt,
    refine_prompt=refine_prompt,
)
resp = chain({"input_documents": docs}, return_only_outputs=True)
print(resp["output_text"])
# Out:
# Created a chunk of size 3001, which is longer than the specified 3000
# Title: Réunion de mise en œuvre de Modjo
# Participants: Celeste, Merlin, Arthur, Lancelot
# Discuté:
# - Problèmes techniques avec la caméra
# - Récapitulatif de la discussion précédente avec Merlin
# - Potentiel de Modjo pour améliorer les ventes et le service client chez RoundTable
# - Planification de proposition de tarification personnalisée
# - Formalisation des routines de coaching et du processus
# - Ateliers de formation commerciale et scripts
# - Objectifs d'amélioration des performances et défis
# - Suivi des contributions aux ventes et individualisation
# - Amélioration du processus de prise de notes et système automatisé de prise de notes
# - Intégration de Modjo avec des outils VOIP, Visio et CRM
# - Transcription automatique des conversations pour l'analyse des performances
# - Discussion sur l'importance des différentes parties de l'appel et des objections
# Actions de suivi:
# - Celeste fera un suivi avec Merlin et Arthur sur la fonctionnalité de la caméra
# - Celeste planifiera une réunion avec Lancelot de SquareChair
# - Exploration des options pour un système automatisé de prise de notes
# Conclusion: La réunion a abordé les problèmes techniques et a examiné le potentiel de Modjo pour améliorer les ventes et le service client. Des actions futures ont été planifiées, notamment la formalisation des routines de coaching, les ateliers de formation commerciale et l'intégration de Modjo avec des outils VOIP, Visio et CRM. Un suivi sera effectué sur la fonctionnalité de la caméra, une réunion sera prévue avec Lancelot et des options pour un système automatisé de prise de notes seront explorées.

# %%
# not bad at all. Reading myself the Json, I believe Lancelot was not there though (when I rerun the code sometimes he gets out of the list sometimes in)

# %%
################### Trying out the same thing for the 60-word summary -> does not respect the 60words constraint somehow
# Choosing appropriate chunk size to avoid the maximum limit size specified by OpenAI ChatGPT 3.5

llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")

prompt_template = """Act as a professional technical meeting minutes writer. 
Tone: formal
Format: Technical meeting summary
Length:  60-80 words
{text}
CONCISE SUMMARY IN FRENCH:"""
prompt = PromptTemplate(template=prompt_template, input_variables=["text"])
refine_template = (
    "Your job is to produce a final summary\n"
    "We have provided an existing summary up to a certain point: {existing_answer}\n"
    "We have the opportunity to refine the existing summary"
    "(only if needed) with some more context below.\n"
    "------------\n"
    "{text}\n"
    "------------\n"
    "Given the new context, refine the original summary in French with minimum 50 words and maximum 80 words"
)
refine_prompt = PromptTemplate(
    input_variables=["existing_answer", "text"],
    template=refine_template,
)
chain = load_summarize_chain(
    llm,
    chain_type="refine",
    return_intermediate_steps=True,
    question_prompt=prompt,
    refine_prompt=refine_prompt,
)
resp = chain({"input_documents": docs}, return_only_outputs=True)
print(resp["output_text"])
# Out:
# Modjo est un outil de coaching et d'analyse des appels qui permet de simplifier et d'optimiser les interactions commerciales. Son intelligence artificielle enregistre les appels et génère automatiquement un résumé avec les prochaines étapes et les objections. De plus, il offre des fonctionnalités d'analyse et de formation continue pour aider les managers à coacher leurs équipes. Gymlib est un client satisfait de Modjo, qui a constaté une amélioration de son processus de vente et une économie de temps. Des négociations sont possibles pour réduire le prix de la licence mensuelle de 99 euros.

# %%
len(resp["output_text"])
# Out:
# 596

# %% [markdown]
# ### 2. Free-format summary
#
# When thinking about how the summary will be used, we can improve a little bit by providing the following elements:
# - Asking GPT the summary from above in the form of bullet points
# - Asking chatgpt what's the topic of the discussion and generate a title based on it.
# - Getting the names of all the speakers (directly filtering through the json "speaker field" and asking gpt to find the name), summarizing their contributions.
# - Asking GPT for
#     - problem raised if any
#     - problem solved if any
#     - future action that must be taken
#
#
# Anything else would be context specific: for exemple in the context of sales, tracing customers to a CRM or in the context of software development tracing problems to issues raised in a ticket-system. We won't tackle this here.

# %%
question = "Can you find a title for this conversation (using the same language as the provided transcript)?"
title = qa_chain.run(input_documents=documents, question=question)

question = """Provide a summary given the transcript provided in 60 words max. Use the language of the transcript for summarization. Make a maximum of 10 bullet points in this summary with the key elements. Use the same language as the provided transcript"""
summary = qa_chain.run(input_documents=documents, question=question)

question = """Provide for each speaker in the provided transcript its main impact in the meeting in the form: - speaker_name : impact with a bullet point for each speaker"""
speakers_summary = qa_chain.run(input_documents=documents, question=question)

question = """Provide a conclusion for the meeting: with max 10 bullet points, mention the problems solved, the problems raised, and future actions decided in this meeting"""
conclusion = qa_chain.run(input_documents=documents, question=question)

# %%
output = f"""
title: {title}

summary: {summary}

speakers_summary: {speakers_summary}

conclusions: {conclusion}
"""

print(output)
# Out:
# title: Title: "Discussion de planification pour une réunion"
#
# summary: - Celeste discusses the repair of the camera and greets Merlin and Arthur.
# - The purpose of the call is to discuss knowledge, scopes, and goals at RoundTable.
# - The speaker wants visibility on the business model and a customized pricing proposal.
# - Modjo is a tool to improve sales and CSM goals by enhancing sales techniques and addressing objections.
# - The team is working on scripts and speech techniques to increase sales performance.
# - Workshops and call reviews are conducted to improve performance and reach sales goals.
# - Modjo is a tool for transcribing and analyzing conversations to improve performance and productivity.
# - The tool integrates with VOIP tools, Visio tools, and Hubspot CRM.
# - Modjo helps in understanding pitches, objection handling, and successful strategies.
# - The speaker emphasizes the importance of data visibility, collaboration, and training within teams.
#
# speakers_summary: - Celeste: Confirms usage of Google Meet by CS team and its integration with other tools.
# - Merlin: Raises the issue of productivity on Hubspot and the need for better information sharing.
# - Arthur: Acknowledges Celeste's greeting and confirms his presence in the call.
# - Speaker 1:
#   - Provides information about the number of people involved in the conversation and their roles.
#   - Discusses the lack of ROI for implementing Modjo and highlights potential benefits.
#   - Emphasizes the importance of connectivity and using tools like Modjo for improving sales processes.
# - Speaker 2:
#   - Mentions Speaker 1's sales practices as references for new arrivals and interns.
#   - Emphasizes the lack of flexibility and interest in implementing the first speaker's suggestions.
#   - Acknowledges the benefits of Modjo and expresses a desire to have an effective team or company.
# - Speaker 3:
#   - States the use of a regular phone line for calls instead of using Hubspot or Ringover.
#   - Shares a higher call response rate compared to RingGover's sales team.
#   - Introduces the concept of offering discounts and discusses potential benefits and budget allocations.
# - Speaker 4:
#   - Questions if RingGover's sales team is using a different system.
#   - Suggests a call for pricing bids and expresses interest in a competitive offer.
# - Speaker 5:
#   - Highlights the importance of customer relationship management (CRM) and appreciates the idea of synthesizing analytics data.
# - Speaker 6:
#   - Provides a possible range of licenses depending on whether the manager is included.
# - Speaker 7:
#   - Clarifies that licenses are for the call part, not the video part.
# - Speaker 8:
#   - States that the video part is mainly handled by the CSMs and is not the main focus of the meeting.
#
# conclusions: Conclusion of the Meeting:
#
# Problems Solved:
# - Identified the need for a new tool with advanced features
# - Acknowledged budget constraints and inability to afford certain tools
# - Determined the number of users required for the tool
# - Discussed call practices and acknowledged Merlin's high response rate using a traditional phone line
# - Clarified discount terms and negotiations for sales
#
# Problems Raised:
# - Existing tools (Intercom and Hubspot) are costly and not meeting the needs
# - Current budget limitations prevent the allocation of a significant amount for a new tool
# - Low response rates for sales using Ringover compared to Merlin's orange line
#
# Future Actions Decided:
# - Explore alternative tools that are more affordable
# - Limit the number of users for the new tool initially
# - Analyze and assess the effectiveness of different phone lines for sales prospecting
# - Conduct a prospecting challenge to gather more data on response rates using different phone lines
# - Consider negotiation strategies for flexible pricing options
# - Evaluate the potential benefits and ROI of using Modjo
# - Schedule a follow-up meeting to discuss the findings of the analysis and make a decision on implementing Modjo
# - Conduct a call for pricing proposals and further activate negotiation strategies to reduce the license price
# - Conduct a thorough analysis of Issue C and present findings in the next meeting
# - Assign a task force to investigate and provide recommendations for addressing Issue D
# - Review progress on these actions and make further decisions in a follow-up meeting
# - Schedule a meeting to present the offer and discuss potential leverages for success
# - Continue the discussion with Celeste and inquire about the onboarding process
# - Utilize the dedicated consultant for market tips, productivity improvement, team coaching, and maximizing the use of Modjo
# - Implement certain actions to align with Hubspot practices
# - Request a competitive offer and explore the integration of CR and analytics synthesis
# - Conduct internal discussions to determine the appropriate time and resources for implementing the tool
# - Implement Modjo as a necessary tool for the team and evaluate its effectiveness and benefits continuously
# - Ensure proper training and integration of Modjo into daily work routines

# %% [markdown]
# This is not super satisfactory... It would make more sense to try other input formats... For exemple one "Page" per sentence instead of he recursive splitter may be more indicated here.
# The conclusions as well missed the next call decided at the end. Maybe there should be several dedicated prompts for actionables like "next meetings" and these could be aggregated in a neat fashion.

# %% [markdown]
# ## Question answering
#
# Using GPT-3.5-turbo provide a method that can answer the following questions using the provided json path
# 1. What are the next steps?
# 2. Was budget mentioned, if so what was the amount?
# 3. Who is Lancelot?
# 4. Which CRM does the prospect use?
# 5. What are the main objections raised ?

# %%
def qa_method(json_path: str, question: str) -> str:
    """
    Answer the question on the transcript

    Parameters
    ----------
    - `json_path` (str) : path of the json transccript
    - `question` (str) : plain text question

    Returns
    -------
    - (str): the reply to the question
    """
    with open(json_path) as f:
        data = json.load(f)
    textified_conversation = organize_json(data)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    texts = text_splitter.split_text(textified_conversation)
    documents = [Document(page_content=text) for text in texts]
    llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")
    qa_chain = load_qa_chain(llm, chain_type="map_reduce")
    answer = qa_chain.run(input_documents=documents, question=question)
    return answer


answer = qa_method("demo-segments.json", "What are the next steps")
print(answer)
# Out:
# The next steps involve analyzing the data to determine the typology of calls and the individuals driving the push. The goal is to gain visibility on this information. This allows the managers to identify who is effectively pushing the live note and making sales. They can then use this information to coach the rest of the team who may be struggling to push certain offers. The process also involves continuous training and listening to qualifications and demos from top performers using Modjo.

# %%
answer = qa_method("demo-segments.json", "Who is Lancelot? What's his job")
print(answer)
# Out:
# I don't know who Lancelot is or what his job is. The given text does not provide any information about Lancelot or his job.

# %% [markdown]
# How disappointing... This is probably because the text should not be cut with a recursivecurser but rather "line by line"

# %%
def qa_method(json_path: str, question: str) -> str:
    """
    Answer the question on the transcript

    Parameters
    ----------
    - `json_path` (str) : path of the json transccript
    - `question` (str) : plain text question

    Returns
    -------
    - (str): the reply to the question
    """
    with open(json_path) as f:
        data = json.load(f)
    textified_conversation = organize_json(data)
    documents = [
        Document(page_content=text) for text in textified_conversation.split("- ")
    ]
    llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k")
    qa_chain = load_qa_chain(llm, chain_type="map_reduce")
    answer = qa_chain.run(input_documents=documents, question=question)
    return answer


answer = qa_method("demo-segments.json", "Who is Lancelot? What's his job")
print(answer)
# Out:
# I don't know who Lancelot is or what his job is. The provided text does not contain any information about Lancelot or his job.

# %% [markdown]
# Looks like the problem is deeper, maybe the QA chain is in cause here. I would investigate how it works and check how I can make sure important bits of information are not ignored.

# %%
#################################### Going further

# %%
# Using the same character split as above in the refineing/load_summarize_qa_chain
docs
# Out:
# [Document(page_content="spk2: Oui bonjour Celeste.\n - spk0: Bonjour Merlin. Comment vas-tu ?\n - spk2: Très bien et toi ?\n - spk0: Super. Écoute, ça va super. Je suis ravie de commencer mon après-midi avec toi. Je vois que la caméra n'a pas été réparée. Je sais pas si t'es tout seul ou t'es avec...\n - spk2: Non, là je t'avoue que avec le gros brume que j'ai...\n - spk0: Ah oui ! Ok, pas de problème. Non, mais je ne savais pas si du coup, Arthur et l'autre Merlin se connectaient derrière toi ou s'il y avait d'autres personnes qui arrivaient.\n - spk2: Non, alors Merlin, je ne sais pas, mais Arthur, ben voilà, il est là, parfait.\n - spk0: Ben voilà. Bonjour Arthur, enchanté. Salut Arthur.\n - spk1: Je suis là, bonjour Celeste.\n - spk2: Ah c'est Merlin, parfait. Donc, je suis juste contente de reposer le contexte par rapport à notre échange de la dernière fois et puis l'objectif de cette petite call tous ensemble.\n - spk0: Oui, effectivement, l'idée c'était, si ça vous va, l'agenda du coup juste que je vous propose effectivement, c'est peut-être juste de faire un petit tour de table avant pour connaître un peu du coup le niveau de connaissance de Merlin et de Arthur sur Modjo et connaître un peu exactement vos scopes et vos enjeux un peu personnels justement sur vos scopes de collectif chez RoundTable. Ensuite, évidemment, je vais faire un récap' des enjeux discutés avec Merlin lors de notre précédent call et pour être sûr qu'on est tous les quatre alignés. Et évidemment, on va très vite s'immerger dans Modjo pour que vous puissiez justement vous projeter et voir en quoi ça pourrait évidemment vous aider sur vos enjeux à la fois côté sales et CSM et la fin de l'échange, ça serait du coup de planifier la suite. Pour vous, l'idée, c'est d'avoir un peu de la visibilité du coup sur notre business model et pour moi, c'est pouvoir vous préparer une proposition tarifaire sur mesure et du coup la plus adaptée que ça soit en termes de nombre de licences. Est-ce que ça vous va comme comme comme Ouais, pas mal. L'échange. Ouais, OK, juste je peux me permettre. Merlin et Arthur, est-ce que vous votre caméra fonctionne ou pas?\n - spk2: La caméra, je vais voir si elle fonctionne.\n - spk0: OK, génial, trop cool. OK, ça va super. C'est sympa. Merci. Comme ça, plus qu'en plus, on est trois. Comme ça, je suis sûre. Si vous avez des questions, peut être aussi d'avoir le visuel. Juste avant du coup de commencer, je suis juste curieuse de savoir Arthur et du coup Merlin, quel est juste votre niveau de connaissance de Modjo et qu'est ce que vous faites exactement chez RoundTable pour être sûr de présenter?"),
#  Document(page_content="spk2: Et bien, on a radé un petit peu, donc c'était pour améliorer les performances commerciales, notamment grâce à l'IA. En gros, c'est par rapport à un script, voir à quel degré de similitude on est par rapport au script. Et donc, du coup, pour améliorer tout ce qui est nous, les relations clients après l'espèce commerciale et aussi l'espèce commerciale pour avoir de nouveaux clients. Et du coup, quand je suis à RoundTable, l'équipe d'équipe customer success et on est sur la partie commerciale opérationnelle.\n - spk1: Ouais, moi, je m'occupe de toute la partie opérationnelle. Je suis associé à Merlin qui est ici dans la call et connaissance de Modjo au même moment avec Merlin, puisque c'est on était dans la même réunion le jour où on nous en a parlé. OK, donc voilà en synthèse.\n - spk0: OK, génial. Et du coup, justement, je crois que vous avez passé pas mal de temps ces dernières semaines ou ces derniers jours chez Furnitures. Est ce que vous avez pu échanger avec SquareChair? Enfin, du coup, je crois que c'est Lancelot et Lancelot. Oui, c'est ça. Lancelot, le CEO de SquareChair qui est dans le même incubateur que vous.\n - spk1: Non, on n'a pas parlé avec Lancelot spécialement sur ça, je t'avoue.\n - spk0: OK, non, mais pas de problème. C'était par curiosité. OK, super clair.\n - spk1: Pour le savoir, on se gardera avec lui la semaine prochaine."),
#  Document(page_content="spk0: OK, non, mais pas de problème. C'était par curiosité. OK, super clair.\n - spk1: Pour le savoir, on se gardera avec lui la semaine prochaine.\n - spk0: Écoutez, bah écoutez, avec plaisir, effectivement, ces équipes l'utilisent. Depuis, c'était mon premier client parce que moi, je suis à eux depuis trois mois maintenant et du coup, qui de mieux qu'un utilisateur Modjo pourra vous partager des insights. Donc, trop bien si vous le rencontrez. Du coup, pour récapituler ce qu'on s'est dit la dernière fois du coup avec Merlin et être sûr qu'on est sur le même niveau d'information. Moi, ce que j'ai compris, c'est que vous avez des grosses ambitions de croissance. Aujourd'hui, vous avez des équipes principalement à Lyon, mais aussi un peu à Barcelone. Du coup, il y a un enjeu de manager à distance pour être plus efficient. Vous avez des process aujourd'hui qui est du coup, je reprends tes termes à Merlin. Je ne sais pas du tout de ma bouche, mais qui sont encore un peu brouillon. Et du coup, vous avez un enjeu de scalaire un peu sur cet aspect. Du coup, formaliser plus les process pour aller chercher plus de méthodologie dans votre approche, que ça soit côté CSM et SAIS. Et du coup, quand vous parlez justement, quand on parle du coup de performance de croissance aujourd'hui, tu parlais aujourd'hui de vos deux enjeux qui étaient augmentés drastiquement. Le MRR généré aujourd'hui, c'est un peu possible que ça soit sur la partie tunnel d'acquisition en termes de volume ou de panier moyen. Et c'était aussi de fidéliser du coup les clients côté CSM. Et pour ça, du coup, vous avez besoin d'un ou vous voudriez vous projeter sur un outil d'intelligence conversationnelle. Du coup, côté sales, c'était vraiment pour l'aspect amélioration du discours, peut être test aussi de discours en fonction de vos nouvelles offres pour aller peut être chercher justement un panier moyen plus important. Aussi, réponse aux objections et faire monter tout simplement vos recrues en compétences, parce que notamment, c'est des profils assez juniors et alternants. Si je ne m'abuse. Et côté CSM, c'est aussi de challenger sur la partie plutôt démo avec démo et avoir une expertise CSM vraiment encore plus poussée sur votre plateforme. Et on avait parlé d'un dernier sujet qui était moins lié à la performance, mais qui serait amené certainement à être challenge. C'était la partie productivité sur Hubspot. Merlin, tu disais que que vous l'utilisiez peut être aujourd'hui à 30% et que 99% vous n'étais pas sûr à 99% que les notes dans les opportunités soient bien prises et qu'il y aurait potentiellement des sujets de passations d'information entre CSM. Et du coup, c'est tout l'idée de Modjo d'un outil global, c'est de vous aider sur ses parties performance et productivité. Est ce qu'on est toujours aligné? Est ce qu'il y a d'autres points que vous vouliez voir et qui sera important pour vous pour la démo?\n - spk2: Non, tu as très bien résumé."),
#  Document(page_content="spk2: Non, tu as très bien résumé.\n - spk0: OK, génial. Et qu'est ce que je veux dire? Oui, non, dernier dernier aspect. Du coup, on avait à parler un tout petit peu moins de ça la dernière fois, Merlin, j'étais curieuse de savoir aujourd'hui concrètement qu'est ce que vous mettez en place comme routine de coaching à proprement parler, puisque du coup, vous aimeriez bien challenger sur le discours, sur les objections. Mais du coup, à date, sans un Modjo sans un outil pour vous y aider, qu'est ce qui est mis en place par les managers?\n - spk2: Pas grand chose. Ce n'est pas le problème. Donc, sur la partie CSM, on met en place depuis un mois, un mois et demi des tests de pitch juste sur la partie pitch démo fonctionnel. Donc, on faut qu'on garde justement cette vélocité sur ces tests. Et c'est tout ce que l'on fait, en tout cas sur la partie CSM aujourd'hui. Je pense qu'il y a d'autres éléments à prendre en compte aussi sur la qualité des process qui sont traités. Et sur la partie sales, tu peux dire deux mots, mais voilà, je sais qu'il y a des écoutes pendant un moment qui étaient faites sur Ringover, du double écoute ou même après coup, mais par quelque chose de régulièrement.\n - spk1: On fait principalement des workshops. OK. Des workshops en règle générale, c'est une fois par mois.\n - spk0: Ça se matérialise comment? Concrètement, ces workshops, c'est quoi l'objectif?\n - spk1: C'est en gros, moi, je demande, donc il y a des ateliers à Ringover qui nous permettent de les écouter. Clairement, il n'y a pas de double écoute dans le sens où on n'est à personne qui a le temps de faire de la double écoute. En tout cas, moi, je n'ai pas le temps de faire la double écoute. Donc, on demande celle de venir avec d'enregistrer des bad calls et des good calls en gros, au nombre de cinq par mois. Et ils viennent avec en atelier.\n - spk0: Ouais."),
#  Document(page_content="spk0: Ouais.\n - spk1: Workshop. On travaille comme ça, notamment beaucoup. Le traitement des objections. Voilà, c'est aujourd'hui, c'est la méthode où qui est qui est qui est faite côté sales. Donc, c'est une fois par mois. Sachant que ça, effectivement, ça c'est là depuis septembre. Ça s'est arrêté puisqu'on a eu pas mal de nouvelles recrues qui sont rentrées, etc. Donc, en gros, il y a une petite pause sur septembre, octobre. Le temps de remettre l'équipe à flot. Donc là, ça va reprendre. On a arrêté, je crois, le dernier, c'était en juillet, début juillet, en été. Donc voilà, septembre, octobre, il n'y en a pas. Là, on va reprendre en novembre. Sachant que nous, les nouveaux sales, quand ils rentrent, on les fait d'abord travailler sur du pur call à froid. Donc, du pur call à froid, on ne les fait pas travailler sur des pros spéciaux de notre CRM. On travaille sur le script, le discours, on va dire en condition dure pour être potentiellement plus efficace en conditions plus clémentes. Et au niveau du script, tout est scripté, j'allais dire, en fonction des différents cas, que ce soit du prospect froid au prospect. Il y a deux doigts de signer et qui a déjà fait une période d'essai. Donc, on a à peu près tout scripté. Néanmoins, on n'est pas dans une logique de... Moi, j'ai tendance à dire aux sales que l'important, c'est qu'ils sont en capacité d'avoir la profondeur de traiter les objections et la résilience de s'accrocher. Après, effectivement, ça reste de l'impro en fonction de qui tu es en face de toi. Donc, tu ne peux pas avoir un discours de robot, même si au début, tu l'as un petit peu sur les trois et six premiers mois. Ils sont un peu en mode robot et c'est normal. Et j'allais dire, c'est même les robots qui sont en mode robot, parce que ça veut dire qu'ils suivent le script. Néanmoins, par la suite, ce n'est pas le robot qui signe. C'est lui.\n - spk0: Et du coup, juste petite question. Que ça soit sur les sales qui ont déjà eu leur phase de ramp-up ou les junior aujourd'hui, donc, effectivement, ils testent le pitch, ils répondent à des objections. Concrètement, là, tu fais comment juste pour t'assurer qu'ils répondent bien? Parce qu'il y a les workshops que vous mettiez en place. Mais aujourd'hui, à date, tu fais comment? Tu es sur le flot, tu les écoutes comme ça, tu fais de la réécoute via ring-over. Comment tu les accompagnes dans leur montée en compétence?"),
#  Document(page_content="spk1: Nous, en gros, on a un suivi hebdo. Le lundi, on a une réunion d'équipe. Le vendredi, on a une réunion individuelle. En réunion individuelle, ils ont pris l'habitude de venir avec leur, entre guillemets, avec leurs problématiques, leurs objections. Ils viennent souvent me demander des arguments. Effectivement, à l'instant T maintenant, alors avant, ce n'était pas obligatoirement le cas avant l'été, mais maintenant, on a la chance d'avoir une sorte d'open space sur lequel moi, je peux entendre les appels. Donc, ça me permet d'intervenir quand je suis là pour éventuellement donner des petits des petits feedbacks. Voilà des tips. Mais jusqu'alors, on va dire que jusqu'alors, on était sur un modèle où, comme je te dis, il n'y a pas de réécoute à part le workshop. Il n'y a pas de réécoute. Après, les celles chez nous ont participé pour la plupart, ou en tout cas, ont au moins participé une fois un salon. Salon, ça veut dire que, voilà, j'allais dire, il n'y a pas derrière un téléphone, tu ne peux pas te cacher, tu es face à la personne et tu dois tu dois débiter. Et aujourd'hui, tous les sales, on va dire, ont participé au moins à un salon et ils ont déjà conclu des ventes. Donc, on a quand même un niveau de performance minimum qu'on sait être capable de tenir. Le problème, c'est la recherche de la... Le problème, c'est de travailler sur l'amélioration de la performance. C'est vraiment ça. C'est augmenter le nombre de conversions par mois, le nombre de closures, c'est le sujet.\n - spk0: Tu vas aller chercher combien en taux de conversion aujourd'hui ? Pardon ? Tu vas aller chercher combien en taux de conversion aujourd'hui ? Enfin, vous êtes à combien en taux de conversion et tu vas aller chercher combien dans l'idéal ?\n - spk1: En gros, aujourd'hui, on veut aller... On a nous un gros top service qui est la customize, la marque blanche chez nous. Si tu regardes un petit peu...\n - spk0: Ici, j'ai regardé votre site à 139 euros.\n - spk1: Voilà, notre objectif, c'est d'être tous les mois au moins 10. Donc, ça, c'est vraiment notre objectif d'être à 10.\n - spk0: Et aujourd'hui, vous êtes à combien ?\n - spk1: Aujourd'hui, on tourne entre 6 et 8 en gros. Donc, on est un cran en dessous. Ce mois-ci, on va aller faire les 10 parce qu'on sort d'un salon. On va dire que le taf a été bien fait, mais dans la récurrence... Et d'ailleurs, on a une performance assez ératique dans le sens où il y a des mois, je ne sais plus, en juin, on en fait 5 et en juillet, par exemple, on en fait 10. Donc, en fait, on est vraiment comptable au niveau de la perfo. C'est ça qui est le plus frustrant. C'est là qu'on aimerait avoir un outil qui potentiellement nous permette d'améliorer de manière continue la performance des sales.\n - spk0: En termes de chiffre d'affaires ou de MRR ou ARR à aller chercher sur l'année, tu as une idée de ce que ça représenterait d'augmenter justement cette performance qui est aujourd'hui pas forcément stable de moins en moins."),
#  Document(page_content="spk1: C'est-à-dire le fait d'atteindre l'objectif, qu'est-ce que ça apporte ton MRR en plus ?\n - spk0: Aujourd'hui, c'est quoi ton objectif ? C'est quoi le manque à gagner en termes d'ARR que tu as en visibilité le fait de ne pas être à 10 aujourd'hui ?\n - spk1: Tu peux parler de son MRR.\n - spk0: MRR, oui.\n - spk1: C'est un jeu galère quand il met son niveau. Là, c'est simple. On a fait 7 marques blanches en septembre. L'objectif, c'est 10. C'est à peu près 500 euros par mois la marque blanche. C'est 1500 euros mensuels qui tournent par an.\n - spk0: Et du coup, ça c'est par sales ? Pour l'équipe ? Au global ?\n - spk1: Le sales doit faire 3 marques blanches par mois. Si on voudrait qu'ils soient au niveau, il faut qu'ils fassent 3 marques blanches par mois. Normalement, s'ils en font 3 par mois, sachant que moi également j'en fais aussi, ça en fait 12 tout de moins.\n - spk2: Attention, ça c'est nos chiffres aujourd'hui. Les chiffres de TAM4, c'est pas ce que ça donne. On leur fait le calcul avec Samuel pas plus tard que ce matin.\n - spk0: Ça serait plutôt combien du coup ?\n - spk2: Là, on serait plutôt à nombre de marques blanches par personne par mois, 5. Après, on s'est fixé des objectifs.\n - spk1: Par mois, c'est pas possible. T'es à 15 marques blanches.\n - spk2: Si on veut suivre ce qu'on est censé progresser, comment on est censé progresser, en tout cas sur 2024, on devrait être à terme à ce nombre-là. Dans tous les cas, on a un gros gap entre haut et bas.\n - spk0: Il y a un gros gap. On parle juste de marques blanches. Les autres sont complètement dépriorisés ? Est-ce que vos sales performent plus sur les autres ?\n - spk1: Là-dessus, Celeste, c'est compliqué parce que tu poses des questions auxquelles on n'a pas de réponse.\n - spk0: Ok, pas de problème.\n - spk1: La question est pertinente, mais tu poses des questions auxquelles on n'a pas de réponse.\n - spk0: Ok, c'est pas grave.\n - spk1: Le problème, c'est que le sales contribue à la vente de licence les deux autres, sauf qu'on ne sait pas le traquer. On ne sait pas pourquoi nos clients, quand le sales leur donne un code, ils ne l'utilisent pas spécialement. On se trouve des sales qui aident à vendre la licence à 49 ou 69 euros, mais on ne sait pas si la vente a été faite par X ou Y. On sait que l'équipe contribue, donc on a une sorte de prime d'équipe là-dessus. Mais on n'arrive pas à l'individualiser. Aujourd'hui, alors que pour la marque blanche, on sait parce que le devis est fait par le sales, par le propriétaire de la transaction, donc là, c'est beaucoup plus facile. Moi, alors, dans le suivi mensuel, comme je les ai deux fois par semaine, je sais quel deal X ou Y a signé, donc je suis capable d'identifier qui a fait son taff, si c'est bon, si ou non.\n - spk0: Traquer dans un call, tel ou tel offre, ça vous permettrait d'avoir plus de visibilité sur ce qui pourrait être poussé par vos sales ?"),
#  Document(page_content="spk0: Traquer dans un call, tel ou tel offre, ça vous permettrait d'avoir plus de visibilité sur ce qui pourrait être poussé par vos sales ?\n - spk1: Oui, identifier ce qui a été vendu dans le call et être capable de dire que c'était Jacky qui a vendu ça. Oui, ça peut être intéressant.\n - spk0: Ok, clairement, c'est un truc que je n'avais pas en tête, donc je vous montrerai. J'ai une dernière question et après, je vous promets, on switch sur la démo, mais on n'a pas trop parlé du coup de la partie CSM. J'ai compris qu'il y avait un enjeu sur la partie plutôt démo de votre côté. Juste pour comprendre aujourd'hui, c'est quoi les axes d'amélioration d'une démo. Concrètement, qu'est-ce que vous cherchez exactement à faire ?\n - spk2: Je pense qu'on peut rester sur le périmètre size.\n - spk0: Size, ok.\n - spk2: Très clair. Le démo, effectivement, peut l'améliorer, mais la personne est déjà sur le produit et c'est des informations qu'on vient lui donner. Donc oui, il y a de l'amélioration à faire, mais là pour la démo, je pense qu'on peut focusser sur les sales.\n - spk0: Ok, donc, focussons dans ce cas-là sur les sales. On n'avait pas sur la partie compte rendu, prise de notes. Tu me disais, Merlin, pendant le dernier échange que du coup, à ta connaissance en tout cas, aujourd'hui, c'est qu'il y avait peu de prise de notes de fait. Du coup, l'autre, Merlin, je crois que c'est toi qui manage les sales. À ton niveau, c'est quoi ta connaissance ?\n - spk1: C'est dans les deux sens. Aujourd'hui, on n'est pas bon dans les deux sens, dans le sens où le sales n'a pas tout le temps pris les notes et souvent le CS ne prend pas les notes du tout en post démo, ce qui fait qu'on a eu sur mai-juin des signatures qu'on a perdu par mauvaise communication CS Sales et Sales CS. Ce qui est sûr, c'est que je suis sûr à 99% qu'il n'y a pas toutes les informations entre les Arthur-Panthéonier vu que deux ou trois fois...\n - spk0: Ok, je mets les pieds là où il ne faut pas, mais l'idée, c'est de faire en sorte que ça ne se passe plus.\n - spk1: C'est clair que les notes, c'est quelque chose qui est très important. Tout le monde a une fois commis l'erreur, voire même la commet de temps à autre, ça, c'est certain. Et si on peut avoir un système de prise de notes automatisée grâce à une IA, oui, c'est intéressant.\n - spk0: Ok. Du coup, aujourd'hui, vous savez pourquoi ce n'est pas fait ?\n - spk1: Pourquoi ce n'est pas fait ? Parce qu'en fait, le CS, il a du mal à le faire parce qu'il fait sa démo en live avec son ordinateur. Et du coup, pour faire son CR, il faut qu'il s'arrête 5 minutes après et qu'il se dise, je fais ma synthèse. Donc là, il faut enlever la synthèse, il faut y penser. Et des fois, le pauvre CS, il enchaîne une réunion avec un autre CS.\n - spk0: Et côté sales sur la partie call ?"),
#  Document(page_content="spk0: Et côté sales sur la partie call ?\n - spk1: Alors côté sales, j'allais dire chez les sales, c'est peut-être l'endroit où c'est peut-être le plus fait parce que déjà, il est libre même. Donc en fait, un sales pour lui-même, il va prendre des notes. Mais les fois où il ne va pas le faire, ça peut être parce qu'il n'est pas à l'aise dans son call et qu'il se fait malmener et que du coup, on va dire que voilà, il a subi le rendez-vous et du coup, il a potentiellement besoin de souffler derrière. Et voilà, soit il enchaîne aussi des réunions, ça peut arriver puisqu'il peut avoir plusieurs réunions prévues avec des prospects. Et après, il y a aussi au-delà de l'aspect faire, il y a la qualité de la synthèse, il y a la qualité du CR, c'est deux choses différentes. Il y a faire et faire et effectivement, certains ont moins l'esprit synthétique que d'autres.\n - spk0: Ok, écoutez, très clair, dans ce cas-là, on regardera bien cet aspect aide à la prise de notes qui aidera du coup les deux équipes. Est-ce que vous avez des choses à rajouter ou est-ce qu'on peut passer du coup au partage d'écran et à la démo ?\n - spk2: Non, c'est complet.\n - spk0: Ok, génial. Merci en tout cas pour ce complément d'information qui va très certainement enrichir cette démo. Je vous partage dès maintenant mon écran, est-ce que vous le voyez bien ?\n - spk2: Oui.\n - spk0: Génial. Du coup, je compte sur vous pour vraiment m'arrêter si vous avez des questions et de me dire si jamais vous voulez passer parce que ça ne vous intéresse pas particulièrement. Normalement, j'ai bien préparé, donc ça ne devrait pas être le cas, mais n'hésitez pas vraiment à m'interrompre pour que ça soit le plus interactif possible. Du coup, bienvenue sur Modjo Comme vous pouvez le voir, c'est mon Modjo à moi. Je vous partage vraiment en toute transparence tous les échanges que j'ai au quotidien avec mes prospects et mes clients. Techniquement, comment ça va se passer ? Modjo ça va venir se plugger à votre outil de VOIP, donc Ringover, à vos outils de Visio et à votre CRM Hubspot. L'idée du coup, c'est qu'on va venir récupérer les enregistrements de ces échanges à des fins de performance, de productivité. Ce qu'on va faire concrètement, c'est qu'on va retranscrire en texte tout ce qui va être abordé, on va dire toute la dialectique, que ça soit côté commercial, CS ou client prospect. Concrètement, juste pour que vous ayez une idée, rien ne va changer pour côté Sales ou CS. Ce que je veux dire, c'est qu'il n'y a pas de manip manuel à faire pour qu'un call, une Visio remonte, tout est fait automatiquement.\n - spk2: Excusez-moi, Celeste, les CS font beaucoup de Google Meet ?\n - spk1: Oui. C'est géré ?"),
#  Document(page_content="spk2: Excusez-moi, Celeste, les CS font beaucoup de Google Meet ?\n - spk1: Oui. C'est géré ?\n - spk0: Du coup, Google Meet, exactement, c'est bien pris en compte. Toutes les vidéos Google Meet vont remonter automatiquement aujourd'hui dans Modjo. On off ? On off, non. On off aujourd'hui, on n'est pas intégré à on off. En revanche, on est intégré à Ringover et à d'autres outils de VOIP, mais pas à on off aujourd'hui.\n - spk2: Ce n'est pas grave, on off, normalement, c'est fait que pour beaucoup, pour des réceptions de SMS, pour débloquer des comptes, etc. Donc, ce n'est pas problématique.\n - spk0: C'est plus de l'écrit du coup plutôt que de l'audio finalement ?\n - spk2: C'est plus pour l'opérationnel que de l'échange pur avec du client.\n - spk0: En tout cas, effectivement, à date, on n'a pas encore d'intégration avec on off. Du coup, à date, on ne récupérerait pas ces échanges. OK. Du coup, l'ADN de Modjo c'est d'être le plus collaboratif possible. Et du coup, que ça soit au sein des équipes sales, customer success, entre managers, managers. Et du coup, comme vous pouvez le voir, on peut avoir accès à mes échanges, aux échanges du coup de mon équipe et aux échanges de toute l'entreprise. Une fois que j'ai dit ça, Modjo c'est également aussi la mémoire de l'entreprise, la mémoire client. Donc, par exemple, si je veux prendre par exemple un de mes, je vais faire encore mieux, je vais prendre SquareChair. SquareChair, comme je vous le disais, c'est une des start-up incubées chez Furnitures. Et du coup, ce qu'on peut faire, c'est qu'on va pouvoir filtrer finalement sur ce compte client. Là, vous pouvez voir qu'il y a effectivement aujourd'hui 10 échanges qui sont remontés. Ça passe de mon appel de prospection, ma discovery, bref, ma démo, l'offre tarifaire, comme aussi tous les échanges que l'équipe aujourd'hui de Modjo Customer Success a avec les équipes. Donc vous voyez vraiment, on part vraiment d'une base énorme d'échanges et on peut filtrer en fonction évidemment des clients pour avoir vraiment une historisation maximum des échanges. Déjà, est-ce que pour vous, ça c'est clair ?\n - spk2: Oui, oui, oui.\n - spk0: Ok, j'ai une idée. Alors, du coup, ce que je vous propose, c'est qu'on va partir sur le premier pilier qui est vraiment le pilier performance. Donc on va prendre du coup la performance commerciale. Aujourd'hui, vous avez des vrais enjeux d'amélioration du discours, de comprendre aujourd'hui ce qui est dit dans les échanges, d'amélioration aussi des réponses à des objections. Vous avez vraiment besoin d'avoir de la visibilité sur ce qui se passe dans les calls. Je ne me trompe pas, je suis fidèle. On est d'accord ? Ok, génial.\n - spk1: On va avoir surtout de l'information de ce qui se passe dans les calls."),
#  Document(page_content="spk1: On va avoir surtout de l'information de ce qui se passe dans les calls.\n - spk0: Ok, et ce qui va se passer, c'est que par exemple, je vais prendre du coup des échanges qui ont eu lieu, par exemple, sur le quarter. Donc ce que vous pouvez voir déjà, c'est qu'il y a des tags en fonction de la typologie des échanges. Il y a effectivement des calls de qualification, de démos. Vous aurez des typologies d'échanges évidemment en fonction de votre cycle de ventre.\n - spk2: Comment ces tags sont mis en fait ?\n - spk0: Alors typiquement, là, c'est des appels, donc c'est des appels de prospection. Donc là, vous pouvez voir que c'est du cold call. Autrement, c'est l'intelligence artificielle.\n - spk2: Comment Modjo sait que c'est du cold call ?\n - spk0: Parce que c'est lié du coup à votre ringover ou à votre aircall ou à votre outil de VOIP. Ça remonte automatiquement ce tag.\n - spk2: D'accord, donc c'est sur ringover et il faut mettre la bonne information.\n - spk1: Quand tu raccroches… Ce qui a été dit.\n - spk0: Il y a deux choses en fait. Par exemple, il y a le nom du meeting. Vous faites une intro, l'intelligence artificielle va venir identifier la typologie de rendez-vous.\n - spk1: Donc là, par exemple, on a accès… Par rapport à l'intro qui a été faite, si tu présentes le produit, c'est que c'est un cold call froid. Si tu attaques directement sur une… Comme on s'est dit la dernière fois… C'est la même chose pour le démo.\n - spk2: Modjo sait à tous les coups classifier ses échanges."),
#  Document(page_content="spk2: Modjo sait à tous les coups classifier ses échanges.\n - spk0: Il sait classifier ses échanges. Alors là, qu'est-ce qui se passe ? Parce que j'ai mis tous les appels. Ça va pas aller. Attendez. Il sait classifier ses échanges. Ces échanges, pardon. Ça m'épette en fonction de la typologie des calls. Ça peut mettre deux, trois minutes. Par exemple, moi, j'ai une démo qui remonte. C'était une heure de démo. Le temps que la plateforme identifique, c'est une démo. Ça peut mettre deux, trois minutes à être taggé comme une démo. Mais effectivement, c'est l'outil qui vient le tagger. Là, par exemple, vous pourriez avoir accès à toutes les démos aujourd'hui qui ont eu lieu chez Modjo sur le mot. OK ? Est-ce que c'est plus clair pour vous déjà, ça ? Oui, oui, oui. OK, génial. Par exemple, ce qu'on voudrait faire, c'est regarder tous les échanges qui ont eu lieu sur ce quarter, par exemple, des discoveries. Parce que notamment, généralement, dans les discoveries…. Parce que je vous demande un exemple où on pitche Modjo. Dans les discoveries, c'est souvent des échanges où effectivement, il y a un pitch ou des objections qui reviennent régulièrement. Ce qui va se passer, c'est que du coup, là, déjà, vous avez accès à l'ensemble des discoveries qui ont eu lieu sur le quarter. Vous allez aussi pouvoir filtrer par équipe ou par user si par exemple, vous voulez coacher en particulier telle ou telle personne. Vous pouvez aussi vous dire, bon, bah moi, je voudrais regarder les meilleurs pitchs qui ont eu lieu ou les meilleures qualifications, les meilleures démos qui ont eu lieu aujourd'hui sur le quarter et qui ont abouti à une vente. Vu que c'est lié à un Hubspot aujourd'hui, vous allez pouvoir filtrer sur, par exemple, toutes les discoveries qui ont abouti à une vente aujourd'hui chez Modjo Donc, vu que c'est effectivement plugé à votre Hubspot, on vient récupérer des informations. Et là, typiquement, on a aujourd'hui neuf masterclass qui sont officiellement des très bonnes discoveries puisqu'en fait, aujourd'hui, ça aboutit à une vente. Est-ce que déjà vous voyez un peu l'idée d'aller chercher de l'information et cette idée d'entonnoir ?\n - spk2: Oui."),
#  Document(page_content="spk2: Oui.\n - spk0: Super. Alors maintenant, je vais reprendre aussi un call de discovery. Et là, l'idée, du coup, vous voulez suivre finalement la manière dont est pitché aujourd'hui, dont est pitché Modjo en fonction, par exemple, selon vos interlocuteurs, selon les personnes qui aujourd'hui travaillent chez vous. Ce qui va se passer, c'est que du coup, vous allez pouvoir arriver dans un échange. Donc, qu'est-ce que je vais pouvoir prendre comme échange ? Par exemple, je vais prendre groupe Endless, donc une introduction que j'ai eue récemment avec un de mes prospects. Donc là, vous arrivez sur une fenêtre de réécoute d'appels. Vous avez énormément d'informations. Il y a les crescendo. Déjà, vous pouvez voir que directement, c'est lié à votre CRM. Nous, c'est Salesforce, mais vous aurez la même chose avec Hubspot. Vous avez la durée de l'échange. Vous avez la possibilité d'accélérer le moment de réécoute. Sélectionnez du coup que le speaker, si vous voulez réécouter qu'un speaker. Et même traduire et avoir les sous-titres pour être plus efficace dans le moment où vous réécoutez un moment d'appel. Une fois que je vous ai présenté cette fenêtre de réécoute d'appels, il y a un vrai sujet qui est aujourd'hui comprendre comment est pitché, comment est présenté aujourd'hui Modjo. Il y a une fonction, enfin Modjo pardon, excusez-moi, assez haut. Ce qui va se passer, c'est que du coup, avec les chapters, ça va vous permettre de découper déjà votre échange en plusieurs phases. Et déjà, ça va vous permettre de se focusser exactement au bon moment que vous voulez réécouter et challenger. Parce que toute l'idée, c'est de challenger vos sales sur justement leur manière de pitcher ou de répondre à des objections. Ce qui va se passer, c'est que du coup, là, on peut voir qu'à la minute, donc à une minute 15, je vais faire une présentation, du coup ma prospect coralie de Modjo Et ce qui va se passer, c'est qu'un manager aujourd'hui va pouvoir, attendez, hop. Un manager va pouvoir venir cliquer sur justement ce passage du call et pouvoir le réécouter. Est-ce que vous avez entendu le son ou pas ? Non. Non, OK. Écoutez, j'ai pas du… Mais ce qui va se passer, c'est que du coup, vous allez pouvoir réécouter juste le passage où effectivement, « tile size pitch Modjo », pitch à zéro. Donc l'idée, c'est qu'en fait, comprendre comment est pitché, comment est présenté aujourd'hui à zéro et du coup pouvoir challenger sur cet aspect-là du cycle de vente. Je ne comprends pas.\n - spk1: Qu'est-ce que vous apportez de plus que Ringover ?"),
#  Document(page_content="spk1: Qu'est-ce que vous apportez de plus que Ringover ?\n - spk0: Alors Ringover, déjà, il faut que tu sélectionnes tes appels un peu à l'aveugle, déjà. Deuxièmement, et tu ne peux pas venir focusser sur un aspect particulier de l'échange, enfin que ça soit une démo, du coup Ringover, ce n'est pas une démo, mais que ça soit… Tu ne peux pas focusser à un moment particulier de l'échange. Là, avec Modjo du coup, on va t'aider à justement pas avoir réécouter 10 minutes d'appels ou 29 minutes d'appels, mais réécouter finalement pile le moment qui paraît essentiel à coacher.\n - spk1: Ouais, OK. Sauf que…, juste le moment de l'objection ou le moment OK dans le sens où… J'ai envie de dire tout le moment de l'appel.\n - spk0: Tout le moment de l'appel est important ?\n - spk1: On a eu le chien de nos colocs qui est venu s'exploser contre la porte.\n - spk0: D'accord, pas de problème.\n - spk1: Pour montrer le pauvre Padi. J'allais dire, ouais, tout le moment de l'appel amène en partie à cette situation. L'appel en lui-même en complet est important. Par contre, effectivement, dans le cadre d'une objection auquel le sales n'arrive pas à répondre ou un manque de résilience, ça peut être intéressant, mais souvent ça se passe ça à la fin du call. Il y a rarement un truc qui se passe au milieu du call. Moi, clairement, aujourd'hui, quand on fait les appels et les écoutes ring-over, je réécoute rarement tous les appels. Je vais écouter les 30 dernières secondes. En fait, les 30 dernières secondes, tu vois là où ça décroche, tu vois là où le sales a manqué de résilience ou alors il a manqué d'argument. Il n'y a pas besoin. Et s'il n'y a même pas eu 30 secondes, là tu sais que c'est sur la manière de faire le discovery que le sales n'a pas été bon, il n'a pas suffisamment rentré. J'avoue que comme ça, je comprends l'idée. L'idée, même si du coup, je me dis que pour moi, soit ça se passe tout au début, soit ça se passe à la fin. Je vois rarement un élément qui se passe au milieu. À part une information importante, et là, le seul endroit où ça me paraît intéressant d'avoir ça, c'est que si vous avez une fonction compte rendu qui reprend tout et toutes les informations importantes du milieu comme de la fin, ça, ça peut être intéressant parce qu'on sait que les sales, ils font des CR où ils oublient des informations."),
#  Document(page_content="spk0: Oui, effectivement. Du coup, sur cette partie compte rendu, je vais te le montrer. Mais du coup, je vais peut-être prendre un exemple plus parlant sur un cold call. Là, ce que je voulais te montrer, c'était aujourd'hui, comment font les managers ? Ils vont réécouter des moments de présentation de pitch pour pouvoir savoir comment Celeste, comment Charles, comment X ou Y personne, pitch Modjo RoundTable, et savoir justement où est-ce qu'il faut l'améliorer. Il y a cette première aspect, mais du coup, par exemple, si on part justement sur la partie objections, on va prendre par exemple des exemples de cold call. Aujourd'hui, tu vas pouvoir filtrer sur tous les appels où il y a eu des objections. Soit tu veux traquer un sujet en particulier, tous les appels où on a abordé telle ou telle offre, ou les appels où il y a eu des objections, ou des appels où on a partie de concurrence. Ça dépend de quels sont les sujets que tu veux traquer. Par exemple, je prends les appels où il y a eu des objections. Et par exemple, je prends les appels de Caradoc, qui est un de nos nouveaux arrivants et qui a souvent des objections dans ses appels. Ce que je vais faire, c'est que ça te permet déjà d'identifier concrètement où est-ce que des objections ont été abordées. Si je prends un exemple, du coup, de… Ça, c'est quoi le pourcentage de précision ? C'est-à-dire ?\n - spk2: Les objections, comment on va parler d'algorithme, est-ce qu'à 98%, toutes les objections sont bien remontées, sont bien détectées ?"),
#  Document(page_content="spk0: En fait, c'est paramétré lors de la mise en place de Modjo. Par exemple, si tu veux traquer tous les sujets où ont été apportés par exemple des concurrents, grâce au paramétrage, on va pouvoir créer un… On appelle ça un Topix, mais en gros un champ l'écritacle autour de ce sujet-là. Et du coup, on va flagger des mots qui ont été abordés dans le call. Et du coup, ça, c'est l'IA qui identifie que, OK, on a parlé de tel concurrent, on a parlé du mot concurrence. Et ça, pour le coup, c'est 100% fiable, vu que tout dépend du transcript. Mais pour le coup, on a une équipe de data scientists qui travail sur le transcript. Et du coup, aujourd'hui, en termes de qualité, c'est exactement pour ça que des équipes sales font appel à nous. Et autrement, c'est juste l'intelligence artificielle qui le reconnaît dans le discours. Donc ce que je voulais vous partager, par exemple, je prends un appel de prospection qui a été perdu aujourd'hui. L'IA, ce qui permet d'identifier, comme je vous disais, c'était l'objection. Donc tu peux identifier différents sujets. Donc là, par exemple, c'est objection. Là, le manager, ce qu'il va faire, c'est du coup, il va juste venir réécouter ou d'ailleurs juste lire, réécouter ce passage, ce passage et réécouter aussi son size pour voir comment il y a répondu. Là, tu vois, l'objection, elle n'est pas du coup, il y en avait aussi une à la fin, mais l'objection, elle est, on peut l'identifier, la flaguer directement. Du coup, l'idée, c'est pas que tu réécoutes 7 minutes d'appel, mais c'est bien que tu réécoutes potentiellement que cette partie là de l'appel. OK. OK. Donc ça, il y a sa première aspect là. Donc déjà, c'est l'IA identifie des sujets abordés. Le deuxième point, c'est qu'en fait, c'est aussi, c'est évidemment un noté de coaching. Donc là, tu vois, en fait, Catalin, il est venu taguer son manager parce qu'il a besoin d'être sur ce call là. Il va venir taguer son manager et son manager va pouvoir faire une review, donc des feedbacks formalisés, concrets pour justement coacher son sales, son BDR. Pour ça, on a une fonctionnalité qui s'appelle du coup la review, pardon, qui permet en fonction effectivement de la typologie de call de finalement noter, apporter une grille lecture à ton à ton size pour qu'il puisse comprendre ses axes d'amélioration et pouvoir revenir aussi sur ce qui est les feedbacks de son manager. Au lieu que ce soit des feedbacks qui soient faits à la volée et que ça soit entre guillemets un peu oublié et du coup qu'il puisse finalement revenir sur son call. Comment ça se matérialise? Je vous montre. Ça se matérialise de cette manière là. Donc là, typiquement, à la fin, tu as une petite note et du coup le manager là aujourd'hui, Gabriel, il a pu venir réécouter ce call où son manager l'a identifié à telle minute et pouvoir prendre des notes et du coup l'accompagner justement dans sa réponse à des objections. Qu'est ce que tu en penses de ça?"),
#  Document(page_content="spk2: Ça apporte de la précision sur ton appel et pour le retravailler derrière. Ça, c'est sûr. La question que je te poserai à la fin de la réunion, c'est aujourd'hui, comme tu connais notre contexte, est ce que c'est un outil qu'il faudrait mettre en place ou est ce qu'il faut attendre que nous, on soit plus carrés pour après améliorer quelque chose sur un socle propre?\n - spk0: Aujourd'hui, ce que vous me disiez, c'est que vous aviez besoin justement de comprendre un peu les pitches, les réponses à des objections, tester, challenger. La l'idée de cet outil, c'est justement vous donner les moyens de réécouter, challenger, avoir du feedback, comprendre comment réagissent votre prospect aux fonctions de par exemple, quand on pousse telle ou telle offre, par exemple, pourquoi vous avez aujourd'hui un sales qui pousse, enfin, pourquoi vous avez un sales par exemple qui pousse quatre offres de marque blanche et pourquoi il y en a un qui arrive à en pousser qu'une? En gros, c'est comprendre la différence de discours, comment y répondre aux objections. Sans un outil comme ça, c'est beaucoup plus compliqué à suivre, analyser, challenger, faire du feedback en tant que manager.\n - spk1: Après, je pense que aujourd'hui, moi, ce qui m'interpelle avec Modjo c'est le temps que ça doit prendre un manager de faire ce travail là. Ça, c'est le premier point. Je t'avoue que là, comme ça, à chaud, je n'identifie pas trop la différence de temps entre les écoutes Ringover et Modjo. Je n'ai pas le sentiment, moi, je me connecte à Ringover. J'écoute les appels, Merlin peut le faire. On a les appels qui sont dans Hubspot. J'ai du mal à voir à quel endroit vous faites gagner du temps à ce niveau là. Ce qui est sûr, c'est que pour écouter l'appel, il faut prendre du temps. Moi ou Merlin, si on veut écouter les appels, il faut qu'on se mette et qu'on s'assoit et qu'on se dise pendant 30 minutes, on fait des coups de l'appel et qu'on soit sur Ringover ou que ce soit sur Modjo Dans tous les cas, il faut prendre les 30 minutes. Donc après, tu as le fameux sujet où tu dis que vous vous isolez, etc. Mais comme je t'ai dit, pour moi aujourd'hui, j'ai une manière d'isoler parce que quand tu connais un peu la structuration des appels, tu sais que tout se passe au début, voire à la fin. La notion de commentaire, je trouve ça intéressant, mais je vais du mal à comprendre en quoi ce n'est pas un doublon par rapport à Hubspot où tu as ta ligne avec ton call écouté. En fait, tu peux faire un commentaire dessus si tu as écouté en disant ton Sales il dit, il tag Merlin, il dit Merlin, ce call là, j'ai eu des problèmes. Moi, je le réécoute et je lui dis, en gros, je trouve l'UX et la manière dont c'est disposé plus sympa que sur Hubspot dans les faits, ce que je vous accorde. Pour moi, vous venez faire mieux que Hubspot quelque chose qu'ils essaient de faire aussi. Mais il va falloir qu'on rationnalise notre décision car ça a un coût supplémentaire."),
#  Document(page_content="spk0: Ok, alors du coup, je fais mon mea culpa parce que je pense que je n'ai pas été assez pertinente dans ma présentation. Première chose, c'est que déjà, c'est pas que pour challenger les calls, mais du coup, vous avez un sujet aussi sur la partie démo et du coup, c'est vraiment un outil global. Le deuxième point que je peux partager, c'est qu'aujourd'hui, toutes les équipes qu'on accompagne sont sur du Hubspot téléphonie et par exemple, ou sur du aircall et par exemple, toutes les équipes d'aircall aujourd'hui n'utilisent absolument pas les enregistrements aircall pour réécouter leurs équipes. Pourquoi ? Parce que justement, ils ont besoin absolument de gagner du temps et du coup, tu me disais, ben en fait, je vois pas en quoi ça me fait gagner du temps. Là, l'idée, c'est qu'effectivement, tu puisses vraiment te focuser sur les, enfin sur tous les appels où il y a tel ou tel sujet qui ont été abordés et en fait, pas par un, c'est vraiment industrier. T'as ton process de réécoute aujourd'hui au lieu de...\n - spk1: C'est juste, je rebondirais sur la question et je pense que, alors je sais pas, on ne s'est pas parlé, mais je pense que, en fait, dans la question, c'est est-ce que nous, on n'est pas trop petit aujourd'hui et on n'est pas trop dans un stade de croissance et de manque d'industrialisation pour prendre un Modjo. Je comprends tout à fait Modjo dans un, tu dis, Hubspot, Hubspot l'utilise et tout, une grosse boîte qui a déjà, qui a déjà ranqué, qui a déjà staffé avec différents niveaux. Je comprends tout à fait l'outil, mais là, nous, à l'instant T, moi, j'ai l'impression que ça prend beaucoup de temps. Et effectivement, je rebondis sur la question posée dans le sens où, à quel moment c'est opportun de le prendre ? Parce que là, c'est vrai que moi, comme ça, à chaud, je pense que ça me paraît très très lourd pour nous. Notre première problématique, c'est le manque de temps. Et en fait, en voyant tout ce que Modjo fait, c'est très bien, mais en gros, c'est encore du temps à prendre."),
#  Document(page_content="spk0: Ok, merci pour ces infos. Toute l'idée, c'est d'un Modjo c'est de faire gagner du temps. Donc effectivement, si tu ne l'ai pas présenté de la manière à aujourd'hui, ça te permet de faire gagner du temps. Je comprends que ça te paraisse pas cohérent. Concrètement, un Modjo au contraire, c'est absolument pas pour les, c'est vraiment pas pour des équipes qui ont déjà squelé, qui ont déjà industrialisé leur process. Pour la petite info et justement pour du SquareChair qui était au démarrage ou même Planity qu'on accompagnait quand ils étaient 4 sales. C'était vraiment pour justement leur donner des bies sur comment mettre en place des process. Une fois que les process sont mis en place, on n'a absolument pas besoin d'un outil justement d'aide à la mise en place de process. Donc c'est vraiment pour le coup, pour aider à processer plus la partie coaching, pour aider à processer toute la partie CRM que je vais vous montrer, pour aider à processer toute la partie onboarding, avoir un outil qui compile toute cette base de connaissances et de performances. Et c'est un outil à la fois côté manager parce que l'idée c'est de gagner du temps sur les aspects où ils vont coacher individuellement les reps. Et après du côté sales ou CSM, c'est aussi un outil pour s'améliorer, se réécouter, demander du feedback à son manager sans attendre des one one ou des workshops qui arrivent au fil de l'eau, mais qui sont du coup plus occasionnels.\n - spk2: Moi en tout cas, je comprends effectivement l'utilité d'un outil avec justement cette analyse qui permet de bien découper. Et je pense que c'est dans ta deuxième partie de présentation. Qu'est ce qui peut ou Modjo peut nous challenger?\n - spk0: Est ce que tu peux préciser cette question?\n - spk2: Alors c'est peut être moi qui n'avais pas compris tout le permettre de l'outil. Là, le fait d'analyser les séquences et de dire ce que tu as montré tout à l'heure, effectivement, c'est super pertinent. Et à la fois pour quelqu'un qui analyse, comme tu dis, il peut aller directement à l'essentiel, tout est trié, tout est catégorisé. Donc ça, c'est top. Mais je pensais qu'il y avait aussi une analyse où il y avait un challenge sur comment la présentation était faite, comment le pitch commercial était fait. Mais encore une fois, je suis peut être gouré dans l'interprétation de ce type de plateforme.\n - spk1: Non, non, je te confirme que nous, j'avais compris comme toi, dans le sens où on pensait que l'IA, on allait rentrer un pitch, un sorte de script de base, un template. Et l'IA, elle devait dire si le script a été respecté ou pas.\n - spk2: Respecté sans forcément avoir cette notion là, mais nous challenger dessus par rapport à l'IA, à toutes les possibilités de l'IA pour améliorer notre pitch en nous faisant des propositions d'amélioration."),
# ...
#  Document(page_content="spk2: Si le manager est compris dedans, ça serait 5.\n - spk0: OK. Mais du coup, toute la partie, donc ça serait que sur la partie call, pas du tout sur la partie vidéo.\n - spk2: Alors la partie vidéo, elle est faite plus par les CSM. Donc dans un deuxième temps, parce que ça, c'est pas aujourd'hui, c'est pas le gros du sujet.\n - spk0: Bah du coup, sur la partie aujourd'hui, du coup, notre business model. Du coup, notre business model, c'est à la licence enregistreuse. Donc, c'est toutes les personnes qui importent de la matière des enregistrements dans Modjo Donc là, ça serait les 4, 5 personnes côté sales. On a un business model où aujourd'hui, du coup, c'est un engagement annuel. Et du coup, le prix à la licence, le prix d'entrée, c'est de 99 euros par licence enregistreuse. Il y a des leviers de négociation, évidemment, possibles en fonction des marges de manoeuvre que vous pouvez avoir. Mais aujourd'hui, du coup, c'est 99 euros par licence par mois.\n - spk1: Nous, on n'a pas de marge de manoeuvre. C'est toi, éventuellement, tu en as. Mais nous, on n'en a pas.\n - spk0: Mais tu imagines bien que si on fait des discounts, il y a forcément des contreparties. Tu dois être meilleur sales que moi. Et du coup, j'imagine que tu as l'habitude de négocier. Du coup, les contreparties, c'est la vélocité en termes de la vélocité en termes de signature, la durée d'engagement et la possibilité aussi de nous faire des introductions auprès de CEO, VP sales, manager sales qui auraient justement les mêmes problématiques, les mêmes enjeux aujourd'hui que vous ou que en tout cas, qui répondraient dont Modjo répondrait en termes de valeur.\n - spk1: Et du coup, pour les trois introductions, combien je gagne ?\n - spk0: 5 %. Mais alors aujourd'hui, non, mais écoutez, aujourd'hui, là, le tout, enfin, le sujet de cet échange, c'est du coup de faire une démo et de valider aujourd'hui la valeur et de vous présenter le business model. Moi, ce que je voudrais faire, c'est vous, du coup, vous partage, enfin, vous faire une offre tarifaire personnalisée. Justement, qu'on voit aujourd'hui les leviers de négociation que vous seriez, enfin, qu'on pourrait activer, actionner, pardon, pour effectivement réduire ce prix à la licence. Du coup, moi, ce que je voudrais vous proposer, c'est plutôt un call d'offre tarifaire parce qu'aujourd'hui, c'est comme ça qu'on fonctionne et comme ça, ça nous permettrait d'avoir plus de temps justement sur l'aspect ROI et budget. Je sais pas ce que vous en pensez.\n - spk2: Ouais, alors moi, je veux juste te donner une autre information. On a 18 mois pour performer. Voilà. Donc, tout budget supplémentaire qui arrive dans ces 18 mois, il faut qu'il soit justifié ou alors avoir un discount comme Hubspot va nous faire là, même si c'est un discount, il y aura des bananes qui nous font."),
#  Document(page_content="spk0: Aujourd'hui, de toute façon, Modjo c'est pas un outil qui est mis en place parce qu'il n'y a pas de ROI. Et le ROI ne serait-ce qu'en termes de taux de conversion, si je reste juste sur le taux de conversion et pas le temps économisé et bref et pas mal d'autres aspects. Aujourd'hui, le ROI, c'est plus 20% sur le taux de conversion dans les équipes aujourd'hui qui sont équipées d'un Modjo versus avant avant mise en place d'un Modjo Donc, c'est pour ça que quand tu parlais de coûts tout à l'heure, il faut vraiment voir ça. En fait, aujourd'hui, combien ça peut vous rapporter versus combien ça va vous coûter. Et du coup, c'est tout l'idée d'un prochain échange, c'est de justement voir combien ça pourrait vous rapporter aujourd'hui. Mais du coup, aujourd'hui, quand tu me parlais d'enveloppes budgétaires, tu en as une ou dans tous les cas, vous n'en avez pas?\n - spk2: On en a une. Oui, on en a une après de donner un montant exact. J'en serais incapable. En tout cas, c'est sûr que c'est un montant qui est vraiment minime. Je te dis avec Hubspot, on est en train de négocier à 200 euros près. Donc, tu vois, on en est rendu.\n - spk0: OK. Et du coup, là, je te partageais juste.\n - spk1: C'est normal de négocier Hubspot, vu ce qui nous prenne 200 euros, c'est de survoir un point. Aujourd'hui, on n'a pas de. Ce n'était pas prévu. On a obligatoirement le besoin d'un e-media. Faut voir le ROI. C'est ce que tu as expliqué. Tu as répondu à deux, trois de me pain. Ça donne. Non, ça donne une bonne vision. Fais nous une offre du coup avec. Avec la meilleure offre que tu peux faire. Et puis, on regardera ça. Là, il faut vraiment qu'on coupe parce qu'il faut que l'on enchaine. C'était intéressant. C'était intéressant. Donc, je te remercie pour ton temps.\n - spk0: Juste sur quoi tu as un doute du coup? Ce que tu m'as dit deux, trois pain, ça veut dire qu'il y en a au moins une auxquelles on n'a pas répondu.\n - spk1: C'est pas que vous n'y répondez pas. C'est que, en gros, je ne sais pas si votre... Déjà, j'ai identifié des bonnes pratiques. Donc, merci. Du coup, je vais dire à mes six de faire certaines choses avec maintenant pour à être Hubspotté qui est un peu du Modjo Ça, c'est métier pour rien dans le sens où c'est. C'est j'allais dire, ça fait partie des choses. Vous faites mieux quelque chose que ce qu'est capable de faire en fait concrètement. Mais vous faites beaucoup mieux. Encore une fois, lui, c'est très sympa. C'est vrai que, par contre, à l'instant T, il y a. Je pense des choses qui sont permises par votre outil qu'on peut faire de manière un peu différente avec des outils un peu. On peut bricoler quoi. Après, le bricolage, ça reste du bricolage. Soyons, j'en ai conscience. Mais bon, à voir après, faites nous une bonne offre et puis on rediscute. La notion des CR, c'est un sujet. Vous avez l'air de le faire. La notion de la synthèse d'analytics à la fin, j'aime bien. Donc, live note aussi.\n - spk0: Tu as bien aimé la live note."),
#  Document(page_content="spk0: Tu as bien aimé la live note.\n - spk1: Voilà, deux, trois pains. En règle générale, je perds pas le temps. Mais, mais, mais, on va voir ton offre. Et derrière, nous, on va rediscuter en interne. Mais évidemment, effectivement, du budget, il n'y en avait pas de base. Faut voir le ROI. Par contre, clairement, à 1000 euros et 1000 euros ou 500, je suis d'accord avec Antoine. On n'ira pas.\n - spk0: Par mois. Oui, on y va. Là, de toute façon, là, du coup, ce que je vous disais, c'était cinq users à 99 euros. Le prix de base, c'est du coup, ça ferait un 495 de mémoire sans levier d'action.\n - spk1: Voilà, je pense que comme t'as beaucoup de levier d'action, je pense que tu vas actionner plein de leviers pour que ce soit potentiellement.\n - spk0: Bah, écoutez, dans ce cas là, prenons nous un créneau parce que je sais que votre temps est compté. Et du coup, ce que je vous propose, c'est qu'on se prenne un créneau pour vous présenter l'offre.\n - spk1: Au pire, tu nous refais un mail et tu nous redis ou tu nous envoies ton calendrier. On prend le calendrier.\n - spk0: C'est pas plus simple de croiser nos agendas maintenant.\n - spk2: Non, mais je vais gérer le troisième rendez-vous.\n - spk1: Voilà, parfait. OK, super.\n - spk0: Allez, ça marche. Merci à tous les trois. Je reste le Celeste juste pour finir. Oui, ça marche.\n - spk2: Merci. Merci Antoine. Donc, Celeste, oui, encore une fois, outil très intéressant. J'avais une autre question au niveau du on boarding. Comment ça se passe chez vous?\n - spk0: Oui, alors du coup, en termes d'onboarding, du coup, effectivement, Modjo c'est 70 80% la plateforme. Mais c'est surtout que vous avez un accompte manager, donc un consultant qui est là pour vous accompagner de la paramétrage. L'onboarding jusqu'à la fin d'utilisation de Modjo Donc ce que je veux dire, c'est qu'en termes d'onboarding, il y a effectivement un onboarding manager, un onboarding équipe qui est qui est prévu en plus du paramétrage. Et ensuite, tout au long de l'utilisation, vous avez un consultant qui est là pour vous partager des tips marché, comment améliorer votre productivité, comment mieux coacher vos équipes, comment les sales peuvent être plus utilisé Modjo Et donc, ça, c'est tout ça, c'est pris en compte dans le prix de la licence du coup enregistreuse. Donc, en fait, il n'y a aucun coût additionnel par rapport à ce que je vous présenterai. Est ce que je vous ai présenté ne serait ce que les 495 euros. Vous avez vraiment un compte manager qui est dédié. Et on a notamment des gens qui sont qui sont qui sont experts sur des secteurs. On accompagne pas mal de saas dans justement le domaine de la chevalerie comme Gymlib, qui est notre premier premier client aujourd'hui. Ils étaient que trois à l'époque et tu vois maintenant à la taille de Gymlib Gymlib.\n - spk2: Ah c'est Gymlib."),
#  Document(page_content="spk2: Ah c'est Gymlib.\n - spk0: Voilà, donc tu vas très bien connaître. Donc tu vois, ça, c'était un de nos premiers clients. Et vraiment, encore une fois, ils n'ont pas du tout mis en place Modjo quand ils étaient Gymlib de maintenant. Ils sont une armée de ça. Ils l'ont mis en place au démarrage où justement ils avaient besoin de gagner en temps à comprendre exactement les besoins du marché, comment pitcher leurs équipes, comment ils répondaient aux objections et justement passer d'un mode un peu bricolage artisanal à un mode crescendo beaucoup plus processé pour aller chercher des parts de marché, pour aller chercher de la productivité, pour faire en sorte que leur leur junior arrive très rapidement au niveau d'un justement Antonique cofondeur qui, évidemment, est le meilleur sales aujourd'hui, mais que lui se détache progressivement du coup de la vente pour avoir des sales qui prennent le relais. Donc c'est tout l'idée d'un Modjo aujourd'hui.\n - spk2: OK, OK, OK.\n - spk0: J'ai bien répondu à ta question.\n - spk2: J'avais saisi effectivement ça. Et sur les évolutions du produit, est-ce qu'on reste sur le même prix ou est-ce qu'on va être bloqué? Si on veut passer à des évolutions là dans tu dis dans un mois là, est-ce que c'est un complémentaire?\n - spk0: Non, effectivement, il y a absolument ce qui est signé restera signé. Ce que je veux dire, c'est que c'est notamment la fonctionnalité dont je t'ai parlé. Tu vas en bénéficier. On n'a pas de coût supplémentaire en fonction des features que tu choisis. Tu auras accès à toutes les nouveautés. Bref, à tout.\n - spk2: Parce que je te dis ça parce que Intercom, par exemple, qui est un excellent outil, il sort des fonctionnalités régulièrement et il y en a qui ne font pas partie du scope. C'est des modules en fait additionnels. C'est pareil avec des ardoises qui sont colossales pour des boîtes comme nous. Même si c'est des outils qui sont très pertinents. Donc voilà, nous, ce que je peux juste te dire, en tout cas, c'est que on est prêt à s'engager. En tout cas, sur les 18 prochains mois avec un tarif très très préférentiel. Très sincèrement et après, continue avec vous. Il n'y a pas de raison à ce que, en tout cas, moi, je crois en cet outil là. Ce n'est pas le problème. Aujourd'hui, nous, le frein, c'est à la fois le tarif et un frein mineur. C'est ça, il faut qu'on en discute en interne. C'est le temps à accorder après sur cet outil là. Si c'est pour avoir un outil pour dire qu'on a Modjo mais derrière qu'on ne l'exploite pas. Parce que aujourd'hui, on a des outils qu'on n'exploite pas comme il se devrait, comme il devrait. Ça ne nous servira à rien. Mais ça, c'est plus surprenant à se mettre d'avis."),
#  Document(page_content="spk0: OK, effectivement, après, tu vois, sur la partie productivité, notes. Aujourd'hui, du coup, c'est l'IA qui fait tout. Et donc, pour le coup, ça remonte directement dans ton Hubspot. Donc, en fait, de toute façon, les calls, ils sont enregistrés. Donc ça, de toute façon, on va dire que vous avez entre guillemets plus la main mise sur est-ce que mon IA prend des notes. De toute façon, elle prendra les notes. Et sur la partie du coup réécoute. Pour moi, c'est on vient pas modifier vos routines, ce qui est mis en place par Merlin, ce qui est mis en place par Arthur, peut être sur toi, sur la partie management des équipes CSM. On vient juste vous faire gagner du temps d'écoupler votre force de coaching et surtout donner les moyens à des sales aujourd'hui ou des CSM de s'améliorer. Et du coup, aujourd'hui, honnêtement, en termes de connexion, c'est évidemment qu'il y a des managers. Mais en fait, aujourd'hui, c'est un outil. Il y a des équipes aujourd'hui qui font des sales aujourd'hui qui demandent de leur de leurs entretiens. Est ce que vous avez Modjo ? Parce qu'en fait, ça leur simplifie à mort la vie. La dernière fois, on avait parlé du fait que vous ayez des grands comptes et six mois de cycles de ventes. Si je ne m'abuse, justement, un outil comme ça, ça te permet de revenir sur tes échanges, de te remettre dedans, de préparer des rendez-vous, être beaucoup plus pertinent. Et en fait, c'est vraiment comment dire? C'est en fait, ça devient indispensable pour les équipes. Du coup, en termes d'usage, je comprends effectivement le côté. On n'a pas envie de mettre en place un outil pour un outil. Mais alors là, pour le coup, moi, je sais que tu vois le jour où je bosse de Modjo je sais que je veux une équipe, une boîte où il y a un Modjo aujourd'hui. Parce que moi, je m'y imagine pas repasser à des tâches manuelles, revenir sur des enregistrements pour me préparer. Ça me paraît aberrant de faire ça. Voilà, voilà. Écoute, ce que je te propose, c'est qu'on se prenne un petit créneau du coup, effectivement, pour la partie tarifaire.\n - spk2: Oui.\n - spk0: Qu'est ce que tu penses? Moi, j'ai un créneau demain si tu veux ou autrement lundi.\n - spk2: Lundi, ce sera mieux. Lundi, lundi, lundi.\n - spk1: Qu'est ce que c'est?\n - spk2: Lundi 16h30.")]

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.chains import RetrievalQA

vectorstore = Chroma.from_documents(
    documents=docs, embedding=OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
)
prompt_template = """Act as a professional technical meeting summarizer.
Tone: formal
Format: Question Answering, concise.
Length:  The minimum amount of words required up to 100. No more.
Point of View: act as an external tool, you are not part of a specific team. You don't say "you", you just mention the name of the actors at play.
Use the following pieces of context provided (a transcription of a professional videocall) to answer the question at the end.
If you don't know the answer just say it, don't make up an answer.
Answer the question precisely without adding unrelated information.
-----------\n
context: {context}
-----------\n
CONCISE AND HELPFUL ANSWER IN FERNCH:"""
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=vectorstore.as_retriever(),
    chain_type_kwargs={"prompt": PromptTemplate.from_template(prompt_template)},
)
answer = qa_chain({"query": "Who is Lancelot?"})
print(answer["result"])
# Out:
# Lancelot est le CEO de SquareChair et il est dans le même incubateur que vous.

# %%
answer = qa_chain(
    {
        "query": "What are the next steps as follow-up to the current conversation that people agree to throughout the conversation?"
    }
)
print(answer["result"])
# Out:
# La question posée à la fin de la réunion est de savoir s'il faut mettre en place cet outil maintenant ou attendre que l'équipe soit plus organisée pour l'améliorer sur une base solide.

# %%
answer = qa_chain(
    {
        "query": """Was there any clear mention of a budget? If so answer with the following format:
                   budget = <budget here with dots between every thousand expressed in euros> € 
                   If there was no budget don't make up an answer, say it clearly"""
    }
)
print(answer["result"])
# Out:
# Le budget actuel de l'entreprise est serré et il n'est pas possible de dépenser 1000 euros ou même 500 euros par mois pour l'outil en question. Ils utilisent déjà Intercom et Hubspot, qui sont coûteux. En ce qui concerne les utilisateurs, ils envisagent de commencer avec 4 licences et si le manager est inclus, cela passerait à 5.

# %%
answer = qa_chain({"query": """What CRM does the prospect use"""})
print(answer["result"])
# Out:
# Le sujet principal de la réunion était l'intégration automatique des données dans le CRM HubSpot.

# %%
answer = qa_chain({"query": """What are the main objections raised"""})
print(answer["result"])
# Out:
# Le participant a mentionné qu'il était important d'être respecté et de se faire challenger par rapport à l'IA. Il souhaite que des propositions d'amélioration lui soient faites pour améliorer leur pitch.

# %%
# TODO:
# Creer structure de repo:
# cleaned_notebook.py
# fichier python pour la summary task
# fichier python pour la QA task
# fichier python final commente main.py
# 1 test par exp pour le jsonloader readme
